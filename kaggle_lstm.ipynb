# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import pickle

from sklearn.metrics import confusion_matrix

import keras
from keras import optimizers
from keras import backend as K
from keras import regularizers
from keras.models import Sequential
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.layers import Input, Embedding, Dense, SimpleRNN, LSTM, Concatenate
from keras.utils import plot_model
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

from pymagnitude import *
from tqdm import tqdm
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer 
import os, re, csv, math, codecs

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %%
train_df = pd.read_csv('hsd/Reddit/train.csv', sep=',', header=0, index_col=0)
test_df = pd.read_csv('hsd/Reddit/test.csv', sep=',', header=0, index_col=0)
validate_df = pd.read_csv('hsd/Reddit/validate.csv', sep=',', header=0, index_col=0)
test_df = test_df.fillna('_NA_')

print("num train: ", train_df.shape[0])
print("num test: ", test_df.shape[0])

label_names = ['class']
y_train = list(map(lambda number: 1 if number[0] == 2 else 0, train_df[label_names].values.tolist()))
y_train = to_categorical(y_train)

y_test = list(map(lambda number: 1 if number[0] == 2 else 0, test_df[label_names].values.tolist()))
y_test = to_categorical(y_test)

#visualize word distribution
train_df['doc_len'] = train_df['lemmatized_text'].apply( lambda words: len(str(words).split()) )
max_seq_len = np.round(train_df['doc_len'].mean() + train_df['doc_len'].std()).astype(int) + 2
sns.distplot(train_df['doc_len'], hist=True, kde=True, color='b', label='doc len')
plt.axvline(x=max_seq_len, color='k', linestyle='--', label='max len')
plt.title('comment length'); plt.legend()
plt.show()
# Out:
# num train:  38592
# num test:  16540

# %%
MAX_NB_WORDS = 100000

raw_docs_train = train_df['lemmatized_text'].apply(lambda words: str(words)).tolist()
raw_docs_test = test_df['lemmatized_text'].apply(lambda words: str(words)).tolist() 
raw_docs_validate = validate_df['lemmatized_text'].apply(lambda words: str(words)).tolist() 
num_classes = len(label_names)

print("tokenizing input data...")
tokenizer = Tokenizer(num_words=MAX_NB_WORDS, lower=True, char_level=False)
tokenizer.fit_on_texts(raw_docs_train + raw_docs_test + raw_docs_validate)  #leaky
word_seq_train = tokenizer.texts_to_sequences(raw_docs_train)
word_seq_test = tokenizer.texts_to_sequences(raw_docs_test)
word_seq_val = tokenizer.texts_to_sequences(raw_docs_validate)
word_index = tokenizer.word_index
print("dictionary size: ", len(word_index))

#pad sequences
word_seq_train = sequence.pad_sequences(word_seq_train, maxlen=max_seq_len)
word_seq_test = sequence.pad_sequences(word_seq_test, maxlen=max_seq_len)
word_seq_val = sequence.pad_sequences(word_seq_val, maxlen=max_seq_len)
# Out:
# tokenizing input data...
# dictionary size:  42027

# %%
#training params
batch_size = 256 
num_epochs = 20 

#model parameters
CONV_FILTER = (2, 4)
num_filters = 64 
embed_dim = 300 
weight_decay = 1e-4

# hyperparams
LAYERS = 4  # convolutional layers count
LR = 0.01  # learning rate
OPTIM = tf.keras.optimizers.Adam  # optimizer
EPOCHS = 10

# params
BATCH_SIZE = 50  # size of input batch
INIT = 'random_normal'  # trainable param initializer
RNN_UNITS = 64  # recurrent network working units

# %%
#embedding matrix
print('preparing embedding matrix...')
words_not_found = []
nb_words = min(MAX_NB_WORDS, len(word_index))
embedding_matrix = np.zeros((nb_words, embed_dim))
vecs = Magnitude(MagnitudeUtils.download_model('http://magnitude.plasticity.ai/fasttext/medium/crawl-300d-2M.magnitude'))
for word, i in word_index.items():
    if i >= nb_words:
        continue
    embedding_vector = vecs.query(word)
    if (embedding_vector is not None) and len(embedding_vector) > 0:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
    else:
        words_not_found.append(word)
vecs = None
print('number of null word embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# preparing embedding matrix...
# number of null word embeddings: 1

# %%
class MetricsCallback(Callback):
    def __init__(self):
        super(MetricsCallback, self).__init__()
        self.val_f1s0 = []
        self.val_f1s1 = []
    
    def on_epoch_end(self, epoch, logs={}):
        val_predict = np.asarray(tf.argmax(self.model.predict(word_seq_test), axis=1))
        val_true = np.asarray(tf.argmax(y_test, axis=1))
        c_m = confusion_matrix(val_true, val_predict, labels=[0, 1])
        self.val_f1s0.append(2*float(c_m[0][0])/(2*float(c_m[0][0]) + c_m[0][1] + c_m[1][0]))
        self.val_f1s1.append(2*float(c_m[1][1])/(2*float(c_m[1][1]) + c_m[1][0] + c_m[0][1]))

# %%
class LSTMModel():
    def __init__(self, nb_words, embed_dim, embedding_matrix, max_seq_len, model_type='lstm', name='conv_model', **kwargs):
        self.type = LSTM if model_type == 'lstm' else SimpleRNN
        
        # hyperparams
        self.layers = LAYERS if 'layers' not in kwargs else kwargs['layers']
        self.lr = LR if 'lr' not in kwargs else kwargs['lr']
        self.optim = OPTIM(learning_rate=self.lr) if 'optim' not in kwargs else kwargs['optim'](learning_rate=self.lr)
        self.epochs = EPOCHS if 'epochs' not in kwargs else kwargs['epochs']
        
        # params
        self.batch_size = BATCH_SIZE if 'batch_size' not in kwargs else kwargs['batch_size']
        self.init = INIT if 'init' not in kwargs else kwargs['init']
        self.rnn_units = RNN_UNITS if 'rnn_units' not in kwargs else kwargs['rnn_units']
        
        # layers
        self.model = Sequential()
        self.model.add(Embedding(nb_words, embed_dim,
                    weights=[embedding_matrix], input_length=max_seq_len, trainable=False))
        self.model.add(self.type(units=self.rnn_units, name='wt_recurrent',
                       kernel_initializer=self.init, bias_initializer=self.init))
                    
        self.model.add(Dense(64, activation='relu', name='dense_1',
                    kernel_initializer='random_normal', bias_initializer='random_normal'))
        self.model.add(Dense(2, activation='softmax', name='predictions',
                    kernel_initializer='random_normal', bias_initializer='random_normal'))

        self.name = name
        self.mc = MetricsCallback()
    
    def summary(self):
        return self.model.summary()
    
    def compile(self):
        self.model.compile(optimizer=self.optim,
                           loss=tf.keras.losses.CategoricalCrossentropy(),
                           metrics=[tf.keras.metrics.CategoricalAccuracy()])
    
    def fit(self, X_tr, y_tr, X_ev, y_ev):
        return self.model.fit(X_tr, y_tr, batch_size=self.batch_size, epochs=self.epochs,
                              validation_data=(X_ev, y_ev), callbacks=[self.mc])
    
    def predict(self, X_t):
        return self.model.predict(X_t)
    
    def save(self, file_name):
        self.model.save(file_name)

# %%
def models_comparison_bars(df, title, interval=2, save_file=None):
    fig, axs = plt.subplots(1, 3, figsize=(16, 4))
    
    labels = [i+1 if i%interval == 0 else '' for i in range(len(df))]
    x = range(len(labels))
    acc = df['acc'].values
    f1s0 = df['f1s0'].values
    f1s1 = df['f1s1'].values
    
    max_acc_id = np.argmax(acc)
    max_f1s0_id = np.argmax(f1s0)
    max_f1s1_id = np.argmax(f1s1)
    
    axs[0].bar(x, acc, color='r')
    axs[0].set_xlabel('Model number')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xticks(x)
    axs[0].set_xticklabels(labels)
    axs[0].set_ylim([0, 1])
    axs[0].set_title('Accuracy | max ({}) at: {}'.format(np.round(np.max(acc), 2), max_acc_id+1))
    axs[0].patches[max_acc_id].set_facecolor('g')
    
    axs[1].bar(x, f1s0, color='b')
    axs[1].set_xlabel('Model number')
    axs[1].set_ylabel('F1 score (no hate)')
    axs[1].set_title('F1 score (no hate) | max ({}) at: {}'.format(np.round(np.max(f1s0), 2), max_f1s0_id+1))
    axs[1].set_xticks(x)
    axs[1].set_xticklabels(labels)
    axs[1].set_ylim([0, 1])
    axs[1].patches[max_f1s0_id].set_facecolor('g')
    
    axs[2].bar(x, f1s1, color='m')
    axs[2].set_xlabel('Model number')
    axs[2].set_ylabel('F1 score (hate speech)')
    axs[2].set_title('F1 score (hate speech) | max ({}) at: {}'.format(np.round(np.max(f1s1), 2),
                                                                       max_f1s1_id+1))
    axs[2].set_xticks(x)
    axs[2].set_xticklabels(labels)
    axs[2].set_ylim([0, 1])
    axs[2].patches[max_f1s1_id].set_facecolor('g')
    
    fig.suptitle(title)
    
    if save_file:
        plt.savefig(save_file)
    plt.show()

# %%
def get_hyperparams_options(layers_options = [1], lr_options = [0.01, 0.001],
                            optim_options = [tf.keras.optimizers.Adam, tf.keras.optimizers.SGD],
                            epochs_options = [5, 10, 15]):
    hp_options = []
    for epochs in [epochs_options[-1]]:  # changed to process 15 epochs (eval. after each 5)
        for lr in lr_options:
            for optim in optim_options:
                for layer in layers_options:
                    hp_options.append({'lr': lr, 'optim': optim, 'epochs': epochs, 'layers': layer})
    return hp_options

# %%
def find_hyper_parameters(options, shape, save_path = 'results/en_lstm/hyperparams_research.csv', epochs_options = [5, 10, 15]):    
    if not os.path.exists(save_path):
        hp_results = []
        for i, opts in enumerate(options):
            print('\nResearching for {}/{} | Hyperparams: {}\n'.format(i+1, len(hp_options), opts))

            hp_model = LSTMModel(nb_words, embed_dim, embedding_matrix, max_seq_len, **opts)
            hp_model.compile()
            hp_history = hp_model.fit(word_seq_train, y_train, word_seq_test, y_test)

            # append means for 5, 10 and 15 epochs
            for eps in epochs_options:
                hp_results.append({'acc': np.mean(hp_history.history['categorical_accuracy'][:eps]),
                                   'val_acc': np.mean(hp_history.history['val_categorical_accuracy'][:eps]),
                                   'loss': np.mean(hp_history.history['val_loss'][:eps]),
                                   'f1s0': np.mean(hp_model.mc.val_f1s0[:eps]),
                                   'f1s1': np.mean(hp_model.mc.val_f1s1[:eps])})

        hp_results_df = pd.DataFrame(hp_results)
        hp_results_df.to_csv(save_path)
    else:
        hp_results_df = pd.read_csv(save_path, index_col=0)
    return hp_results_df

# %%
hp_options = get_hyperparams_options()
hp_results_df = find_hyper_parameters(options = hp_options, shape=(50, 100, 3, ))

# %%
pd.DataFrame(hp_options).head()
# Out:
#       lr                                              optim  epochs  layers
# 0  0.010  <class 'tensorflow.python.keras.optimizer_v2.a...      15       1
# 1  0.010  <class 'tensorflow.python.keras.optimizer_v2.g...      15       1
# 2  0.001  <class 'tensorflow.python.keras.optimizer_v2.a...      15       1
# 3  0.001  <class 'tensorflow.python.keras.optimizer_v2.g...      15       1

# %%
models_comparison_bars(hp_results_df, title='Hyperparams research', interval=10,
                       save_file='results/en_lstm/hyperparams_research.png')

# %%
best_h_num = 3
'Best one: {} with {} run epochs'.format(hp_options[int((best_h_num-1)/3)],
                                         ((best_h_num-1)%3)*5 if (best_h_num-1)%3 != 0 else 15)
# Out:
# "Best one: {'lr': 0.01, 'optim': <class 'tensorflow.python.keras.optimizer_v2.adam.Adam'>, 'epochs': 15, 'layers': 1} with 10 run epochs"

# %%
def get_params_options( batch_size_options = [25, 50, 75, 100, 125],
                        init_options = ['random_uniform', 'random_normal'],
                        rnn_units_options = [64, 128, 192, 255]):

    p_options = []
    for batch_size in batch_size_options:
        for init in init_options:
            for rnn_units in rnn_units_options:
                p_options.append({'batch_size': batch_size,
                                'init': init,
                                'rnn_units': rnn_units})
    return p_options

# %%
def find_parameters(options, shape, 
    save_path = 'results/en_lstm/params_research.csv', epochs_options = [5, 10, 15]):
    if not os.path.exists(save_path):
        p_results = []
        for i, opts in enumerate(p_options):
            print('\nResearching for {}/{} | Hyperparams: {}\n'.format(i+1, len(p_options), opts))

            p_model = LSTMModel(nb_words, embed_dim, embedding_matrix, max_seq_len, **opts)
            p_model.compile()
            p_history = p_model.fit(word_seq_train, y_train, word_seq_test, y_test)

            p_results.append({'acc': np.mean(p_history.history['categorical_accuracy']),
                            'val_acc': np.mean(p_history.history['val_categorical_accuracy']),
                            'loss': np.mean(p_history.history['val_loss']),
                            'f1s0': np.mean(p_model.mc.val_f1s0),
                            'f1s1': np.mean(p_model.mc.val_f1s1)})

        p_results_df = pd.DataFrame(p_results)
        p_results_df.to_csv(save_path)
    else:
        p_results_df = pd.read_csv(save_path, index_col=0)
    return p_results_df

# %%
p_options = get_params_options()
p_results_df = find_parameters(options = p_options, shape = (12, 300, ))
# Out:
# ccuracy: 0.9132
# Epoch 8/10
# 386/386 [==============================] - 3s 8ms/step - loss: 0.1435 - categorical_accuracy: 0.9462 - val_loss: 0.2845 - val_categorical_accuracy: 0.9086
# Epoch 9/10
# 386/386 [==============================] - 3s 8ms/step - loss: 0.1281 - categorical_accuracy: 0.9502 - val_loss: 0.3375 - val_categorical_accuracy: 0.8737
# Epoch 10/10
# 386/386 [==============================] - 3s 8ms/step - loss: 0.2573 - categorical_accuracy: 0.9078 - val_loss: 0.2541 - val_categorical_accuracy: 0.9130
#
# Researching for 30/40 | Hyperparams: {'batch_size': 100, 'init': 'random_normal', 'rnn_units': 128}
#
# Epoch 1/10
# 386/386 [==============================] - 5s 12ms/step - loss: 0.3652 - categorical_accuracy: 0.8548 - val_loss: 0.2415 - val_categorical_accuracy: 0.9163
# Epoch 2/10
# 386/386 [==============================] - 4s 10ms/step - loss: 0.2332 - categorical_accuracy: 0.9195 - val_loss: 0.2317 - val_categorical_accuracy: 0.9207
# Epoch 3/10
# 386/386 [==============================] - 4s 10ms/step - loss: 0.2269 - categorical_accuracy: 0.9185 - val_loss: 0.2299 - val_categorical_accuracy: 0.9183
# Epoch 4/10
# 386/386 [==============================] - 4s 10ms/step - loss: 0.2067 - categorical_accuracy: 0.9231 - val_loss: 0.2366 - val_categorical_accuracy: 0.9183
# Epoch 5/10
# 386/386 [==============================] - 4s 10ms/step - loss: 0.1913 - categorical_accuracy: 0.9260 - val_loss: 0.2453 - val_categorical_accuracy: 0.9176
# Epoch 6/10
# 386/386 [==============================] - 4s 10ms/step - loss: 0.1734 - categorical_accuracy: 0.9314 - val_loss: 0.2526 - val_categorical_accuracy: 0.9169
# Epoch 7/10
# 386/386 [==============================] - 4s 10ms/step - loss: 0.1495 - categorical_accuracy: 0.9378 - val_loss: 0.2826 - val_categorical_accuracy: 0.9105
# Epoch 8/10
# 386/386 [==============================] - 4s 10ms/step - loss: 0.1139 - categorical_accuracy: 0.9552 - val_loss: 0.3441 - val_categorical_accuracy: 0.9052
# Epoch 9/10
# 386/386 [==============================] - 4s 10ms/step - loss: 0.0813 - categorical_accuracy: 0.9695 - val_loss: 0.3873 - val_categorical_accuracy: 0.8989
# Epoch 10/10
# 386/386 [==============================] - 4s 10ms/step - loss: 0.0648 - categorical_accuracy: 0.9773 - val_loss: 0.4386 - val_categorical_accuracy: 0.9035
#
# Researching for 31/40 | Hyperparams: {'batch_size': 100, 'init': 'random_normal', 'rnn_units': 192}
#
# Epoch 1/10
# 386/386 [==============================] - 6s 13ms/step - loss: 0.4123 - categorical_accuracy: 0.8339 - val_loss: 0.2507 - val_categorical_accuracy: 0.9157
# Epoch 2/10
# 386/386 [==============================] - 5s 12ms/step - loss: 0.4770 - categorical_accuracy: 0.7612 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 3/10
# 386/386 [==============================] - 4s 11ms/step - loss: 0.6561 - categorical_accuracy: 0.6355 - val_loss: 0.6537 - val_categorical_accuracy: 0.6398
# Epoch 4/10
# 386/386 [==============================] - 4s 12ms/step - loss: 0.6513 - categorical_accuracy: 0.6430 - val_loss: 0.6537 - val_categorical_accuracy: 0.6398
# Epoch 5/10
# 386/386 [==============================] - 4s 11ms/step - loss: 0.6522 - categorical_accuracy: 0.6416 - val_loss: 0.6532 - val_categorical_accuracy: 0.6398
# Epoch 6/10
# 386/386 [==============================] - 4s 11ms/step - loss: 0.6529 - categorical_accuracy: 0.6406 - val_loss: 0.6532 - val_categorical_accuracy: 0.6398
# Epoch 7/10
# 386/386 [==============================] - 4s 12ms/step - loss: 0.6256 - categorical_accuracy: 0.6614 - val_loss: 0.2456 - val_categorical_accuracy: 0.9144
# Epoch 8/10
# 386/386 [==============================] - 4s 12ms/step - loss: 0.2472 - categorical_accuracy: 0.9160 - val_loss: 0.2305 - val_categorical_accuracy: 0.9201
# Epoch 9/10
# 386/386 [==============================] - 4s 12ms/step - loss: 0.2276 - categorical_accuracy: 0.9218 - val_loss: 0.2252 - val_categorical_accuracy: 0.9207
# Epoch 10/10
# 386/386 [==============================] - 5s 12ms/step - loss: 0.2163 - categorical_accuracy: 0.9234 - val_loss: 0.2335 - val_categorical_accuracy: 0.9195
#
# Researching for 32/40 | Hyperparams: {'batch_size': 100, 'init': 'random_normal', 'rnn_units': 255}
#
# Epoch 1/10
# 386/386 [==============================] - 7s 16ms/step - loss: 0.6531 - categorical_accuracy: 0.6284 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 2/10
# 386/386 [==============================] - 6s 15ms/step - loss: 0.6535 - categorical_accuracy: 0.6401 - val_loss: 0.6537 - val_categorical_accuracy: 0.6398
# Epoch 3/10
# 386/386 [==============================] - 6s 15ms/step - loss: 0.6557 - categorical_accuracy: 0.6363 - val_loss: 0.6537 - val_categorical_accuracy: 0.6398
# Epoch 4/10
# 386/386 [==============================] - 6s 15ms/step - loss: 0.6549 - categorical_accuracy: 0.6374 - val_loss: 0.6538 - val_categorical_accuracy: 0.6398
# Epoch 5/10
# 386/386 [==============================] - 6s 15ms/step - loss: 0.6525 - categorical_accuracy: 0.6420 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 6/10
# 386/386 [==============================] - 6s 15ms/step - loss: 0.6525 - categorical_accuracy: 0.6419 - val_loss: 0.6540 - val_categorical_accuracy: 0.6398
# Epoch 7/10
# 386/386 [==============================] - 6s 15ms/step - loss: 0.6532 - categorical_accuracy: 0.6407 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 8/10
# 386/386 [==============================] - 6s 15ms/step - loss: 0.6538 - categorical_accuracy: 0.6394 - val_loss: 0.6538 - val_categorical_accuracy: 0.6398
# Epoch 9/10
# 386/386 [==============================] - 6s 16ms/step - loss: 0.6542 - categorical_accuracy: 0.6390 - val_loss: 0.6543 - val_categorical_accuracy: 0.6398
# Epoch 10/10
# 386/386 [==============================] - 6s 15ms/step - loss: 0.6518 - categorical_accuracy: 0.6434 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
#
# Researching for 33/40 | Hyperparams: {'batch_size': 125, 'init': 'random_uniform', 'rnn_units': 64}
#
# Epoch 1/10
# 309/309 [==============================] - 4s 9ms/step - loss: 0.3706 - categorical_accuracy: 0.8418 - val_loss: 0.2462 - val_categorical_accuracy: 0.9148
# Epoch 2/10
# 309/309 [==============================] - 3s 8ms/step - loss: 0.2336 - categorical_accuracy: 0.9183 - val_loss: 0.2304 - val_categorical_accuracy: 0.9199
# Epoch 3/10
# 309/309 [==============================] - 3s 8ms/step - loss: 0.2320 - categorical_accuracy: 0.9168 - val_loss: 0.2263 - val_categorical_accuracy: 0.9204
# Epoch 4/10
# 309/309 [==============================] - 3s 8ms/step - loss: 0.2114 - categorical_accuracy: 0.9244 - val_loss: 0.2290 - val_categorical_accuracy: 0.9186
# Epoch 5/10
# 309/309 [==============================] - 3s 8ms/step - loss: 0.2055 - categorical_accuracy: 0.9252 - val_loss: 0.2346 - val_categorical_accuracy: 0.9176
# Epoch 6/10
# 309/309 [==============================] - 3s 9ms/step - loss: 0.1891 - categorical_accuracy: 0.9310 - val_loss: 0.2377 - val_categorical_accuracy: 0.9159
# Epoch 7/10
# 309/309 [==============================] - 3s 9ms/step - loss: 0.1710 - categorical_accuracy: 0.9373 - val_loss: 0.2602 - val_categorical_accuracy: 0.9143
# Epoch 8/10
# 309/309 [==============================] - 3s 9ms/step - loss: 0.1546 - categorical_accuracy: 0.9428 - val_loss: 0.2702 - val_categorical_accuracy: 0.9128
# Epoch 9/10
# 309/309 [==============================] - 3s 8ms/step - loss: 0.1361 - categorical_accuracy: 0.9483 - val_loss: 0.2825 - val_categorical_accuracy: 0.9100
# Epoch 10/10
# 309/309 [==============================] - 3s 8ms/step - loss: 0.1181 - categorical_accuracy: 0.9557 - val_loss: 0.3026 - val_categorical_accuracy: 0.9010
#
# Researching for 34/40 | Hyperparams: {'batch_size': 125, 'init': 'random_uniform', 'rnn_units': 128}
#
# Epoch 1/10
# 309/309 [==============================] - 5s 12ms/step - loss: 0.3872 - categorical_accuracy: 0.8320 - val_loss: 0.2423 - val_categorical_accuracy: 0.9159
# Epoch 2/10
# 309/309 [==============================] - 4s 11ms/step - loss: 0.2558 - categorical_accuracy: 0.9107 - val_loss: 0.3142 - val_categorical_accuracy: 0.9025
# Epoch 3/10
# 309/309 [==============================] - 3s 11ms/step - loss: 0.2617 - categorical_accuracy: 0.9127 - val_loss: 0.2346 - val_categorical_accuracy: 0.9180
# Epoch 4/10
# 309/309 [==============================] - 3s 11ms/step - loss: 0.2274 - categorical_accuracy: 0.9206 - val_loss: 0.2300 - val_categorical_accuracy: 0.9180
# Epoch 5/10
# 309/309 [==============================] - 3s 11ms/step - loss: 0.2138 - categorical_accuracy: 0.9208 - val_loss: 0.2356 - val_categorical_accuracy: 0.9155
# Epoch 6/10
# 309/309 [==============================] - 4s 12ms/step - loss: 0.2218 - categorical_accuracy: 0.9187 - val_loss: 0.2305 - val_categorical_accuracy: 0.9184
# Epoch 7/10
# 309/309 [==============================] - 3s 11ms/step - loss: 0.1929 - categorical_accuracy: 0.9248 - val_loss: 0.2453 - val_categorical_accuracy: 0.9174
# Epoch 8/10
# 309/309 [==============================] - 4s 11ms/step - loss: 0.1812 - categorical_accuracy: 0.9283 - val_loss: 0.2510 - val_categorical_accuracy: 0.9154
# Epoch 9/10
# 309/309 [==============================] - 4s 11ms/step - loss: 0.1553 - categorical_accuracy: 0.9381 - val_loss: 0.2651 - val_categorical_accuracy: 0.9097
# Epoch 10/10
# 309/309 [==============================] - 3s 11ms/step - loss: 0.1276 - categorical_accuracy: 0.9511 - val_loss: 0.3054 - val_categorical_accuracy: 0.9057
#
# Researching for 35/40 | Hyperparams: {'batch_size': 125, 'init': 'random_uniform', 'rnn_units': 192}
#
# Epoch 1/10
# 309/309 [==============================] - 5s 15ms/step - loss: 0.4664 - categorical_accuracy: 0.7783 - val_loss: 0.2482 - val_categorical_accuracy: 0.9152
# Epoch 2/10
# 309/309 [==============================] - 4s 14ms/step - loss: 0.2361 - categorical_accuracy: 0.9200 - val_loss: 0.2301 - val_categorical_accuracy: 0.9164
# Epoch 3/10
# 309/309 [==============================] - 4s 13ms/step - loss: 0.2378 - categorical_accuracy: 0.9196 - val_loss: 0.2404 - val_categorical_accuracy: 0.9180
# Epoch 4/10
# 309/309 [==============================] - 4s 14ms/step - loss: 0.2196 - categorical_accuracy: 0.9234 - val_loss: 0.2343 - val_categorical_accuracy: 0.9193
# Epoch 5/10
# 309/309 [==============================] - 4s 14ms/step - loss: 0.2170 - categorical_accuracy: 0.9226 - val_loss: 0.2349 - val_categorical_accuracy: 0.9181
# Epoch 6/10
# 309/309 [==============================] - 4s 14ms/step - loss: 0.1905 - categorical_accuracy: 0.9300 - val_loss: 0.2409 - val_categorical_accuracy: 0.9151
# Epoch 7/10
# 309/309 [==============================] - 4s 14ms/step - loss: 0.1771 - categorical_accuracy: 0.9364 - val_loss: 0.2465 - val_categorical_accuracy: 0.9160
# Epoch 8/10
# 309/309 [==============================] - 4s 13ms/step - loss: 0.1593 - categorical_accuracy: 0.9410 - val_loss: 0.2698 - val_categorical_accuracy: 0.9099
# Epoch 9/10
# 309/309 [==============================] - 4s 14ms/step - loss: 0.1342 - categorical_accuracy: 0.9502 - val_loss: 0.3047 - val_categorical_accuracy: 0.9028
# Epoch 10/10
# 309/309 [==============================] - 4s 14ms/step - loss: 0.1144 - categorical_accuracy: 0.9589 - val_loss: 0.3412 - val_categorical_accuracy: 0.9032
#
# Researching for 36/40 | Hyperparams: {'batch_size': 125, 'init': 'random_uniform', 'rnn_units': 255}
#
# Epoch 1/10
# 309/309 [==============================] - 7s 19ms/step - loss: 0.5293 - categorical_accuracy: 0.7456 - val_loss: 0.2624 - val_categorical_accuracy: 0.9093
# Epoch 2/10
# 309/309 [==============================] - 6s 18ms/step - loss: 0.2461 - categorical_accuracy: 0.9163 - val_loss: 0.2447 - val_categorical_accuracy: 0.9148
# Epoch 3/10
# 309/309 [==============================] - 6s 18ms/step - loss: 0.2327 - categorical_accuracy: 0.9193 - val_loss: 0.2325 - val_categorical_accuracy: 0.9185
# Epoch 4/10
# 309/309 [==============================] - 6s 18ms/step - loss: 0.2203 - categorical_accuracy: 0.9234 - val_loss: 0.2303 - val_categorical_accuracy: 0.9206
# Epoch 5/10
# 309/309 [==============================] - 6s 18ms/step - loss: 0.2178 - categorical_accuracy: 0.9240 - val_loss: 0.4234 - val_categorical_accuracy: 0.8287
# Epoch 6/10
# 309/309 [==============================] - 6s 19ms/step - loss: 0.3009 - categorical_accuracy: 0.8941 - val_loss: 0.2428 - val_categorical_accuracy: 0.9172
# Epoch 7/10
# 309/309 [==============================] - 6s 18ms/step - loss: 0.2393 - categorical_accuracy: 0.9187 - val_loss: 0.2345 - val_categorical_accuracy: 0.9180
# Epoch 8/10
# 309/309 [==============================] - 6s 18ms/step - loss: 0.2377 - categorical_accuracy: 0.9187 - val_loss: 0.2317 - val_categorical_accuracy: 0.9170
# Epoch 9/10
# 309/309 [==============================] - 6s 18ms/step - loss: 0.2331 - categorical_accuracy: 0.9183 - val_loss: 0.2457 - val_categorical_accuracy: 0.9126
# Epoch 10/10
# 309/309 [==============================] - 6s 18ms/step - loss: 0.2257 - categorical_accuracy: 0.9196 - val_loss: 0.2411 - val_categorical_accuracy: 0.9160
#
# Researching for 37/40 | Hyperparams: {'batch_size': 125, 'init': 'random_normal', 'rnn_units': 64}
#
# Epoch 1/10
# 309/309 [==============================] - 4s 9ms/step - loss: 0.3772 - categorical_accuracy: 0.8363 - val_loss: 0.2472 - val_categorical_accuracy: 0.9170
# Epoch 2/10
# 309/309 [==============================] - 3s 9ms/step - loss: 0.2426 - categorical_accuracy: 0.9177 - val_loss: 0.2356 - val_categorical_accuracy: 0.9199
# Epoch 3/10
# 309/309 [==============================] - 3s 8ms/step - loss: 0.2223 - categorical_accuracy: 0.9213 - val_loss: 0.2284 - val_categorical_accuracy: 0.9209
# Epoch 4/10
# 309/309 [==============================] - 3s 8ms/step - loss: 0.2146 - categorical_accuracy: 0.9216 - val_loss: 0.2297 - val_categorical_accuracy: 0.9201
# Epoch 5/10
# 309/309 [==============================] - 3s 8ms/step - loss: 0.2027 - categorical_accuracy: 0.9240 - val_loss: 0.2313 - val_categorical_accuracy: 0.9193
# Epoch 6/10
# 309/309 [==============================] - 3s 9ms/step - loss: 0.1830 - categorical_accuracy: 0.9288 - val_loss: 0.2485 - val_categorical_accuracy: 0.9158
# Epoch 7/10
# 309/309 [==============================] - 3s 8ms/step - loss: 0.1617 - categorical_accuracy: 0.9360 - val_loss: 0.2492 - val_categorical_accuracy: 0.9112
# Epoch 8/10
# 309/309 [==============================] - 3s 8ms/step - loss: 0.1480 - categorical_accuracy: 0.9413 - val_loss: 0.2891 - val_categorical_accuracy: 0.9002
# Epoch 9/10
# 309/309 [==============================] - 3s 8ms/step - loss: 0.1200 - categorical_accuracy: 0.9541 - val_loss: 0.3448 - val_categorical_accuracy: 0.9103
# Epoch 10/10
# 309/309 [==============================] - 3s 8ms/step - loss: 0.0952 - categorical_accuracy: 0.9638 - val_loss: 0.3919 - val_categorical_accuracy: 0.9009
#
# Researching for 38/40 | Hyperparams: {'batch_size': 125, 'init': 'random_normal', 'rnn_units': 128}
#
# Epoch 1/10
# 309/309 [==============================] - 5s 12ms/step - loss: 0.4165 - categorical_accuracy: 0.8128 - val_loss: 0.2426 - val_categorical_accuracy: 0.9170
# Epoch 2/10
# 309/309 [==============================] - 4s 11ms/step - loss: 0.2390 - categorical_accuracy: 0.9179 - val_loss: 0.2371 - val_categorical_accuracy: 0.9195
# Epoch 3/10
# 309/309 [==============================] - 3s 11ms/step - loss: 0.2241 - categorical_accuracy: 0.9214 - val_loss: 0.2309 - val_categorical_accuracy: 0.9199
# Epoch 4/10
# 309/309 [==============================] - 3s 11ms/step - loss: 0.2149 - categorical_accuracy: 0.9224 - val_loss: 0.2323 - val_categorical_accuracy: 0.9190
# Epoch 5/10
# 309/309 [==============================] - 4s 12ms/step - loss: 0.1976 - categorical_accuracy: 0.9261 - val_loss: 0.2415 - val_categorical_accuracy: 0.9170
# Epoch 6/10
# 309/309 [==============================] - 4s 11ms/step - loss: 0.1761 - categorical_accuracy: 0.9322 - val_loss: 0.2623 - val_categorical_accuracy: 0.9140
# Epoch 7/10
# 309/309 [==============================] - 4s 11ms/step - loss: 0.1502 - categorical_accuracy: 0.9413 - val_loss: 0.2881 - val_categorical_accuracy: 0.9076
# Epoch 8/10
# 309/309 [==============================] - 4s 11ms/step - loss: 0.1171 - categorical_accuracy: 0.9557 - val_loss: 0.3178 - val_categorical_accuracy: 0.9048
# Epoch 9/10
# 309/309 [==============================] - 4s 11ms/step - loss: 0.0918 - categorical_accuracy: 0.9658 - val_loss: 0.3728 - val_categorical_accuracy: 0.9026
# Epoch 10/10
# 309/309 [==============================] - 4s 11ms/step - loss: 0.0800 - categorical_accuracy: 0.9724 - val_loss: 0.4262 - val_categorical_accuracy: 0.9007
#
# Researching for 39/40 | Hyperparams: {'batch_size': 125, 'init': 'random_normal', 'rnn_units': 192}
#
# Epoch 1/10
# 309/309 [==============================] - 5s 15ms/step - loss: 0.3902 - categorical_accuracy: 0.8350 - val_loss: 0.2375 - val_categorical_accuracy: 0.9175
# Epoch 2/10
# 309/309 [==============================] - 4s 14ms/step - loss: 0.2442 - categorical_accuracy: 0.9156 - val_loss: 0.2292 - val_categorical_accuracy: 0.9180
# Epoch 3/10
# 309/309 [==============================] - 4s 14ms/step - loss: 0.2321 - categorical_accuracy: 0.9173 - val_loss: 0.2317 - val_categorical_accuracy: 0.9191
# Epoch 4/10
# 309/309 [==============================] - 4s 14ms/step - loss: 0.2503 - categorical_accuracy: 0.9085 - val_loss: 0.2369 - val_categorical_accuracy: 0.9181
# Epoch 5/10
# 309/309 [==============================] - 4s 14ms/step - loss: 0.2362 - categorical_accuracy: 0.9167 - val_loss: 0.2315 - val_categorical_accuracy: 0.9177
# Epoch 6/10
# 309/309 [==============================] - 4s 14ms/step - loss: 0.2263 - categorical_accuracy: 0.9202 - val_loss: 0.2316 - val_categorical_accuracy: 0.9171
# Epoch 7/10
# 309/309 [==============================] - 4s 14ms/step - loss: 0.2127 - categorical_accuracy: 0.9228 - val_loss: 0.2294 - val_categorical_accuracy: 0.9174
# Epoch 8/10
# 309/309 [==============================] - 4s 14ms/step - loss: 0.1987 - categorical_accuracy: 0.9296 - val_loss: 0.2409 - val_categorical_accuracy: 0.9137
# Epoch 9/10
# 309/309 [==============================] - 4s 14ms/step - loss: 0.1917 - categorical_accuracy: 0.9282 - val_loss: 0.2504 - val_categorical_accuracy: 0.9126
# Epoch 10/10
# 309/309 [==============================] - 4s 14ms/step - loss: 0.1723 - categorical_accuracy: 0.9369 - val_loss: 0.2474 - val_categorical_accuracy: 0.9141
#
# Researching for 40/40 | Hyperparams: {'batch_size': 125, 'init': 'random_normal', 'rnn_units': 255}
#
# Epoch 1/10
# 309/309 [==============================] - 7s 19ms/step - loss: 0.4863 - categorical_accuracy: 0.7823 - val_loss: 0.2659 - val_categorical_accuracy: 0.9111
# Epoch 2/10
# 309/309 [==============================] - 6s 19ms/step - loss: 0.2508 - categorical_accuracy: 0.9133 - val_loss: 0.2389 - val_categorical_accuracy: 0.9164
# Epoch 3/10
# 309/309 [==============================] - 6s 18ms/step - loss: 0.2310 - categorical_accuracy: 0.9207 - val_loss: 0.2378 - val_categorical_accuracy: 0.9153
# Epoch 4/10
# 309/309 [==============================] - 6s 18ms/step - loss: 0.2210 - categorical_accuracy: 0.9208 - val_loss: 0.2333 - val_categorical_accuracy: 0.9184
# Epoch 5/10
# 309/309 [==============================] - 6s 18ms/step - loss: 0.2140 - categorical_accuracy: 0.9217 - val_loss: 0.2322 - val_categorical_accuracy: 0.9176
# Epoch 6/10
# 309/309 [==============================] - 6s 18ms/step - loss: 0.1942 - categorical_accuracy: 0.9268 - val_loss: 0.2361 - val_categorical_accuracy: 0.9179
# Epoch 7/10
# 309/309 [==============================] - 6s 18ms/step - loss: 0.1885 - categorical_accuracy: 0.9280 - val_loss: 0.2479 - val_categorical_accuracy: 0.9141
# Epoch 8/10
# 309/309 [==============================] - 6s 18ms/step - loss: 0.1649 - categorical_accuracy: 0.9348 - val_loss: 0.2895 - val_categorical_accuracy: 0.9163
# Epoch 9/10
# 309/309 [==============================] - 6s 18ms/step - loss: 0.1383 - categorical_accuracy: 0.9440 - val_loss: 0.3080 - val_categorical_accuracy: 0.9080
# Epoch 10/10
# 309/309 [==============================] - 6s 18ms/step - loss: 0.1158 - categorical_accuracy: 0.9532 - val_loss: 0.3183 - val_categorical_accuracy: 0.9004

# %%
p_results_df.head()
# Out:
#         acc   val_acc      loss      f1s0      f1s1
# 0  0.930942  0.912890  0.267986  0.878417  0.932124
# 1  0.936191  0.910314  0.296317  0.874119  0.930330
# 2  0.641672  0.639782  0.653819  0.000000  0.780326
# 3  0.639910  0.639782  0.653877  0.000000  0.780326
# 4  0.939060  0.911765  0.301142  0.876201  0.931438

# %%
models_comparison_bars(p_results_df, title='Params research', save_file='results/en_lstm/params_research.png')

# %%
best_num = 26
'Best one: {}'.format(p_options[best_num-1])
# Out:
# "Best one: {'batch_size': 100, 'init': 'random_uniform', 'rnn_units': 128}"

# %%
model = LSTMModel(nb_words, embed_dim, embedding_matrix, max_seq_len)
model.summary()
# Out:
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_40 (Embedding)     (None, 50, 300)           12608100
# _________________________________________________________________
# wt_recurrent (LSTM)          (None, 64)                93440
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# predictions (Dense)          (None, 2)                 130
# =================================================================
# Total params: 12,705,830
# Trainable params: 97,730
# Non-trainable params: 12,608,100
# _________________________________________________________________

# %%
model.compile()
history = model.fit(word_seq_train, y_train, word_seq_test, y_test)
model.save('models/en_lstm.model')
# Out:
# Epoch 1/10
# 772/772 [==============================] - 6s 6ms/step - loss: 0.3373 - categorical_accuracy: 0.8593 - val_loss: 0.2413 - val_categorical_accuracy: 0.9198
# Epoch 2/10
# 772/772 [==============================] - 5s 6ms/step - loss: 0.2419 - categorical_accuracy: 0.9187 - val_loss: 0.2307 - val_categorical_accuracy: 0.9191
# Epoch 3/10
# 772/772 [==============================] - 5s 6ms/step - loss: 0.2305 - categorical_accuracy: 0.9187 - val_loss: 0.2258 - val_categorical_accuracy: 0.9206
# Epoch 4/10
# 772/772 [==============================] - 5s 6ms/step - loss: 0.2211 - categorical_accuracy: 0.9201 - val_loss: 0.2253 - val_categorical_accuracy: 0.9207
# Epoch 5/10
# 772/772 [==============================] - 5s 6ms/step - loss: 0.2091 - categorical_accuracy: 0.9229 - val_loss: 0.2284 - val_categorical_accuracy: 0.9196
# Epoch 6/10
# 772/772 [==============================] - 5s 6ms/step - loss: 0.1900 - categorical_accuracy: 0.9318 - val_loss: 0.2443 - val_categorical_accuracy: 0.9167
# Epoch 7/10
# 772/772 [==============================] - 5s 6ms/step - loss: 0.1670 - categorical_accuracy: 0.9362 - val_loss: 0.2643 - val_categorical_accuracy: 0.9109
# Epoch 8/10
# 772/772 [==============================] - 5s 6ms/step - loss: 0.1418 - categorical_accuracy: 0.9470 - val_loss: 0.2979 - val_categorical_accuracy: 0.9104
# Epoch 9/10
# 772/772 [==============================] - 5s 6ms/step - loss: 0.1087 - categorical_accuracy: 0.9589 - val_loss: 0.3173 - val_categorical_accuracy: 0.9066
# Epoch 10/10
# 772/772 [==============================] - 5s 6ms/step - loss: 0.0972 - categorical_accuracy: 0.9636 - val_loss: 0.3676 - val_categorical_accuracy: 0.9071
# WARNING:absl:Found untraced functions such as lstm_cell_40_layer_call_and_return_conditional_losses, lstm_cell_40_layer_call_fn, lstm_cell_40_layer_call_fn, lstm_cell_40_layer_call_and_return_conditional_losses, lstm_cell_40_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_40_layer_call_and_return_conditional_losses, lstm_cell_40_layer_call_fn, lstm_cell_40_layer_call_fn, lstm_cell_40_layer_call_and_return_conditional_losses, lstm_cell_40_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/en_lstm.model/assets
# INFO:tensorflow:Assets written to: models/en_lstm.model/assets

# %%
predictions = model.predict(word_seq_test)
y_true = tf.argmax(y_test, axis=1)
y_pred = tf.argmax(predictions, axis=1)

conf_mat = tf.math.confusion_matrix(labels=y_true, predictions=y_pred, num_classes=2).numpy()
acc = float(np.sum(np.diag(conf_mat)))/np.sum(np.sum(conf_mat))
f1s0 = 2*float(conf_mat[0][0])/(2*float(conf_mat[0][0]) + conf_mat[0][1] + conf_mat[1][0])
f1s1 = 2*float(conf_mat[1][1])/(2*float(conf_mat[1][1]) + conf_mat[1][0] + conf_mat[0][1])

# %%
if not os.path.exists('results/en_lstm/short_results.csv'):
    with open('results/en_lstm/short_results.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(['Accuracy', 'F1 score (0)', 'F1 score (1)'])
        writer.writerow([acc, f1s0, f1s1])
else:
    with open('results/en_lstm/short_results.csv', 'a') as f:
        writer = csv.writer(f)
        writer.writerow([acc, f1s0, f1s1])

# %%
# save model history, confusion matrix and accuracy
model_results = {'acc': history.history['categorical_accuracy'],
                 'val_acc': history.history['val_categorical_accuracy'],
                 'loss': history.history['loss'],
                 'val_loss': history.history['val_loss'],
                 'f1s0': model.mc.val_f1s0,
                 'f1s1': model.mc.val_f1s1,
                 'conf_mat': conf_mat,
                 'main_acc': acc}
with open('results/en_lstm/results.pkl', 'wb') as f:
    pickle.dump(model_results, f)

# %%
def plots(y_ss, y_labels, colors, title, file_name=None):
    x_s = range(1, len(y_ss[0])+1)
    for y_s, y_label, color in zip(y_ss, y_labels, colors):
        plt.plot(x_s, y_s, color, label=y_label)
    plt.xlabel('Epoch')
    plt.ylabel('Metrics')
    tick_marks = np.arange(1, len(x_s) + 1)
    plt.xticks(tick_marks, x_s)
    plt.title(title)
    
    plt.legend(loc='best', frameon=False)
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

def twinx_plot(y11_s, y12_s, y21_s, y22_s, x_label, y1_label,y2_label, title,
               styles=['r-', 'r--', 'b-', 'b--'], colors=['r', 'b'], file_name=None):
    fig, ax1 = plt.subplots()
    
    ax1.set_xlabel(x_label)
    ax1.set_xticks(range(1, len(y11_s)+1))
    
    ax1.set_ylabel(y1_label, color=colors[0])
    ax1.plot(range(1, len(y11_s)+1), y11_s, styles[0], label='train acc.')
    ax1.plot(range(1, len(y12_s)+1), y12_s, styles[1], label='valid. acc.')
    ax1.tick_params(axis='y', labelcolor=colors[0])
    
    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
    
    ax2.set_ylabel(y2_label, color=colors[1])  # we already handled the x-label with ax1
    ax2.plot(range(1, len(y21_s)+1), y21_s, styles[2], label='train loss')
    ax2.plot(range(1, len(y22_s)+1), y22_s, styles[3], label='valid. loss')
    ax2.tick_params(axis='y', labelcolor=colors[1])
    
    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    fig.legend(loc='right', bbox_to_anchor=(0.85, 0.5))
    plt.title(title)
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

def confusion_matrix_plot(conf_mat, cls, x_label, y_label, title, file_name=None):
    plt.imshow(conf_mat, interpolation='nearest', cmap=plt.cm.Wistia)
    plt.title(title)
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    tick_marks = np.arange(len(cls))
    plt.grid(False)
    plt.xticks(tick_marks, cls, rotation=45)
    plt.yticks(tick_marks, cls)
    
    for i in range(len(cls)):
        for j in range(len(cls)):
            plt.text(j - 0.2, i, str(conf_mat[i][j]), fontsize=16)
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

def class_distribution_hist(y_true, y_pred, cls, x_label, y_label, title, file_name=None):
    pd.Series([y_true, y_pred]).hist()
    plt.title(title)
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    tick_marks = np.arange(len(cls))
    plt.xticks(tick_marks, cls)
    plt.legend(labels=['Real', 'Predicted'], loc='best')
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

# %%
classes = ['hate speech', 'no hate']

# %%
plots([history.history['categorical_accuracy'],
       history.history['val_categorical_accuracy'],
       model.mc.val_f1s0,
       model.mc.val_f1s1],
      ['training acc.', 'validation acc.', 'no-hate f1 score', 'hate-speech f1 score'],
      ['-r', '--r', 'b', 'm'],
      title='Training progress', file_name='results/en_lstm/train_progress.png')

# %%
twinx_plot(history.history['categorical_accuracy'], history.history['val_categorical_accuracy'],
           history.history['loss'], history.history['val_loss'],
          x_label='Epoch', y1_label='Accuracy', y2_label='Loss', title='Accuracy & loss / epoch',
          file_name='results/en_lstm/acc_loss.png')

# %%
confusion_matrix_plot(conf_mat, cls=classes,
                      x_label='Real', y_label='Predicted',
                      title='Accuracy: {}'.format(round(acc, 2)),
                      file_name='results/en_lstm/cm.png')

# %%
class_distribution_hist(y_true, y_pred, cls=classes,
                        x_label='Classes', y_label='Cardinality', title='Real and pred. classes cards.',
                        file_name='results/en_lstm/cards.png')

# %%
with open('hsd/Reddit/perfect_data.pkl', 'rb') as f:
    texts, _ = pickle.load(f)
texts = texts[int(0.7*len(texts)):]

indices = [6, 10, 19, 26, 27, 28, 29, 164]
test_cases = []
for i, (t, p, l) in enumerate(zip(texts, y_pred, y_true)):
    if i in indices:
        test_cases.append({'Text': t, 'Prediction': p.numpy(), 'Label': l.numpy()})

# %%
def test_cases_board(test_cases, title, file_name=None):
    h = 20
    n = len(test_cases)
    fig, axis = plt.subplots(1, 1, figsize=(16., n*3.2))
    axis.axis('off')
    axis.set_xlim([0, 100])
    axis.set_ylim([0, n*h])
    axis.plot([0, 100], [0, 0], color='k')
    axis.plot([0, 0], [0, n*h], color='k')
    axis.plot([100, 100], [0, n*h], color='k')
    
    for i in range(n):
        axis.annotate('Tweet text:', xy=(4, 16 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        text = u'{}'.format(test_cases[i]['Text'].replace('\n', ''))
        text = '\n'.join([text[j:j+int(len(text)/3)] for j in range(0, len(text), int(len(text)/3))])
        axis.annotate(text, xy=(4, 7 + i*h), xycoords='data', size=15)
        
        axis.annotate('Prediction:', xy=(4, 4 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        pred = 'no hate' if test_cases[i]['Prediction'] == 0 else 'hate speech'
        pred_color = 'b' if pred == 'no hate' else 'm'
        axis.annotate(pred, xy=(15, 4 + i*h), xycoords='data', size=15, color=pred_color)
        
        axis.annotate('Label:', xy=(27, 4 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        label = 'no hate' if test_cases[i]['Label'] == 0 else 'hate speech'
        label_color = 'b' if label == 'no hate' else 'm'
        axis.annotate(label, xy=(34, 4 + i*h), xycoords='data', size=15, color=label_color)
        
        axis.annotate('Result:', xy=(50, 4 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        reason = 'OK' if pred == label else '1-st type error' if pred == 'no hate' else '2-nd type error'
        reason_color = 'g' if reason == 'OK' else 'r'
        axis.annotate(reason, xy=(57, 4 + i*h), xycoords='data', size=15, color=reason_color)
        
        axis.plot([0, 100], [20 + i*h, 20 + i*h], color='k')
    
    
    plt.title(title)
    if file_name:
        plt.savefig(file_name)
    plt.show()

# %%
test_cases_board(test_cases, title='Tweets summary', file_name='results/en_lstm/tweets_summary.png')
