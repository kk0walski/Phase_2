# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import pickle

from sklearn.metrics import confusion_matrix, f1_score, precision_score, roc_auc_score

import keras
from keras import optimizers
from keras import backend as K
from keras import regularizers
from keras.models import Sequential
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.layers import Input, Embedding, Dense, SimpleRNN, LSTM, Concatenate
from keras.utils import plot_model
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

from pymagnitude import *
from tqdm import tqdm
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer 
import os, re, csv, math, codecs

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %%
train_df = pd.read_csv('hsd/Reddit/train.csv', sep=',', header=0, index_col=0)
test_df = pd.read_csv('hsd/Reddit/test.csv', sep=',', header=0, index_col=0)
validate_df = pd.read_csv('hsd/Reddit/validate_reddit.csv', sep=',', header=0, index_col=0)
test_df = test_df.fillna('_NA_')

print("num train: ", train_df.shape[0])
print("num test: ", test_df.shape[0])

label_names = ['class']
y_train = list(map(lambda number: 1 if number[0] == 2 else 0, train_df[label_names].values.tolist()))
y_train = to_categorical(y_train)

y_test = list(map(lambda number: 1 if number[0] == 2 else 0, test_df[label_names].values.tolist()))
y_test = to_categorical(y_test)

#visualize word distribution
train_df['doc_len'] = train_df['lemmatized_text'].apply( lambda words: len(str(words).split()) )
max_seq_len = 50
sns.distplot(train_df['doc_len'], hist=True, kde=True, color='b', label='doc len')
plt.axvline(x=max_seq_len, color='k', linestyle='--', label='max len')
plt.title('comment length'); plt.legend()
plt.show()
# Out:
# num train:  38592
# num test:  16540

# %%
MAX_NB_WORDS = 100000

raw_docs_train = train_df['lemmatized_text'].apply(lambda words: str(words)).tolist()
raw_docs_test = test_df['lemmatized_text'].apply(lambda words: str(words)).tolist() 
raw_docs_validate = validate_df['lemmatized_text'].apply(lambda words: str(words)).tolist() 
num_classes = len(label_names)

print("tokenizing input data...")
tokenizer = Tokenizer(num_words=MAX_NB_WORDS, lower=True, char_level=False)
tokenizer.fit_on_texts(raw_docs_train + raw_docs_test + raw_docs_validate)  #leaky
word_seq_train = tokenizer.texts_to_sequences(raw_docs_train)
word_seq_test = tokenizer.texts_to_sequences(raw_docs_test)
word_seq_val = tokenizer.texts_to_sequences(raw_docs_validate)
word_index = tokenizer.word_index
print("dictionary size: ", len(word_index))

#pad sequences
word_seq_train = sequence.pad_sequences(word_seq_train, maxlen=max_seq_len)
word_seq_test = sequence.pad_sequences(word_seq_test, maxlen=max_seq_len)
word_seq_val = sequence.pad_sequences(word_seq_val, maxlen=max_seq_len)
# Out:
# tokenizing input data...
# dictionary size:  41407

# %%
#training params
batch_size = 256 
num_epochs = 20 

#model parameters
CONV_FILTER = (2, 4)
num_filters = 64 
embed_dim = 300 
weight_decay = 1e-4

# hyperparams
LAYERS = 4  # convolutional layers count
LR = 0.01  # learning rate
OPTIM = tf.keras.optimizers.Adam  # optimizer
EPOCHS = 5

# params
BATCH_SIZE = 50  # size of input batch
INIT = 'random_normal'  # trainable param initializer
RNN_UNITS = 64  # recurrent network working units

# %%
#embedding matrix
print('preparing embedding matrix...')
words_not_found = []
nb_words = min(MAX_NB_WORDS, len(word_index)) + 1
embedding_matrix = np.zeros((nb_words, embed_dim))
vecs = Magnitude(MagnitudeUtils.download_model('http://magnitude.plasticity.ai/fasttext/medium/crawl-300d-2M.magnitude'))
for word, i in word_index.items():
    if i >= nb_words:
        continue
    embedding_vector = vecs.query(word)
    if (embedding_vector is not None) and len(embedding_vector) > 0:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
    else:
        words_not_found.append(word)
vecs = None
print('number of null word embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# preparing embedding matrix...
# number of null word embeddings: 1

# %%
class MetricsCallback(Callback):
    def __init__(self):
        super(MetricsCallback, self).__init__()
        self.val_f1s0 = []
        self.val_f1s1 = []
    
    def on_epoch_end(self, epoch, logs={}):
        val_predict = np.asarray(tf.argmax(self.model.predict(word_seq_test), axis=1))
        val_true = np.asarray(tf.argmax(y_test, axis=1))
        c_m = confusion_matrix(val_true, val_predict, labels=[0, 1])
        self.val_f1s0.append(2*float(c_m[0][0])/(2*float(c_m[0][0]) + c_m[0][1] + c_m[1][0]))
        self.val_f1s1.append(2*float(c_m[1][1])/(2*float(c_m[1][1]) + c_m[1][0] + c_m[0][1]))

# %%
class LSTMModel():
    def __init__(self, nb_words, embed_dim, embedding_matrix, max_seq_len, model_type='lstm', name='conv_model', **kwargs):
        self.type = LSTM if model_type == 'lstm' else SimpleRNN
        
        # hyperparams
        self.layers = LAYERS if 'layers' not in kwargs else kwargs['layers']
        self.lr = LR if 'lr' not in kwargs else kwargs['lr']
        self.optim = OPTIM(learning_rate=self.lr) if 'optim' not in kwargs else kwargs['optim'](learning_rate=self.lr)
        self.epochs = EPOCHS if 'epochs' not in kwargs else kwargs['epochs']
        
        # params
        self.batch_size = BATCH_SIZE if 'batch_size' not in kwargs else kwargs['batch_size']
        self.init = INIT if 'init' not in kwargs else kwargs['init']
        self.rnn_units = RNN_UNITS if 'rnn_units' not in kwargs else kwargs['rnn_units']
        
        # layers
        self.model = Sequential()
        self.model.add(Embedding(nb_words, embed_dim,
                    weights=[embedding_matrix], input_length=max_seq_len, trainable=False))
        self.model.add(self.type(units=self.rnn_units, name='wt_recurrent',
                       kernel_initializer=self.init, bias_initializer=self.init))
                    
        self.model.add(Dense(64, activation='relu', name='dense_1',
                    kernel_initializer='random_normal', bias_initializer='random_normal'))
        self.model.add(Dense(2, activation='softmax', name='predictions',
                    kernel_initializer='random_normal', bias_initializer='random_normal'))

        self.name = name
        self.mc = MetricsCallback()
    
    def summary(self):
        return self.model.summary()
    
    def compile(self):
        self.model.compile(optimizer=self.optim,
                           loss=tf.keras.losses.CategoricalCrossentropy(),
                           metrics=[tf.keras.metrics.CategoricalAccuracy()])
    
    def fit(self, X_tr, y_tr, X_ev, y_ev):
        return self.model.fit(X_tr, y_tr, batch_size=self.batch_size, epochs=self.epochs,
                              validation_data=(X_ev, y_ev), callbacks=[self.mc])
    
    def predict(self, X_t):
        return self.model.predict(X_t)
    
    def save(self, file_name):
        self.model.save(file_name)

# %%
def models_comparison_bars(df, title, interval=2, save_file=None):
    fig, axs = plt.subplots(1, 3, figsize=(16, 4))
    
    labels = [i+1 if i%interval == 0 else '' for i in range(len(df))]
    x = range(len(labels))
    acc = df['acc'].values
    f1s0 = df['f1s0'].values
    f1s1 = df['f1s1'].values
    
    max_acc_id = np.argmax(acc)
    max_f1s0_id = np.argmax(f1s0)
    max_f1s1_id = np.argmax(f1s1)
    
    axs[0].bar(x, acc, color='r')
    axs[0].set_xlabel('Model number')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xticks(x)
    axs[0].set_xticklabels(labels)
    axs[0].set_ylim([0, 1])
    axs[0].set_title('Accuracy | max ({}) at: {}'.format(np.round(np.max(acc), 2), max_acc_id+1))
    axs[0].patches[max_acc_id].set_facecolor('g')
    
    axs[1].bar(x, f1s0, color='b')
    axs[1].set_xlabel('Model number')
    axs[1].set_ylabel('F1 score (no hate)')
    axs[1].set_title('F1 score (no hate) | max ({}) at: {}'.format(np.round(np.max(f1s0), 2), max_f1s0_id+1))
    axs[1].set_xticks(x)
    axs[1].set_xticklabels(labels)
    axs[1].set_ylim([0, 1])
    axs[1].patches[max_f1s0_id].set_facecolor('g')
    
    axs[2].bar(x, f1s1, color='m')
    axs[2].set_xlabel('Model number')
    axs[2].set_ylabel('F1 score (hate speech)')
    axs[2].set_title('F1 score (hate speech) | max ({}) at: {}'.format(np.round(np.max(f1s1), 2),
                                                                       max_f1s1_id+1))
    axs[2].set_xticks(x)
    axs[2].set_xticklabels(labels)
    axs[2].set_ylim([0, 1])
    axs[2].patches[max_f1s1_id].set_facecolor('g')
    
    fig.suptitle(title)
    
    if save_file:
        plt.savefig(save_file)
    plt.show()

# %%
def get_hyperparams_options(layers_options = [1], lr_options = [0.01, 0.001],
                            optim_options = [tf.keras.optimizers.Adam, tf.keras.optimizers.SGD],
                            epochs_options = [5, 10, 15]):
    hp_options = []
    for epochs in [epochs_options[-1]]:  # changed to process 15 epochs (eval. after each 5)
        for lr in lr_options:
            for optim in optim_options:
                for layer in layers_options:
                    hp_options.append({'lr': lr, 'optim': optim, 'epochs': epochs, 'layers': layer})
    return hp_options

# %%
def find_hyper_parameters(options, shape, save_path = 'results/en_lstm/hyperparams_research.csv', epochs_options = [5, 10, 15]):    
    if not os.path.exists(save_path):
        hp_results = []
        for i, opts in enumerate(options):
            print('\nResearching for {}/{} | Hyperparams: {}\n'.format(i+1, len(hp_options), opts))

            hp_model = LSTMModel(nb_words, embed_dim, embedding_matrix, max_seq_len, **opts)
            hp_model.compile()
            hp_history = hp_model.fit(word_seq_train, y_train, word_seq_test, y_test)

            # append means for 5, 10 and 15 epochs
            for eps in epochs_options:
                hp_results.append({'acc': np.mean(hp_history.history['categorical_accuracy'][:eps]),
                                   'val_acc': np.mean(hp_history.history['val_categorical_accuracy'][:eps]),
                                   'loss': np.mean(hp_history.history['val_loss'][:eps]),
                                   'f1s0': np.mean(hp_model.mc.val_f1s0[:eps]),
                                   'f1s1': np.mean(hp_model.mc.val_f1s1[:eps])})

        hp_results_df = pd.DataFrame(hp_results)
        hp_results_df.to_csv(save_path)
    else:
        hp_results_df = pd.read_csv(save_path, index_col=0)
    return hp_results_df

# %%
hp_options = get_hyperparams_options()
hp_results_df = find_hyper_parameters(options = hp_options, shape=(50, 100, 3, ))
# Out:
# Researching for 1/4 | Hyperparams: {'lr': 0.01, 'optim': <class 'tensorflow.python.keras.optimizer_v2.adam.Adam'>, 'epochs': 15, 'layers': 1}
#
# Epoch 1/15
# 772/772 [==============================] - 13s 10ms/step - loss: 0.3625 - categorical_accuracy: 0.8507 - val_loss: 0.2373 - val_categorical_accuracy: 0.9195
# Epoch 2/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.2388 - categorical_accuracy: 0.9190 - val_loss: 0.2299 - val_categorical_accuracy: 0.9197
# Epoch 3/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.2308 - categorical_accuracy: 0.9188 - val_loss: 0.2289 - val_categorical_accuracy: 0.9186
# Epoch 4/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.2106 - categorical_accuracy: 0.9231 - val_loss: 0.2382 - val_categorical_accuracy: 0.9196
# Epoch 5/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.1933 - categorical_accuracy: 0.9274 - val_loss: 0.2392 - val_categorical_accuracy: 0.9172
# Epoch 6/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.1719 - categorical_accuracy: 0.9342 - val_loss: 0.2656 - val_categorical_accuracy: 0.9152
# Epoch 7/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.1433 - categorical_accuracy: 0.9457 - val_loss: 0.2802 - val_categorical_accuracy: 0.9139
# Epoch 8/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.1158 - categorical_accuracy: 0.9578 - val_loss: 0.3244 - val_categorical_accuracy: 0.9062
# Epoch 9/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.0926 - categorical_accuracy: 0.9651 - val_loss: 0.3690 - val_categorical_accuracy: 0.9076
# Epoch 10/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.0843 - categorical_accuracy: 0.9696 - val_loss: 0.4269 - val_categorical_accuracy: 0.9055
# Epoch 11/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.0671 - categorical_accuracy: 0.9752 - val_loss: 0.4326 - val_categorical_accuracy: 0.8961
# Epoch 12/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.0609 - categorical_accuracy: 0.9780 - val_loss: 0.4960 - val_categorical_accuracy: 0.9013
# Epoch 13/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.0538 - categorical_accuracy: 0.9819 - val_loss: 0.3500 - val_categorical_accuracy: 0.9025
# Epoch 14/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.0972 - categorical_accuracy: 0.9652 - val_loss: 0.4211 - val_categorical_accuracy: 0.8987
# Epoch 15/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.0508 - categorical_accuracy: 0.9823 - val_loss: 0.4941 - val_categorical_accuracy: 0.9038
#
# Researching for 2/4 | Hyperparams: {'lr': 0.01, 'optim': <class 'tensorflow.python.keras.optimizer_v2.gradient_descent.SGD'>, 'epochs': 15, 'layers': 1}
#
# Epoch 1/15
# 772/772 [==============================] - 8s 8ms/step - loss: 0.6582 - categorical_accuracy: 0.6432 - val_loss: 0.6530 - val_categorical_accuracy: 0.6398
# Epoch 2/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.6543 - categorical_accuracy: 0.6372 - val_loss: 0.6525 - val_categorical_accuracy: 0.6398
# Epoch 3/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.6524 - categorical_accuracy: 0.6396 - val_loss: 0.6518 - val_categorical_accuracy: 0.6398
# Epoch 4/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.6523 - categorical_accuracy: 0.6387 - val_loss: 0.6508 - val_categorical_accuracy: 0.6398
# Epoch 5/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.6492 - categorical_accuracy: 0.6422 - val_loss: 0.6493 - val_categorical_accuracy: 0.6398
# Epoch 6/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.6491 - categorical_accuracy: 0.6394 - val_loss: 0.6466 - val_categorical_accuracy: 0.6398
# Epoch 7/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.6458 - categorical_accuracy: 0.6398 - val_loss: 0.6412 - val_categorical_accuracy: 0.6398
# Epoch 8/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.6397 - categorical_accuracy: 0.6389 - val_loss: 0.6278 - val_categorical_accuracy: 0.6398
# Epoch 9/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.6216 - categorical_accuracy: 0.6402 - val_loss: 0.5777 - val_categorical_accuracy: 0.6655
# Epoch 10/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.5640 - categorical_accuracy: 0.6997 - val_loss: 0.5300 - val_categorical_accuracy: 0.7998
# Epoch 11/15
# 772/772 [==============================] - 7s 9ms/step - loss: 0.5047 - categorical_accuracy: 0.7600 - val_loss: 0.4524 - val_categorical_accuracy: 0.7770
# Epoch 12/15
# 772/772 [==============================] - 7s 9ms/step - loss: 0.4481 - categorical_accuracy: 0.7954 - val_loss: 0.4466 - val_categorical_accuracy: 0.8211
# Epoch 13/15
# 772/772 [==============================] - 8s 10ms/step - loss: 0.4260 - categorical_accuracy: 0.8145 - val_loss: 0.3886 - val_categorical_accuracy: 0.8463
# Epoch 14/15
# 772/772 [==============================] - 7s 10ms/step - loss: 0.4039 - categorical_accuracy: 0.8240 - val_loss: 0.4112 - val_categorical_accuracy: 0.8044
# Epoch 15/15
# 772/772 [==============================] - 7s 9ms/step - loss: 0.3887 - categorical_accuracy: 0.8383 - val_loss: 0.3590 - val_categorical_accuracy: 0.8609
#
# Researching for 3/4 | Hyperparams: {'lr': 0.001, 'optim': <class 'tensorflow.python.keras.optimizer_v2.adam.Adam'>, 'epochs': 15, 'layers': 1}
#
# Epoch 1/15
# 772/772 [==============================] - 9s 10ms/step - loss: 0.4154 - categorical_accuracy: 0.7933 - val_loss: 0.2454 - val_categorical_accuracy: 0.9128
# Epoch 2/15
# 772/772 [==============================] - 7s 9ms/step - loss: 0.2482 - categorical_accuracy: 0.9129 - val_loss: 0.2416 - val_categorical_accuracy: 0.9145
# Epoch 3/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.2322 - categorical_accuracy: 0.9189 - val_loss: 0.2335 - val_categorical_accuracy: 0.9180
# Epoch 4/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.2326 - categorical_accuracy: 0.9189 - val_loss: 0.2368 - val_categorical_accuracy: 0.9170
# Epoch 5/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.2249 - categorical_accuracy: 0.9198 - val_loss: 0.2298 - val_categorical_accuracy: 0.9201
# Epoch 6/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.2150 - categorical_accuracy: 0.9238 - val_loss: 0.2282 - val_categorical_accuracy: 0.9202
# Epoch 7/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.2133 - categorical_accuracy: 0.9231 - val_loss: 0.2306 - val_categorical_accuracy: 0.9199
# Epoch 8/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.2092 - categorical_accuracy: 0.9256 - val_loss: 0.2287 - val_categorical_accuracy: 0.9198
# Epoch 9/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.2060 - categorical_accuracy: 0.9245 - val_loss: 0.2390 - val_categorical_accuracy: 0.9167
# Epoch 10/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.1960 - categorical_accuracy: 0.9289 - val_loss: 0.2365 - val_categorical_accuracy: 0.9183
# Epoch 11/15
# 772/772 [==============================] - 6s 7ms/step - loss: 0.1895 - categorical_accuracy: 0.9308 - val_loss: 0.2531 - val_categorical_accuracy: 0.9179
# Epoch 12/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.1836 - categorical_accuracy: 0.9319 - val_loss: 0.2497 - val_categorical_accuracy: 0.9148
# Epoch 13/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.1722 - categorical_accuracy: 0.9364 - val_loss: 0.2619 - val_categorical_accuracy: 0.9160
# Epoch 14/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.1604 - categorical_accuracy: 0.9399 - val_loss: 0.2599 - val_categorical_accuracy: 0.9111
# Epoch 15/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.1546 - categorical_accuracy: 0.9411 - val_loss: 0.2921 - val_categorical_accuracy: 0.9116
#
# Researching for 4/4 | Hyperparams: {'lr': 0.001, 'optim': <class 'tensorflow.python.keras.optimizer_v2.gradient_descent.SGD'>, 'epochs': 15, 'layers': 1}
#
# Epoch 1/15
# 772/772 [==============================] - 8s 8ms/step - loss: 0.6743 - categorical_accuracy: 0.6421 - val_loss: 0.6645 - val_categorical_accuracy: 0.6398
# Epoch 2/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.6617 - categorical_accuracy: 0.6427 - val_loss: 0.6583 - val_categorical_accuracy: 0.6398
# Epoch 3/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.6573 - categorical_accuracy: 0.6403 - val_loss: 0.6556 - val_categorical_accuracy: 0.6398
# Epoch 4/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.6560 - categorical_accuracy: 0.6381 - val_loss: 0.6544 - val_categorical_accuracy: 0.6398
# Epoch 5/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.6530 - categorical_accuracy: 0.6424 - val_loss: 0.6538 - val_categorical_accuracy: 0.6398
# Epoch 6/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.6531 - categorical_accuracy: 0.6411 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 7/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.6547 - categorical_accuracy: 0.6377 - val_loss: 0.6534 - val_categorical_accuracy: 0.6398
# Epoch 8/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.6535 - categorical_accuracy: 0.6397 - val_loss: 0.6534 - val_categorical_accuracy: 0.6398
# Epoch 9/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.6529 - categorical_accuracy: 0.6407 - val_loss: 0.6533 - val_categorical_accuracy: 0.6398
# Epoch 10/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.6519 - categorical_accuracy: 0.6424 - val_loss: 0.6533 - val_categorical_accuracy: 0.6398
# Epoch 11/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.6523 - categorical_accuracy: 0.6415 - val_loss: 0.6532 - val_categorical_accuracy: 0.6398
# Epoch 12/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.6532 - categorical_accuracy: 0.6399 - val_loss: 0.6532 - val_categorical_accuracy: 0.6398
# Epoch 13/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.6538 - categorical_accuracy: 0.6389 - val_loss: 0.6532 - val_categorical_accuracy: 0.6398
# Epoch 14/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.6519 - categorical_accuracy: 0.6420 - val_loss: 0.6532 - val_categorical_accuracy: 0.6398
# Epoch 15/15
# 772/772 [==============================] - 6s 8ms/step - loss: 0.6554 - categorical_accuracy: 0.6358 - val_loss: 0.6531 - val_categorical_accuracy: 0.6398

# %%
pd.DataFrame(hp_options).head()
# Out:
#       lr                                              optim  epochs  layers
# 0  0.010  <class 'tensorflow.python.keras.optimizer_v2.a...      15       1
# 1  0.010  <class 'tensorflow.python.keras.optimizer_v2.g...      15       1
# 2  0.001  <class 'tensorflow.python.keras.optimizer_v2.a...      15       1
# 3  0.001  <class 'tensorflow.python.keras.optimizer_v2.g...      15       1

# %%
models_comparison_bars(hp_results_df, title='Hyperparams research', interval=10,
                       save_file='results/en_lstm/hyperparams_research.png')

# %%
best_h_num = 3
'Best one: {} with {} run epochs'.format(hp_options[int((best_h_num-1)/3)],
                                         ((best_h_num-1)%3)*5 if (best_h_num-1)%3 != 0 else 15)
# Out:
# "Best one: {'lr': 0.01, 'optim': <class 'tensorflow.python.keras.optimizer_v2.adam.Adam'>, 'epochs': 15, 'layers': 1} with 10 run epochs"

# %%
def get_params_options( batch_size_options = [25, 50, 75, 100, 125],
                        init_options = ['random_uniform', 'random_normal'],
                        rnn_units_options = [64, 128, 192, 255]):

    p_options = []
    for batch_size in batch_size_options:
        for init in init_options:
            for rnn_units in rnn_units_options:
                p_options.append({'batch_size': batch_size,
                                'init': init,
                                'rnn_units': rnn_units})
    return p_options

# %%
def find_parameters(options, shape, 
    save_path = 'results/en_lstm/params_research.csv', epochs_options = [5, 10, 15]):
    if not os.path.exists(save_path):
        p_results = []
        for i, opts in enumerate(p_options):
            print('\nResearching for {}/{} | Hyperparams: {}\n'.format(i+1, len(p_options), opts))

            p_model = LSTMModel(nb_words, embed_dim, embedding_matrix, max_seq_len, **opts)
            p_model.compile()
            p_history = p_model.fit(word_seq_train, y_train, word_seq_test, y_test)

            p_results.append({'acc': np.mean(p_history.history['categorical_accuracy']),
                            'val_acc': np.mean(p_history.history['val_categorical_accuracy']),
                            'loss': np.mean(p_history.history['val_loss']),
                            'f1s0': np.mean(p_model.mc.val_f1s0),
                            'f1s1': np.mean(p_model.mc.val_f1s1)})

        p_results_df = pd.DataFrame(p_results)
        p_results_df.to_csv(save_path)
    else:
        p_results_df = pd.read_csv(save_path, index_col=0)
    return p_results_df

# %%
p_options = get_params_options()
p_results_df = find_parameters(options = p_options, shape = (12, 300, ))
# Out:
# 1ms/step - loss: 0.2326 - categorical_accuracy: 0.9209 - val_loss: 0.2293 - val_categorical_accuracy: 0.9185
# Epoch 4/5
# 515/515 [==============================] - 6s 11ms/step - loss: 0.2221 - categorical_accuracy: 0.9219 - val_loss: 0.2327 - val_categorical_accuracy: 0.9190
# Epoch 5/5
# 515/515 [==============================] - 6s 11ms/step - loss: 0.2114 - categorical_accuracy: 0.9246 - val_loss: 0.2303 - val_categorical_accuracy: 0.9178
#
# Researching for 20/40 | Hyperparams: {'batch_size': 75, 'init': 'random_uniform', 'rnn_units': 255}
#
# Epoch 1/5
# 515/515 [==============================] - 9s 15ms/step - loss: 0.6108 - categorical_accuracy: 0.6862 - val_loss: 0.4890 - val_categorical_accuracy: 0.8002
# Epoch 2/5
# 515/515 [==============================] - 7s 14ms/step - loss: 0.3393 - categorical_accuracy: 0.8675 - val_loss: 0.2533 - val_categorical_accuracy: 0.9123
# Epoch 3/5
# 515/515 [==============================] - 7s 14ms/step - loss: 0.2540 - categorical_accuracy: 0.9105 - val_loss: 0.2449 - val_categorical_accuracy: 0.9172
# Epoch 4/5
# 515/515 [==============================] - 7s 14ms/step - loss: 0.3243 - categorical_accuracy: 0.8742 - val_loss: 0.2639 - val_categorical_accuracy: 0.9085
# Epoch 5/5
# 515/515 [==============================] - 7s 14ms/step - loss: 0.2716 - categorical_accuracy: 0.9052 - val_loss: 0.2615 - val_categorical_accuracy: 0.9087
#
# Researching for 21/40 | Hyperparams: {'batch_size': 75, 'init': 'random_normal', 'rnn_units': 64}
#
# Epoch 1/5
# 515/515 [==============================] - 7s 10ms/step - loss: 0.3563 - categorical_accuracy: 0.8582 - val_loss: 0.2484 - val_categorical_accuracy: 0.9126
# Epoch 2/5
# 515/515 [==============================] - 5s 9ms/step - loss: 0.2483 - categorical_accuracy: 0.9139 - val_loss: 0.2390 - val_categorical_accuracy: 0.9196
# Epoch 3/5
# 515/515 [==============================] - 4s 9ms/step - loss: 0.2282 - categorical_accuracy: 0.9212 - val_loss: 0.2262 - val_categorical_accuracy: 0.9203
# Epoch 4/5
# 515/515 [==============================] - 5s 9ms/step - loss: 0.2143 - categorical_accuracy: 0.9210 - val_loss: 0.2476 - val_categorical_accuracy: 0.9143
# Epoch 5/5
# 515/515 [==============================] - 5s 9ms/step - loss: 0.2024 - categorical_accuracy: 0.9258 - val_loss: 0.2318 - val_categorical_accuracy: 0.9190
#
# Researching for 22/40 | Hyperparams: {'batch_size': 75, 'init': 'random_normal', 'rnn_units': 128}
#
# Epoch 1/5
# 515/515 [==============================] - 7s 11ms/step - loss: 0.3844 - categorical_accuracy: 0.8478 - val_loss: 0.2374 - val_categorical_accuracy: 0.9196
# Epoch 2/5
# 515/515 [==============================] - 5s 10ms/step - loss: 0.2372 - categorical_accuracy: 0.9173 - val_loss: 0.2309 - val_categorical_accuracy: 0.9201
# Epoch 3/5
# 515/515 [==============================] - 5s 10ms/step - loss: 0.2193 - categorical_accuracy: 0.9226 - val_loss: 0.2277 - val_categorical_accuracy: 0.9204
# Epoch 4/5
# 515/515 [==============================] - 5s 10ms/step - loss: 0.2034 - categorical_accuracy: 0.9236 - val_loss: 0.2413 - val_categorical_accuracy: 0.9190
# Epoch 5/5
# 515/515 [==============================] - 5s 10ms/step - loss: 0.1843 - categorical_accuracy: 0.9273 - val_loss: 0.2413 - val_categorical_accuracy: 0.9177
#
# Researching for 23/40 | Hyperparams: {'batch_size': 75, 'init': 'random_normal', 'rnn_units': 192}
#
# Epoch 1/5
# 515/515 [==============================] - 8s 12ms/step - loss: 0.5545 - categorical_accuracy: 0.7237 - val_loss: 0.2468 - val_categorical_accuracy: 0.9130
# Epoch 2/5
# 515/515 [==============================] - 6s 11ms/step - loss: 0.2460 - categorical_accuracy: 0.9152 - val_loss: 0.2321 - val_categorical_accuracy: 0.9194
# Epoch 3/5
# 515/515 [==============================] - 6s 11ms/step - loss: 0.2337 - categorical_accuracy: 0.9192 - val_loss: 0.2331 - val_categorical_accuracy: 0.9177
# Epoch 4/5
# 515/515 [==============================] - 6s 11ms/step - loss: 0.2245 - categorical_accuracy: 0.9217 - val_loss: 0.2320 - val_categorical_accuracy: 0.9169
# Epoch 5/5
# 515/515 [==============================] - 6s 11ms/step - loss: 0.2143 - categorical_accuracy: 0.9241 - val_loss: 0.2324 - val_categorical_accuracy: 0.9163
#
# Researching for 24/40 | Hyperparams: {'batch_size': 75, 'init': 'random_normal', 'rnn_units': 255}
#
# Epoch 1/5
# 515/515 [==============================] - 9s 14ms/step - loss: 0.3748 - categorical_accuracy: 0.8436 - val_loss: 0.2483 - val_categorical_accuracy: 0.9184
# Epoch 2/5
# 515/515 [==============================] - 7s 13ms/step - loss: 0.2459 - categorical_accuracy: 0.9160 - val_loss: 0.2314 - val_categorical_accuracy: 0.9187
# Epoch 3/5
# 515/515 [==============================] - 7s 13ms/step - loss: 0.2256 - categorical_accuracy: 0.9191 - val_loss: 0.2297 - val_categorical_accuracy: 0.9197
# Epoch 4/5
# 515/515 [==============================] - 7s 13ms/step - loss: 0.2141 - categorical_accuracy: 0.9217 - val_loss: 0.2291 - val_categorical_accuracy: 0.9180
# Epoch 5/5
# 515/515 [==============================] - 7s 13ms/step - loss: 0.1918 - categorical_accuracy: 0.9274 - val_loss: 0.2585 - val_categorical_accuracy: 0.9168
#
# Researching for 25/40 | Hyperparams: {'batch_size': 100, 'init': 'random_uniform', 'rnn_units': 64}
#
# Epoch 1/5
# 386/386 [==============================] - 5s 11ms/step - loss: 0.3626 - categorical_accuracy: 0.8524 - val_loss: 0.2378 - val_categorical_accuracy: 0.9172
# Epoch 2/5
# 386/386 [==============================] - 3s 9ms/step - loss: 0.2445 - categorical_accuracy: 0.9154 - val_loss: 0.2398 - val_categorical_accuracy: 0.9182
# Epoch 3/5
# 386/386 [==============================] - 4s 9ms/step - loss: 0.2280 - categorical_accuracy: 0.9211 - val_loss: 0.2291 - val_categorical_accuracy: 0.9201
# Epoch 4/5
# 386/386 [==============================] - 3s 9ms/step - loss: 0.2167 - categorical_accuracy: 0.9221 - val_loss: 0.2323 - val_categorical_accuracy: 0.9177
# Epoch 5/5
# 386/386 [==============================] - 4s 9ms/step - loss: 0.2011 - categorical_accuracy: 0.9281 - val_loss: 0.2326 - val_categorical_accuracy: 0.9198
#
# Researching for 26/40 | Hyperparams: {'batch_size': 100, 'init': 'random_uniform', 'rnn_units': 128}
#
# Epoch 1/5
# 386/386 [==============================] - 6s 13ms/step - loss: 0.3936 - categorical_accuracy: 0.8347 - val_loss: 0.2440 - val_categorical_accuracy: 0.9154
# Epoch 2/5
# 386/386 [==============================] - 4s 11ms/step - loss: 0.2445 - categorical_accuracy: 0.9166 - val_loss: 0.2329 - val_categorical_accuracy: 0.9183
# Epoch 3/5
# 386/386 [==============================] - 5s 12ms/step - loss: 0.2272 - categorical_accuracy: 0.9215 - val_loss: 0.2343 - val_categorical_accuracy: 0.9205
# Epoch 4/5
# 386/386 [==============================] - 4s 11ms/step - loss: 0.2117 - categorical_accuracy: 0.9242 - val_loss: 0.2338 - val_categorical_accuracy: 0.9196
# Epoch 5/5
# 386/386 [==============================] - 4s 11ms/step - loss: 0.2030 - categorical_accuracy: 0.9252 - val_loss: 0.2353 - val_categorical_accuracy: 0.9199
#
# Researching for 27/40 | Hyperparams: {'batch_size': 100, 'init': 'random_uniform', 'rnn_units': 192}
#
# Epoch 1/5
# 386/386 [==============================] - 7s 14ms/step - loss: 0.6524 - categorical_accuracy: 0.6291 - val_loss: 0.6537 - val_categorical_accuracy: 0.6398
# Epoch 2/5
# 386/386 [==============================] - 5s 13ms/step - loss: 0.6546 - categorical_accuracy: 0.6382 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 3/5
# 386/386 [==============================] - 5s 13ms/step - loss: 0.6539 - categorical_accuracy: 0.6395 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 4/5
# 386/386 [==============================] - 5s 13ms/step - loss: 0.6546 - categorical_accuracy: 0.6382 - val_loss: 0.6537 - val_categorical_accuracy: 0.6398
# Epoch 5/5
# 386/386 [==============================] - 5s 13ms/step - loss: 0.6532 - categorical_accuracy: 0.6407 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
#
# Researching for 28/40 | Hyperparams: {'batch_size': 100, 'init': 'random_uniform', 'rnn_units': 255}
#
# Epoch 1/5
# 386/386 [==============================] - 9s 18ms/step - loss: 0.6530 - categorical_accuracy: 0.6251 - val_loss: 0.6537 - val_categorical_accuracy: 0.6398
# Epoch 2/5
# 386/386 [==============================] - 6s 17ms/step - loss: 0.6549 - categorical_accuracy: 0.6379 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 3/5
# 386/386 [==============================] - 6s 16ms/step - loss: 0.6560 - categorical_accuracy: 0.6360 - val_loss: 0.6535 - val_categorical_accuracy: 0.6398
# Epoch 4/5
# 386/386 [==============================] - 6s 16ms/step - loss: 0.6539 - categorical_accuracy: 0.6394 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 5/5
# 386/386 [==============================] - 6s 16ms/step - loss: 0.6559 - categorical_accuracy: 0.6360 - val_loss: 0.6535 - val_categorical_accuracy: 0.6398
#
# Researching for 29/40 | Hyperparams: {'batch_size': 100, 'init': 'random_normal', 'rnn_units': 64}
#
# Epoch 1/5
# 386/386 [==============================] - 6s 11ms/step - loss: 0.3661 - categorical_accuracy: 0.8447 - val_loss: 0.2381 - val_categorical_accuracy: 0.9190
# Epoch 2/5
# 386/386 [==============================] - 3s 9ms/step - loss: 0.2346 - categorical_accuracy: 0.9203 - val_loss: 0.2368 - val_categorical_accuracy: 0.9157
# Epoch 3/5
# 386/386 [==============================] - 4s 9ms/step - loss: 0.2267 - categorical_accuracy: 0.9208 - val_loss: 0.2266 - val_categorical_accuracy: 0.9198
# Epoch 4/5
# 386/386 [==============================] - 3s 9ms/step - loss: 0.2137 - categorical_accuracy: 0.9235 - val_loss: 0.2307 - val_categorical_accuracy: 0.9215
# Epoch 5/5
# 386/386 [==============================] - 3s 9ms/step - loss: 0.1980 - categorical_accuracy: 0.9288 - val_loss: 0.2369 - val_categorical_accuracy: 0.9187
#
# Researching for 30/40 | Hyperparams: {'batch_size': 100, 'init': 'random_normal', 'rnn_units': 128}
#
# Epoch 1/5
# 386/386 [==============================] - 6s 12ms/step - loss: 0.3859 - categorical_accuracy: 0.8342 - val_loss: 0.2372 - val_categorical_accuracy: 0.9187
# Epoch 2/5
# 386/386 [==============================] - 4s 11ms/step - loss: 0.2405 - categorical_accuracy: 0.9172 - val_loss: 0.2328 - val_categorical_accuracy: 0.9191
# Epoch 3/5
# 386/386 [==============================] - 5s 12ms/step - loss: 0.2306 - categorical_accuracy: 0.9192 - val_loss: 0.2369 - val_categorical_accuracy: 0.9164
# Epoch 4/5
# 386/386 [==============================] - 4s 11ms/step - loss: 0.2185 - categorical_accuracy: 0.9207 - val_loss: 0.2335 - val_categorical_accuracy: 0.9158
# Epoch 5/5
# 386/386 [==============================] - 4s 11ms/step - loss: 0.2108 - categorical_accuracy: 0.9219 - val_loss: 0.2314 - val_categorical_accuracy: 0.9179
#
# Researching for 31/40 | Hyperparams: {'batch_size': 100, 'init': 'random_normal', 'rnn_units': 192}
#
# Epoch 1/5
# 386/386 [==============================] - 7s 14ms/step - loss: 0.5369 - categorical_accuracy: 0.7633 - val_loss: 0.2512 - val_categorical_accuracy: 0.9143
# Epoch 2/5
# 386/386 [==============================] - 5s 13ms/step - loss: 0.2548 - categorical_accuracy: 0.9095 - val_loss: 0.2444 - val_categorical_accuracy: 0.9193
# Epoch 3/5
# 386/386 [==============================] - 5s 13ms/step - loss: 0.2310 - categorical_accuracy: 0.9209 - val_loss: 0.2367 - val_categorical_accuracy: 0.9183
# Epoch 4/5
# 386/386 [==============================] - 5s 13ms/step - loss: 0.2184 - categorical_accuracy: 0.9219 - val_loss: 0.2300 - val_categorical_accuracy: 0.9203
# Epoch 5/5
# 386/386 [==============================] - 5s 13ms/step - loss: 0.2085 - categorical_accuracy: 0.9222 - val_loss: 0.2302 - val_categorical_accuracy: 0.9209
#
# Researching for 32/40 | Hyperparams: {'batch_size': 100, 'init': 'random_normal', 'rnn_units': 255}
#
# Epoch 1/5
# 386/386 [==============================] - 9s 18ms/step - loss: 0.4692 - categorical_accuracy: 0.7851 - val_loss: 0.2438 - val_categorical_accuracy: 0.9153
# Epoch 2/5
# 386/386 [==============================] - 7s 17ms/step - loss: 0.2368 - categorical_accuracy: 0.9192 - val_loss: 0.2362 - val_categorical_accuracy: 0.9169
# Epoch 3/5
# 386/386 [==============================] - 6s 17ms/step - loss: 0.2255 - categorical_accuracy: 0.9212 - val_loss: 0.2326 - val_categorical_accuracy: 0.9183
# Epoch 4/5
# 386/386 [==============================] - 6s 17ms/step - loss: 0.2117 - categorical_accuracy: 0.9243 - val_loss: 0.2395 - val_categorical_accuracy: 0.9158
# Epoch 5/5
# 386/386 [==============================] - 6s 17ms/step - loss: 0.2001 - categorical_accuracy: 0.9253 - val_loss: 0.2322 - val_categorical_accuracy: 0.9187
#
# Researching for 33/40 | Hyperparams: {'batch_size': 125, 'init': 'random_uniform', 'rnn_units': 64}
#
# Epoch 1/5
# 309/309 [==============================] - 5s 11ms/step - loss: 0.3831 - categorical_accuracy: 0.8308 - val_loss: 0.2381 - val_categorical_accuracy: 0.9174
# Epoch 2/5
# 309/309 [==============================] - 3s 10ms/step - loss: 0.2321 - categorical_accuracy: 0.9193 - val_loss: 0.2333 - val_categorical_accuracy: 0.9169
# Epoch 3/5
# 309/309 [==============================] - 3s 10ms/step - loss: 0.2297 - categorical_accuracy: 0.9193 - val_loss: 0.2278 - val_categorical_accuracy: 0.9200
# Epoch 4/5
# 309/309 [==============================] - 3s 10ms/step - loss: 0.2153 - categorical_accuracy: 0.9222 - val_loss: 0.2283 - val_categorical_accuracy: 0.9201
# Epoch 5/5
# 309/309 [==============================] - 3s 10ms/step - loss: 0.1992 - categorical_accuracy: 0.9250 - val_loss: 0.2375 - val_categorical_accuracy: 0.9175
#
# Researching for 34/40 | Hyperparams: {'batch_size': 125, 'init': 'random_uniform', 'rnn_units': 128}
#
# Epoch 1/5
# 309/309 [==============================] - 6s 14ms/step - loss: 0.4167 - categorical_accuracy: 0.8127 - val_loss: 0.2451 - val_categorical_accuracy: 0.9129
# Epoch 2/5
# 309/309 [==============================] - 4s 12ms/step - loss: 0.2418 - categorical_accuracy: 0.9178 - val_loss: 0.2384 - val_categorical_accuracy: 0.9187
# Epoch 3/5
# 309/309 [==============================] - 4s 12ms/step - loss: 0.2356 - categorical_accuracy: 0.9167 - val_loss: 0.2282 - val_categorical_accuracy: 0.9187
# Epoch 4/5
# 309/309 [==============================] - 4s 12ms/step - loss: 0.2125 - categorical_accuracy: 0.9239 - val_loss: 0.2337 - val_categorical_accuracy: 0.9178
# Epoch 5/5
# 309/309 [==============================] - 4s 13ms/step - loss: 0.1967 - categorical_accuracy: 0.9270 - val_loss: 0.2360 - val_categorical_accuracy: 0.9182
#
# Researching for 35/40 | Hyperparams: {'batch_size': 125, 'init': 'random_uniform', 'rnn_units': 192}
#
# Epoch 1/5
# 309/309 [==============================] - 6s 16ms/step - loss: 0.5297 - categorical_accuracy: 0.7435 - val_loss: 0.2433 - val_categorical_accuracy: 0.9158
# Epoch 2/5
# 309/309 [==============================] - 5s 15ms/step - loss: 0.2451 - categorical_accuracy: 0.9162 - val_loss: 0.2310 - val_categorical_accuracy: 0.9191
# Epoch 3/5
# 309/309 [==============================] - 5s 15ms/step - loss: 0.2324 - categorical_accuracy: 0.9182 - val_loss: 0.2300 - val_categorical_accuracy: 0.9187
# Epoch 4/5
# 309/309 [==============================] - 4s 14ms/step - loss: 0.2160 - categorical_accuracy: 0.9233 - val_loss: 0.2300 - val_categorical_accuracy: 0.9184
# Epoch 5/5
# 309/309 [==============================] - 5s 15ms/step - loss: 0.2070 - categorical_accuracy: 0.9259 - val_loss: 0.2333 - val_categorical_accuracy: 0.9167
#
# Researching for 36/40 | Hyperparams: {'batch_size': 125, 'init': 'random_uniform', 'rnn_units': 255}
#
# Epoch 1/5
# 309/309 [==============================] - 8s 21ms/step - loss: 0.5817 - categorical_accuracy: 0.7056 - val_loss: 0.2775 - val_categorical_accuracy: 0.9076
# Epoch 2/5
# 309/309 [==============================] - 6s 19ms/step - loss: 0.2908 - categorical_accuracy: 0.8984 - val_loss: 0.3328 - val_categorical_accuracy: 0.8969
# Epoch 3/5
# 309/309 [==============================] - 6s 19ms/step - loss: 0.2905 - categorical_accuracy: 0.9000 - val_loss: 0.2419 - val_categorical_accuracy: 0.9153
# Epoch 4/5
# 309/309 [==============================] - 6s 19ms/step - loss: 0.2463 - categorical_accuracy: 0.9160 - val_loss: 0.2494 - val_categorical_accuracy: 0.9125
# Epoch 5/5
# 309/309 [==============================] - 6s 19ms/step - loss: 0.2370 - categorical_accuracy: 0.9190 - val_loss: 0.2401 - val_categorical_accuracy: 0.9160
#
# Researching for 37/40 | Hyperparams: {'batch_size': 125, 'init': 'random_normal', 'rnn_units': 64}
#
# Epoch 1/5
# 309/309 [==============================] - 5s 11ms/step - loss: 0.3786 - categorical_accuracy: 0.8384 - val_loss: 0.2471 - val_categorical_accuracy: 0.9128
# Epoch 2/5
# 309/309 [==============================] - 3s 10ms/step - loss: 0.2412 - categorical_accuracy: 0.9179 - val_loss: 0.2281 - val_categorical_accuracy: 0.9193
# Epoch 3/5
# 309/309 [==============================] - 3s 10ms/step - loss: 0.2244 - categorical_accuracy: 0.9206 - val_loss: 0.2265 - val_categorical_accuracy: 0.9208
# Epoch 4/5
# 309/309 [==============================] - 3s 10ms/step - loss: 0.2155 - categorical_accuracy: 0.9221 - val_loss: 0.2378 - val_categorical_accuracy: 0.9204
# Epoch 5/5
# 309/309 [==============================] - 3s 10ms/step - loss: 0.2024 - categorical_accuracy: 0.9243 - val_loss: 0.2429 - val_categorical_accuracy: 0.9190
#
# Researching for 38/40 | Hyperparams: {'batch_size': 125, 'init': 'random_normal', 'rnn_units': 128}
#
# Epoch 1/5
# 309/309 [==============================] - 6s 14ms/step - loss: 0.3934 - categorical_accuracy: 0.8314 - val_loss: 0.2457 - val_categorical_accuracy: 0.9154
# Epoch 2/5
# 309/309 [==============================] - 4s 12ms/step - loss: 0.2502 - categorical_accuracy: 0.9130 - val_loss: 0.2307 - val_categorical_accuracy: 0.9192
# Epoch 3/5
# 309/309 [==============================] - 4s 12ms/step - loss: 0.2273 - categorical_accuracy: 0.9203 - val_loss: 0.2294 - val_categorical_accuracy: 0.9192
# Epoch 4/5
# 309/309 [==============================] - 4s 12ms/step - loss: 0.2158 - categorical_accuracy: 0.9225 - val_loss: 0.2309 - val_categorical_accuracy: 0.9192
# Epoch 5/5
# 309/309 [==============================] - 4s 12ms/step - loss: 0.1978 - categorical_accuracy: 0.9272 - val_loss: 0.2463 - val_categorical_accuracy: 0.9198
#
# Researching for 39/40 | Hyperparams: {'batch_size': 125, 'init': 'random_normal', 'rnn_units': 192}
#
# Epoch 1/5
# 309/309 [==============================] - 6s 16ms/step - loss: 0.3831 - categorical_accuracy: 0.8490 - val_loss: 0.2569 - val_categorical_accuracy: 0.9097
# Epoch 2/5
# 309/309 [==============================] - 4s 14ms/step - loss: 0.2569 - categorical_accuracy: 0.9119 - val_loss: 0.2370 - val_categorical_accuracy: 0.9187
# Epoch 3/5
# 309/309 [==============================] - 4s 14ms/step - loss: 0.2311 - categorical_accuracy: 0.9198 - val_loss: 0.2293 - val_categorical_accuracy: 0.9204
# Epoch 4/5
# 309/309 [==============================] - 4s 14ms/step - loss: 0.2240 - categorical_accuracy: 0.9193 - val_loss: 0.2260 - val_categorical_accuracy: 0.9203
# Epoch 5/5
# 309/309 [==============================] - 4s 14ms/step - loss: 0.2103 - categorical_accuracy: 0.9239 - val_loss: 0.2342 - val_categorical_accuracy: 0.9178
#
# Researching for 40/40 | Hyperparams: {'batch_size': 125, 'init': 'random_normal', 'rnn_units': 255}
#
# Epoch 1/5
# 309/309 [==============================] - 8s 21ms/step - loss: 0.5064 - categorical_accuracy: 0.7399 - val_loss: 0.2427 - val_categorical_accuracy: 0.9155
# Epoch 2/5
# 309/309 [==============================] - 6s 19ms/step - loss: 0.2481 - categorical_accuracy: 0.9141 - val_loss: 0.2358 - val_categorical_accuracy: 0.9172
# Epoch 3/5
# 309/309 [==============================] - 6s 19ms/step - loss: 0.2333 - categorical_accuracy: 0.9206 - val_loss: 0.2403 - val_categorical_accuracy: 0.9174
# Epoch 4/5
# 309/309 [==============================] - 6s 19ms/step - loss: 0.2150 - categorical_accuracy: 0.9260 - val_loss: 0.2306 - val_categorical_accuracy: 0.9188
# Epoch 5/5
# 309/309 [==============================] - 6s 19ms/step - loss: 0.2164 - categorical_accuracy: 0.9238 - val_loss: 0.2340 - val_categorical_accuracy: 0.9181

# %%
p_results_df.head()
# Out:
#         acc   val_acc      loss      f1s0      f1s1
# 0  0.919377  0.918779  0.239128  0.885417  0.937088
# 1  0.918304  0.918537  0.238830  0.884190  0.937162
# 2  0.914495  0.916106  0.240024  0.882849  0.934613
# 3  0.639708  0.639782  0.653998  0.000000  0.780326
# 4  0.918346  0.917231  0.237933  0.882198  0.936180

# %%
models_comparison_bars(p_results_df, title='Params research', save_file='results/en_lstm/params_research.png')

# %%
best_num = 26
'Best one: {}'.format(p_options[best_num-1])
# Out:
# "Best one: {'batch_size': 100, 'init': 'random_uniform', 'rnn_units': 128}"

# %%
model = LSTMModel(nb_words, embed_dim, embedding_matrix, max_seq_len)
model.summary()
# Out:
# Model: "sequential_44"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_44 (Embedding)     (None, 50, 300)           12422400
# _________________________________________________________________
# wt_recurrent (LSTM)          (None, 64)                93440
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# predictions (Dense)          (None, 2)                 130
# =================================================================
# Total params: 12,520,130
# Trainable params: 97,730
# Non-trainable params: 12,422,400
# _________________________________________________________________

# %%
model.compile()
history = model.fit(word_seq_train, y_train, word_seq_test, y_test)
model.save('models/en_lstm.model')
# Out:
# Epoch 1/5
# 772/772 [==============================] - 8s 8ms/step - loss: 0.3411 - categorical_accuracy: 0.8647 - val_loss: 0.2338 - val_categorical_accuracy: 0.9185
# Epoch 2/5
# 772/772 [==============================] - 6s 8ms/step - loss: 0.2393 - categorical_accuracy: 0.9176 - val_loss: 0.2270 - val_categorical_accuracy: 0.9196
# Epoch 3/5
# 772/772 [==============================] - 6s 7ms/step - loss: 0.2201 - categorical_accuracy: 0.9211 - val_loss: 0.2265 - val_categorical_accuracy: 0.9195
# Epoch 4/5
# 772/772 [==============================] - 6s 7ms/step - loss: 0.2094 - categorical_accuracy: 0.9225 - val_loss: 0.2321 - val_categorical_accuracy: 0.9184
# Epoch 5/5
# 772/772 [==============================] - 6s 7ms/step - loss: 0.1868 - categorical_accuracy: 0.9304 - val_loss: 0.2506 - val_categorical_accuracy: 0.9162
# WARNING:absl:Found untraced functions such as lstm_cell_44_layer_call_fn, lstm_cell_44_layer_call_and_return_conditional_losses, lstm_cell_44_layer_call_fn, lstm_cell_44_layer_call_and_return_conditional_losses, lstm_cell_44_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_44_layer_call_fn, lstm_cell_44_layer_call_and_return_conditional_losses, lstm_cell_44_layer_call_fn, lstm_cell_44_layer_call_and_return_conditional_losses, lstm_cell_44_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/en_lstm.model/assets
# INFO:tensorflow:Assets written to: models/en_lstm.model/assets

# %%
predictions = model.predict(word_seq_test)
y_true = tf.argmax(y_test, axis=1)
y_pred = tf.argmax(predictions, axis=1)


conf_mat = tf.math.confusion_matrix(labels=y_true, predictions=y_pred, num_classes=2).numpy()
roc = roc_auc_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)

acc = float(np.sum(np.diag(conf_mat)))/np.sum(np.sum(conf_mat))
f1s0 = 2*float(conf_mat[0][0])/(2*float(conf_mat[0][0]) + conf_mat[0][1] + conf_mat[1][0])
f1s1 = 2*float(conf_mat[1][1])/(2*float(conf_mat[1][1]) + conf_mat[1][0] + conf_mat[0][1])

# %%
if not os.path.exists('results/en_lstm/short_results.csv'):
    with open('results/en_lstm/short_results.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(['Accuracy', 'F1 score (0)', 'F1 score (1)', 'F1', 'ROC', 'Precision'])
        writer.writerow([acc, f1s0, f1s1, f1, roc, precision])
else:
    with open('results/en_lstm/short_results.csv', 'a') as f:
        writer = csv.writer(f)
        writer.writerow([acc, f1s0, f1s1, f1, roc, precision])

# %%
# save model history, confusion matrix and accuracy
model_results = {'acc': history.history['categorical_accuracy'],
                 'val_acc': history.history['val_categorical_accuracy'],
                 'loss': history.history['loss'],
                 'val_loss': history.history['val_loss'],
                 'f1s0': model.mc.val_f1s0,
                 'f1s1': model.mc.val_f1s1,
                 'conf_mat': conf_mat,
                 'main_acc': acc}
with open('results/en_lstm/results.pkl', 'wb') as f:
    pickle.dump(model_results, f)

# %%
def plots(y_ss, y_labels, colors, title, file_name=None):
    x_s = range(1, len(y_ss[0])+1)
    for y_s, y_label, color in zip(y_ss, y_labels, colors):
        plt.plot(x_s, y_s, color, label=y_label)
    plt.xlabel('Epoch')
    plt.ylabel('Metrics')
    tick_marks = np.arange(1, len(x_s) + 1)
    plt.xticks(tick_marks, x_s)
    plt.title(title)
    
    plt.legend(loc='best', frameon=False)
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

def twinx_plot(y11_s, y12_s, y21_s, y22_s, x_label, y1_label,y2_label, title,
               styles=['r-', 'r--', 'b-', 'b--'], colors=['r', 'b'], file_name=None):
    fig, ax1 = plt.subplots()
    
    ax1.set_xlabel(x_label)
    ax1.set_xticks(range(1, len(y11_s)+1))
    
    ax1.set_ylabel(y1_label, color=colors[0])
    ax1.plot(range(1, len(y11_s)+1), y11_s, styles[0], label='train acc.')
    ax1.plot(range(1, len(y12_s)+1), y12_s, styles[1], label='valid. acc.')
    ax1.tick_params(axis='y', labelcolor=colors[0])
    
    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
    
    ax2.set_ylabel(y2_label, color=colors[1])  # we already handled the x-label with ax1
    ax2.plot(range(1, len(y21_s)+1), y21_s, styles[2], label='train loss')
    ax2.plot(range(1, len(y22_s)+1), y22_s, styles[3], label='valid. loss')
    ax2.tick_params(axis='y', labelcolor=colors[1])
    
    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    fig.legend(loc='right', bbox_to_anchor=(0.85, 0.5))
    plt.title(title)
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

def confusion_matrix_plot(conf_mat, cls, x_label, y_label, title, file_name=None):
    plt.imshow(conf_mat, interpolation='nearest', cmap=plt.cm.Wistia)
    plt.title(title)
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    tick_marks = np.arange(len(cls))
    plt.grid(False)
    plt.xticks(tick_marks, cls, rotation=45)
    plt.yticks(tick_marks, cls)
    
    for i in range(len(cls)):
        for j in range(len(cls)):
            plt.text(j - 0.2, i, str(conf_mat[i][j]), fontsize=16)
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

def class_distribution_hist(y_true, y_pred, cls, x_label, y_label, title, file_name=None):
    pd.Series([y_true, y_pred]).hist()
    plt.title(title)
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    tick_marks = np.arange(len(cls))
    plt.xticks(tick_marks, cls)
    plt.legend(labels=['Real', 'Predicted'], loc='best')
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

# %%
classes = ['hate speech', 'no hate']

# %%
plots([history.history['categorical_accuracy'],
       history.history['val_categorical_accuracy'],
       model.mc.val_f1s0,
       model.mc.val_f1s1],
      ['training acc.', 'validation acc.', 'no-hate f1 score', 'hate-speech f1 score'],
      ['-r', '--r', 'b', 'm'],
      title='Training progress', file_name='results/en_lstm/train_progress.png')

# %%
twinx_plot(history.history['categorical_accuracy'], history.history['val_categorical_accuracy'],
           history.history['loss'], history.history['val_loss'],
          x_label='Epoch', y1_label='Accuracy', y2_label='Loss', title='Accuracy & loss / epoch',
          file_name='results/en_lstm/acc_loss.png')

# %%
confusion_matrix_plot(conf_mat, cls=classes,
                      x_label='Real', y_label='Predicted',
                      title='Accuracy: {}'.format(round(acc, 2)),
                      file_name='results/en_lstm/cm.png')

# %%
class_distribution_hist(y_true, y_pred, cls=classes,
                        x_label='Classes', y_label='Cardinality', title='Real and pred. classes cards.',
                        file_name='results/en_lstm/cards.png')

# %%
with open('hsd/Reddit/perfect_data.pkl', 'rb') as f:
    texts, _ = pickle.load(f)
texts = texts[int(0.7*len(texts)):]

indices = [6, 10, 19, 26, 27, 28, 29, 164]
test_cases = []
for i, (t, p, l) in enumerate(zip(texts, y_pred, y_true)):
    if i in indices:
        test_cases.append({'Text': t, 'Prediction': p.numpy(), 'Label': l.numpy()})

# %%
def test_cases_board(test_cases, title, file_name=None):
    h = 20
    n = len(test_cases)
    fig, axis = plt.subplots(1, 1, figsize=(16., n*3.2))
    axis.axis('off')
    axis.set_xlim([0, 100])
    axis.set_ylim([0, n*h])
    axis.plot([0, 100], [0, 0], color='k')
    axis.plot([0, 0], [0, n*h], color='k')
    axis.plot([100, 100], [0, n*h], color='k')
    
    for i in range(n):
        axis.annotate('Tweet text:', xy=(4, 16 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        text = u'{}'.format(test_cases[i]['Text'].replace('\n', ''))
        text = '\n'.join([text[j:j+int(len(text)/3)] for j in range(0, len(text), int(len(text)/3))])
        axis.annotate(text, xy=(4, 7 + i*h), xycoords='data', size=15)
        
        axis.annotate('Prediction:', xy=(4, 4 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        pred = 'no hate' if test_cases[i]['Prediction'] == 0 else 'hate speech'
        pred_color = 'b' if pred == 'no hate' else 'm'
        axis.annotate(pred, xy=(15, 4 + i*h), xycoords='data', size=15, color=pred_color)
        
        axis.annotate('Label:', xy=(27, 4 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        label = 'no hate' if test_cases[i]['Label'] == 0 else 'hate speech'
        label_color = 'b' if label == 'no hate' else 'm'
        axis.annotate(label, xy=(34, 4 + i*h), xycoords='data', size=15, color=label_color)
        
        axis.annotate('Result:', xy=(50, 4 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        reason = 'OK' if pred == label else '1-st type error' if pred == 'no hate' else '2-nd type error'
        reason_color = 'g' if reason == 'OK' else 'r'
        axis.annotate(reason, xy=(57, 4 + i*h), xycoords='data', size=15, color=reason_color)
        
        axis.plot([0, 100], [20 + i*h, 20 + i*h], color='k')
    
    
    plt.title(title)
    if file_name:
        plt.savefig(file_name)
    plt.show()

# %%
test_cases_board(test_cases, title='Tweets summary', file_name='results/en_lstm/tweets_summary.png')

# %%
from tensorflow import keras
model = keras.models.load_model('models/en_lstm.model')

# %%
predictions_val = model.predict(word_seq_val)
y_val_pred = tf.argmax(predictions_val, axis=1)

# %%
validate_df['prediction'] = y_val_pred
validate_df.to_csv('hsd/Reddit/validate_final.csv')

# %%
y_val_pred.shape
# Out:
# TensorShape([162])

# %%
validate_df
# Out:
#                                                   text             user  \
# 6    Gamergate in 2014-2016 was a movement that sta...   KotakuInAction
# 9    Just seeing Lady Dimitrescu from RE:V makes me...   KotakuInAction
# 24   Just a heads up for those who want to know.  T...   KotakuInAction
# 30   The purpose of this operation is to translate ...   KotakuInAction
# 80   This idea popped into my head a couple of time...   KotakuInAction
# ..                                                 ...              ...
# 78   MARYLAND - A Talbot County nurse sneaks a leth...  PussyPassDenied
# 82   [https://youtu.be/ZoQoaljMKfc](https://youtu.b...  PussyPassDenied
# 105  BBC News - Paris mayor mocks 'absurd' fine for...  PussyPassDenied
# 190  Hey, my little reprobates. It's been a while. ...  PussyPassDenied
# 0    Just a quick reminder that **posts featuring R...   TumblrInAction
#
#                                        lemmatized_text  prediction
# 6    Gamergate movement start truly impassioned eye...           1
# 9    Just see Lady Dimitrescu RE V make happy But f...           1
# 24   Just head want know There reshuffle video cont...           1
# 30   The purpose operation translate GamerGate Wiki...           1
# 80   This idea pop head couple time past day play F...           1
# ..                                                 ...         ...
# 78   MARYLAND A Talbot County nurse sneak lethal do...           1
# 82   GREEN A woman sex teen student sentence Friday...           1
# 105     BBC News Paris mayor mock fine hire many woman           1
# 190  Hey little reprobate It I personal issue BUT I...           1
# 0    Just quick reminder post feature Reddit thread...           1
#
# [162 rows x 4 columns]
