# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import pickle

from sklearn.metrics import confusion_matrix, f1_score, precision_score, roc_auc_score

import keras
from keras import optimizers
from keras import backend as K
from keras import regularizers
from keras.models import Sequential
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.layers import Input, Embedding, Dense, Conv2D, MaxPool2D, AvgPool2D, Flatten, Concatenate, Reshape
from keras.utils import plot_model
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

from pymagnitude import *
from tqdm import tqdm
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer 
import os, re, csv, math, codecs

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %%
train_df = pd.read_csv('hsd/Reddit/train.csv', sep=',', header=0, index_col=0)
test_df = pd.read_csv('hsd/Reddit/test.csv', sep=',', header=0, index_col=0)
validate_df = pd.read_csv('hsd/Reddit/validate_reddit.csv', sep=',', header=0, index_col=0)
test_df = test_df.fillna('_NA_')

print("num train: ", train_df.shape[0])
print("num test: ", test_df.shape[0])

label_names = ['class']
y_train = list(map(lambda number: 1 if number[0] == 2 else 0, train_df[label_names].values.tolist()))
y_train = to_categorical(y_train)

y_test = list(map(lambda number: 1 if number[0] == 2 else 0, test_df[label_names].values.tolist()))
y_test = to_categorical(y_test)

#visualize word distribution
train_df['doc_len'] = train_df['lemmatized_text'].apply( lambda words: len(str(words).split()) )
max_seq_len = 50
sns.distplot(train_df['doc_len'], hist=True, kde=True, color='b', label='doc len')
plt.axvline(x=max_seq_len, color='k', linestyle='--', label='max len')
plt.title('comment length'); plt.legend()
plt.show()
# Out:
# num train:  38592
# num test:  16540

# %%
MAX_NB_WORDS = 100000

raw_docs_train = train_df['lemmatized_text'].apply(lambda words: str(words)).tolist()
raw_docs_test = test_df['lemmatized_text'].apply(lambda words: str(words)).tolist() 
raw_docs_validate = validate_df['lemmatized_text'].apply(lambda words: str(words)).tolist() 
num_classes = len(label_names)

print("tokenizing input data...")
tokenizer = Tokenizer(num_words=MAX_NB_WORDS, lower=True, char_level=False)
tokenizer.fit_on_texts(raw_docs_train + raw_docs_test + raw_docs_validate)  #leaky
word_seq_train = tokenizer.texts_to_sequences(raw_docs_train)
word_seq_test = tokenizer.texts_to_sequences(raw_docs_test)
word_seq_val = tokenizer.texts_to_sequences(raw_docs_validate)
word_index = tokenizer.word_index
print("dictionary size: ", len(word_index))

#pad sequences
word_seq_train = sequence.pad_sequences(word_seq_train, maxlen=max_seq_len)
word_seq_test = sequence.pad_sequences(word_seq_test, maxlen=max_seq_len)
word_seq_val = sequence.pad_sequences(word_seq_val, maxlen=max_seq_len)
# Out:
# tokenizing input data...
# dictionary size:  41407

# %%
#training params
batch_size = 256 
num_epochs = 20 

#model parameters
CONV_FILTER = (2, 4)
num_filters = 64 
embed_dim = 300 
weight_decay = 1e-4


# hyperparams
LAYERS = 2  # convolutional layers count
LR = 0.001  # learning rate
OPTIM = tf.keras.optimizers.Adam  # optimizer
EPOCHS = 10

# params
BATCH_SIZE = 100  # size of input batch
INIT = 'random_normal'  # trainable param initializer
CONV_FILTER = (2, 4)  # convolution filter
POOL_FILTER = (2, 4)  # pooling filter
POOL_STRIDE = (2, 4)  # pooling stride

#non-testing params
CHANNELS = 64  # convolutional layer channels
POOL = MaxPool2D  # pooling method

# %%
#embedding matrix
print('preparing embedding matrix...')
words_not_found = []
nb_words = min(MAX_NB_WORDS, len(word_index))
embedding_matrix = np.zeros((nb_words, embed_dim))
vecs = Magnitude(MagnitudeUtils.download_model('http://magnitude.plasticity.ai/fasttext/medium/crawl-300d-2M.magnitude'))
for word, i in word_index.items():
    if i >= nb_words:
        continue
    embedding_vector = vecs.query(word)
    if (embedding_vector is not None) and len(embedding_vector) > 0:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
    else:
        words_not_found.append(word)
print('number of null word embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# preparing embedding matrix...
# number of null word embeddings: 1

# %%
class MetricsCallback(Callback):
    def __init__(self):
        super(MetricsCallback, self).__init__()
        self.val_f1s0 = []
        self.val_f1s1 = []
    
    def on_epoch_end(self, epoch, logs={}):
        val_predict = np.asarray(tf.argmax(self.model.predict(word_seq_test), axis=1))
        val_true = np.asarray(tf.argmax(y_test, axis=1))
        c_m = confusion_matrix(val_true, val_predict, labels=[0, 1])
        self.val_f1s0.append(2*float(c_m[0][0])/(2*float(c_m[0][0]) + c_m[0][1] + c_m[1][0]))
        self.val_f1s1.append(2*float(c_m[1][1])/(2*float(c_m[1][1]) + c_m[1][0] + c_m[0][1]))

# %%
class ConvModel():
    def __init__(self, nb_words, embed_dim, embedding_matrix, max_seq_len, name='conv_model', **kwargs):
       
       # hyperparams
        self.layers = LAYERS if 'layers' not in kwargs else kwargs['layers']
        self.lr = LR if 'lr' not in kwargs else kwargs['lr']
        self.optim = OPTIM(learning_rate=self.lr) if 'optim' not in kwargs else kwargs['optim'](learning_rate=self.lr)
        self.epochs = EPOCHS if 'epochs' not in kwargs else kwargs['epochs']
        
        # params
        self.batch_size = BATCH_SIZE if 'batch_size' not in kwargs else kwargs['batch_size']
        self.init = INIT if 'init' not in kwargs else kwargs['init']
        self.channels = CHANNELS if 'channels' not in kwargs else kwargs['channels']
        self.conv_filter = CONV_FILTER if 'conv_filter' not in kwargs else kwargs['conv_filter']
        self.pool_filter = POOL_FILTER if 'pool_filter' not in kwargs else kwargs['pool_filter']
        self.pool_stride = POOL_STRIDE if 'pool_stride' not in kwargs else kwargs['pool_stride']
        self.pool = POOL if 'pool' not in kwargs else kwargs['pool']

        self.model = Sequential()
        self.model.add(Embedding(nb_words, embed_dim,
                    weights=[embedding_matrix], input_length=max_seq_len, trainable=False))
        self.model.add(Reshape((max_seq_len, int(embed_dim/3), 3), input_shape=(max_seq_len, embed_dim, )))
        self.model.add(Conv2D(self.channels, kernel_size = self.conv_filter,
                    activation='relu', name='wt_conv_1',
                    kernel_initializer = self.init, bias_initializer = self.init))

        for layer in range(self.layers)[1:]:
            self.model.add(Conv2D(self.channels, kernel_size = self.conv_filter,
                    activation='relu', name='wt_conv_{}'.format(layer+1),
                    kernel_initializer = self.init, bias_initializer = self.init))
                    
        self.model.add(self.pool(pool_size= self.pool_filter, strides= self.pool_stride, name='wt_pool'))
        self.model.add(Flatten(name='wt_flatten'))
        self.model.add(Dense(64, activation='relu', name='dense_1',
                    kernel_initializer='random_normal', bias_initializer='random_normal'))
        self.model.add(Dense(2, activation='softmax', name='predictions',
                    kernel_initializer='random_normal', bias_initializer='random_normal'))

        self.name = name
        self.mc = MetricsCallback()

    def summary(self):
        return self.model.summary()
    
    def compile(self):
        self.model.compile(optimizer=self.optim,
                           loss=tf.keras.losses.CategoricalCrossentropy(),
                           metrics=[tf.keras.metrics.CategoricalAccuracy()])
    
    def fit(self, X_tr, y_tr, X_ev, y_ev):
        return self.model.fit(X_tr, y_tr, batch_size=self.batch_size, epochs=self.epochs,
                              validation_data=(X_ev, y_ev), callbacks=[self.mc])
    
    def predict(self, X_t):
        return self.model.predict(X_t)
    
    def save(self, file_name):
        self.model.save(file_name)

# %%
def models_comparison_bars(df, title, interval=2, save_file=None):
    fig, axs = plt.subplots(1, 3, figsize=(16, 4))
    
    labels = [i+1 if i%interval == 0 else '' for i in range(len(df))]
    x = range(len(labels))
    acc = df['acc'].values
    f1s0 = df['f1s0'].values
    f1s1 = df['f1s1'].values
    
    max_acc_id = np.argmax(acc)
    max_f1s0_id = np.argmax(f1s0)
    max_f1s1_id = np.argmax(f1s1)
    
    axs[0].bar(x, acc, color='r')
    axs[0].set_xlabel('Model number')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xticks(x)
    axs[0].set_xticklabels(labels)
    axs[0].set_ylim([0, 1])
    axs[0].set_title('Accuracy | max ({}) at: {}'.format(np.round(np.max(acc), 2), max_acc_id+1))
    axs[0].patches[max_acc_id].set_facecolor('g')
    
    axs[1].bar(x, f1s0, color='b')
    axs[1].set_xlabel('Model number')
    axs[1].set_ylabel('F1 score (no hate)')
    axs[1].set_title('F1 score (no hate) | max ({}) at: {}'.format(np.round(np.max(f1s0), 2), max_f1s0_id+1))
    axs[1].set_xticks(x)
    axs[1].set_xticklabels(labels)
    axs[1].set_ylim([0, 1])
    axs[1].patches[max_f1s0_id].set_facecolor('g')
    
    axs[2].bar(x, f1s1, color='m')
    axs[2].set_xlabel('Model number')
    axs[2].set_ylabel('F1 score (hate speech)')
    axs[2].set_title('F1 score (hate speech) | max ({}) at: {}'.format(np.round(np.max(f1s1), 2),
                                                                       max_f1s1_id+1))
    axs[2].set_xticks(x)
    axs[2].set_xticklabels(labels)
    axs[2].set_ylim([0, 1])
    axs[2].patches[max_f1s1_id].set_facecolor('g')
    
    fig.suptitle(title)
    
    if save_file:
        plt.savefig(save_file)
    plt.show()

# %%
def get_hyperparams_options(layers_options = [1, 2], lr_options = [0.01, 0.001],
                            optim_options = [tf.keras.optimizers.Adam, tf.keras.optimizers.SGD],
                            epochs_options = [5, 10, 15]):
    hp_options = []
    for epochs in [epochs_options[-1]]:  # changed to process 15 epochs (eval. after each 5)
        for lr in lr_options:
            for optim in optim_options:
                for layer in layers_options:
                    hp_options.append({'lr': lr, 'optim': optim, 'epochs': epochs, 'layers': layer})
    return hp_options

# %%
def find_hyper_parameters(options, shape, save_path = 'results/en_conv/hyperparams_research.csv', epochs_options = [5, 10, 15]):    
    if not os.path.exists(save_path):
        hp_results = []
        for i, opts in enumerate(options):
            print('\nResearching for {}/{} | Hyperparams: {}\n'.format(i+1, len(hp_options), opts))

            hp_model = ConvModel(nb_words, embed_dim, embedding_matrix, max_seq_len, **opts)
            hp_model.compile()
            hp_history = hp_model.fit(word_seq_train, y_train, word_seq_test, y_test)

            # append means for 5, 10 and 15 epochs
            for eps in epochs_options:
                hp_results.append({'acc': np.mean(hp_history.history['categorical_accuracy'][:eps]),
                                   'val_acc': np.mean(hp_history.history['val_categorical_accuracy'][:eps]),
                                   'loss': np.mean(hp_history.history['val_loss'][:eps]),
                                   'f1s0': np.mean(hp_model.mc.val_f1s0[:eps]),
                                   'f1s1': np.mean(hp_model.mc.val_f1s1[:eps])})

        hp_results_df = pd.DataFrame(hp_results)
        hp_results_df.to_csv(save_path)
    else:
        hp_results_df = pd.read_csv(save_path, index_col=0)
    return hp_results_df

# %%
hp_options = get_hyperparams_options()
hp_results_df = find_hyper_parameters(options = hp_options, shape=(50, 100, 3, ))
# Out:
#  - val_loss: 0.6295 - val_categorical_accuracy: 0.8063
# Epoch 15/15
# 386/386 [==============================] - 8s 21ms/step - loss: 0.2380 - categorical_accuracy: 0.9005 - val_loss: 0.6958 - val_categorical_accuracy: 0.8042
#
# Researching for 2/8 | Hyperparams: {'lr': 0.01, 'optim': <class 'tensorflow.python.keras.optimizer_v2.adam.Adam'>, 'epochs': 15, 'layers': 2}
#
# Epoch 1/15
#   6/386 [..............................] - ETA: 19s - loss: 3.9030 - categorical_accuracy: 0.4597WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0146s vs `on_train_batch_end` time: 0.0338s). Check your callbacks.
# 386/386 [==============================] - 25s 61ms/step - loss: 0.8522 - categorical_accuracy: 0.6273 - val_loss: 0.6544 - val_categorical_accuracy: 0.6398
# Epoch 2/15
# 386/386 [==============================] - 23s 59ms/step - loss: 0.6522 - categorical_accuracy: 0.6433 - val_loss: 0.6537 - val_categorical_accuracy: 0.6398
# Epoch 3/15
# 386/386 [==============================] - 23s 59ms/step - loss: 0.6548 - categorical_accuracy: 0.6382 - val_loss: 0.6542 - val_categorical_accuracy: 0.6398
# Epoch 4/15
# 386/386 [==============================] - 23s 59ms/step - loss: 0.6551 - categorical_accuracy: 0.6379 - val_loss: 0.6537 - val_categorical_accuracy: 0.6398
# Epoch 5/15
# 386/386 [==============================] - 23s 59ms/step - loss: 0.6542 - categorical_accuracy: 0.6390 - val_loss: 0.6535 - val_categorical_accuracy: 0.6398
# Epoch 6/15
# 386/386 [==============================] - 23s 59ms/step - loss: 0.6526 - categorical_accuracy: 0.6420 - val_loss: 0.6535 - val_categorical_accuracy: 0.6398
# Epoch 7/15
# 386/386 [==============================] - 23s 59ms/step - loss: 0.6538 - categorical_accuracy: 0.6397 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 8/15
# 386/386 [==============================] - 23s 59ms/step - loss: 0.6534 - categorical_accuracy: 0.6404 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 9/15
# 386/386 [==============================] - 23s 59ms/step - loss: 0.6536 - categorical_accuracy: 0.6398 - val_loss: 0.6541 - val_categorical_accuracy: 0.6398
# Epoch 10/15
# 386/386 [==============================] - 23s 59ms/step - loss: 0.6541 - categorical_accuracy: 0.6396 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 11/15
# 386/386 [==============================] - 23s 59ms/step - loss: 0.6547 - categorical_accuracy: 0.6384 - val_loss: 0.6535 - val_categorical_accuracy: 0.6398
# Epoch 12/15
# 386/386 [==============================] - 23s 59ms/step - loss: 0.6536 - categorical_accuracy: 0.6398 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch
# Epoch 15/15
# 386/386 [==============================] - 8s 20ms/step - loss: 0.6422 - categorical_accuracy: 0.6400 - val_loss: 0.6399 - val_categorical_accuracy: 0.6398
#
# Researching for 4/8 | Hyperparams: {'lr': 0.01, 'optim': <class 'tensorflow.python.keras.optimizer_v2.gradient_descent.SGD'>, 'epochs': 15, 'layers': 2}
#
# Epoch 1/15
#   6/386 [..............................] - ETA: 20s - loss: 0.7086 - categorical_accuracy: 0.3975WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0145s vs `on_train_batch_end` time: 0.0380s). Check your callbacks.
# 386/386 [==============================] - 24s 60ms/step - loss: 0.6616 - categorical_accuracy: 0.6190 - val_loss: 0.6533 - val_categorical_accuracy: 0.6398
# Epoch 2/15
# 386/386 [==============================] - 23s 60ms/step - loss: 0.6567 - categorical_accuracy: 0.6342 - val_loss: 0.6530 - val_categorical_accuracy: 0.6398
# Epoch 3/15
# 386/386 [==============================] - 23s 60ms/step - loss: 0.6516 - categorical_accuracy: 0.6420 - val_loss: 0.6524 - val_categorical_accuracy: 0.6398
# Epoch 4/15
# 386/386 [==============================] - 23s 60ms/step - loss: 0.6528 - categorical_accuracy: 0.6391 - val_loss: 0.6521 - val_categorical_accuracy: 0.6398
# Epoch 5/15
# 386/386 [==============================] - 23s 60ms/step - loss: 0.6528 - categorical_accuracy: 0.6388 - val_loss: 0.6521 - val_categorical_accuracy: 0.6398
# Epoch 6/15
# 386/386 [==============================] - 23s 60ms/step - loss: 0.6510 - categorical_accuracy: 0.6407 - val_loss: 0.6506 - val_categorical_accuracy: 0.6398
# Epoch 7/15
# 386/386 [==============================] - 23s 60ms/step - loss: 0.6527 - categorical_accuracy: 0.6366 - val_loss: 0.6500 - val_categorical_accuracy: 0.6398
# Epoch 8/15
# 386/386 [==============================] - 23s 60ms/step - loss: 0.6509 - categorical_accuracy: 0.6381 - val_loss: 0.6491 - val_categorical_accuracy: 0.6398
# Epoch 9/15
# 386/386 [==============================] - 23s 60ms/step - loss: 0.6466 - categorical_accuracy: 0.6446 - val_loss: 0.6507 - val_categorical_accuracy: 0.6398
# Epoch 10/15
# 386/386 [==============================] - 23s 60ms/step - loss: 0.6468 - categorical_accuracy: 0.6429 - val_loss: 0.6480 - val_categorical_accuracy: 0.6398
# Epoch 11/15
# 386/386 [==============================] - 23s 60ms/step - loss: 0.6482 - categorical_accuracy: 0.6387 - val_loss: 0.6456 - val_categorical_accuracy: 0.6398
# Epoch 12/15
# 386/386 [==============================] - 23s 60ms/step - loss: 0.6454 - categorical_accuracy: 0.6420 - val_loss: 0.6441 - val_categorical_accuracy: 0.6398
# Epoch 13/15
# 386/386 [==============================] - 23s 60ms/step - loss: 0.6446 - categorical_accuracy: 0.6399 - val_loss: 0.6423 - val_categorical_accuracy: 0.6398
# Epoch 14/15
# 386/386 [==============================] - 23s 60ms/step - loss: 0.6422 - categorical_accuracy: 0.6408 - val_loss: 0.6389 - val_categorical_accuracy: 0.6398
# Epoch 15/15
# 386/386 [==============================] - 23s 60ms/step - loss: 0.6392 - categorical_accuracy: 0.6408 - val_loss: 0.6350 - val_categorical_accuracy: 0.6400
#
# Researching for 5/8 | Hyperparams: {'lr': 0.001, 'optim': <class 'tensorflow.python.keras.optimizer_v2.adam.Adam'>, 'epochs': 15, 'layers': 1}
#
# Epoch 1/15
# 386/386 [==============================] - 9s 22ms/step - loss: 0.6199 - categorical_accuracy: 0.6671 - val_loss: 0.4662 - val_categorical_accuracy: 0.7892
# Epoch 2/15
# 386/386 [==============================] - 8s 21ms/step - loss: 0.4392 - categorical_accuracy: 0.8090 - val_loss: 0.4360 - val_categorical_accuracy: 0.8159
# Epoch 3/15
# 386/386 [==============================] - 8s 20ms/step - loss: 0.3919 - categorical_accuracy: 0.8349 - val_loss: 0.4026 - val_categorical_accuracy: 0.8338
# Epoch 4/15
# Epoch 12/15
# 386/386 [==============================] - 27s 70ms/step - loss: 0.6541 - categorical_accuracy: 0.6376 - val_loss: 0.6527 - val_categorical_accuracy: 0.6398
# Epoch 13/15
# 386/386 [==============================] - 27s 71ms/step - loss: 0.6512 - categorical_accuracy: 0.6424 - val_loss: 0.6527 - val_categorical_accuracy: 0.6398
# Epoch 14/15
# 386/386 [==============================] - 27s 71ms/step - loss: 0.6521 - categorical_accuracy: 0.6409 - val_loss: 0.6526 - val_categorical_accuracy: 0.6398
# Epoch 15/15
# 386/386 [==============================] - 27s 71ms/step - loss: 0.6535 - categorical_accuracy: 0.6382 - val_loss: 0.6526 - val_categorical_accuracy: 0.6398

# %%
pd.DataFrame(hp_options).head()
# Out:
#       lr                                              optim  epochs  layers
# 0  0.010  <class 'tensorflow.python.keras.optimizer_v2.a...      15       1
# 1  0.010  <class 'tensorflow.python.keras.optimizer_v2.a...      15       2
# 2  0.010  <class 'tensorflow.python.keras.optimizer_v2.g...      15       1
# 3  0.010  <class 'tensorflow.python.keras.optimizer_v2.g...      15       2
# 4  0.001  <class 'tensorflow.python.keras.optimizer_v2.a...      15       1

# %%
models_comparison_bars(hp_results_df, title='Hyperparams research', interval=10,
                       save_file='results/en_conv/hyperparams_research.png')

# %%
best_h_num = 18
'Best one: {} with {} run epochs'.format(hp_options[int((best_h_num-1)/3)],
                                         ((best_h_num-1)%3)*5 if (best_h_num-1)%3 != 0 else 15)
# Out:
# "Best one: {'lr': 0.001, 'optim': <class 'tensorflow.python.keras.optimizer_v2.adam.Adam'>, 'epochs': 15, 'layers': 2} with 10 run epochs"

# %%
def get_params_options(batch_size_options = [100, 200],
                       init_options = ['random_normal'],
                       conv_filter_options = [(1, 2), (2, 4)],
                       pool_filter_options = [(1, 2), (2, 4)],
                       pool_stride_options = [(1, 2), (2, 4)]):

    p_options = []
    for batch_size in batch_size_options:
        for init in init_options:
            for conv_filter in conv_filter_options:
                for pool_filter in pool_filter_options:
                    for pool_stride in pool_stride_options:
                        p_options.append({'batch_size': batch_size,
                                        'init': init,
                                        'conv_filter': conv_filter,
                                        'pool_filter': pool_filter,
                                        'pool_stride': pool_stride})
    return p_options

# %%
p_options = get_params_options()
pd.DataFrame(p_options).head()
# Out:
#    batch_size           init conv_filter pool_filter pool_stride
# 0         100  random_normal      (1, 2)      (1, 2)      (1, 2)
# 1         100  random_normal      (1, 2)      (1, 2)      (2, 4)
# 2         100  random_normal      (1, 2)      (2, 4)      (1, 2)
# 3         100  random_normal      (1, 2)      (2, 4)      (2, 4)
# 4         100  random_normal      (2, 4)      (1, 2)      (1, 2)

# %%
def find_parameters(options, shape, save_path = 'results/en_conv/params_research.csv', epochs_options = [5, 10, 15]):
    if not os.path.exists(save_path):
        p_results = []
        for i, opts in enumerate(p_options):
            print('\nResearching for {}/{} | Params: {}\n'.format(i+1, len(p_options), opts))

            p_model = ConvModel(nb_words, embed_dim, embedding_matrix, max_seq_len, **opts)
            p_model.compile()
            p_history = p_model.fit(word_seq_train, y_train, word_seq_test, y_test)

            p_results.append({'acc': np.mean(p_history.history['categorical_accuracy']),
                            'val_acc': np.mean(p_history.history['val_categorical_accuracy']),
                            'loss': np.mean(p_history.history['val_loss']),
                            'f1s0': np.mean(p_model.mc.val_f1s0),
                            'f1s1': np.mean(p_model.mc.val_f1s1)})
        
        p_results_df = pd.DataFrame(p_results)
        p_results_df.to_csv(save_path)
    else:
        p_results_df = pd.read_csv(save_path, index_col=0)
    return p_results_df

# %%
p_results_df = find_parameters(options = p_options, shape = (12, 300, ))
# Out:
#  val_loss: 0.2738 - val_categorical_accuracy: 0.9010
# Epoch 5/10
# 386/386 [==============================] - 30s 78ms/step - loss: 0.2103 - categorical_accuracy: 0.9248 - val_loss: 0.2892 - val_categorical_accuracy: 0.8918
# Epoch 6/10
# 386/386 [==============================] - 30s 78ms/step - loss: 0.1780 - categorical_accuracy: 0.9366 - val_loss: 0.2946 - val_categorical_accuracy: 0.8937
# Epoch 7/10
# 386/386 [==============================] - 31s 79ms/step - loss: 0.1512 - categorical_accuracy: 0.9489 - val_loss: 0.3164 - val_categorical_accuracy: 0.8894
# Epoch 8/10
# 386/386 [==============================] - 30s 79ms/step - loss: 0.1356 - categorical_accuracy: 0.9536 - val_loss: 0.3471 - val_categorical_accuracy: 0.8857
# Epoch 9/10
# 386/386 [==============================] - 30s 79ms/step - loss: 0.1188 - categorical_accuracy: 0.9611 - val_loss: 0.3970 - val_categorical_accuracy: 0.8927
# Epoch 10/10
# 386/386 [==============================] - 30s 78ms/step - loss: 0.1037 - categorical_accuracy: 0.9642 - val_loss: 0.4052 - val_categorical_accuracy: 0.8852
#
# Researching for 8/16 | Params: {'batch_size': 100, 'init': 'random_normal', 'conv_filter': (2, 4), 'pool_filter': (2, 4), 'pool_stride': (2, 4)}
#
# Epoch 1/10
#   6/386 [..............................] - ETA: 24s - loss: 0.7127 - categorical_accuracy: 0.5174WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0179s vs `on_train_batch_end` time: 0.0469s). Check your callbacks.
# 386/386 [==============================] - 28s 72ms/step - loss: 0.6233 - categorical_accuracy: 0.6614 - val_loss: 0.3723 - val_categorical_accuracy: 0.8360
# Epoch 2/10
# 386/386 [==============================] - 28s 72ms/step - loss: 0.3504 - categorical_accuracy: 0.8544 - val_loss: 0.2955 - val_categorical_accuracy: 0.8817
# Epoch 3/10
# 386/386 [==============================] - 28s 71ms/step - loss: 0.2707 - categorical_accuracy: 0.8983 - val_loss: 0.3065 - val_categorical_accuracy: 0.8855
# Epoch 4/10
# 386/386 [==============================] - 28s 72ms/step - loss: 0.2448 - categorical_accuracy: 0.9091 - val_loss: 0.2819 - val_categorical_accuracy: 0.8952
# Epoch 5/10
# 386/386 [==============================] - 28s 71ms/step - loss: 0.2142 - categorical_accuracy: 0.9226 - val_loss: 0.2900 - val_categorical_accuracy: 0.8929
# Epoch 6/10
# 386/386 [==============================] - 28s 72ms/step - loss: 0.1805 - categorical_accuracy: 0.9356 - val_loss: 0.3050 - val_categorical_accuracy: 0.8907
# Epoch 7/10
# 386/386 [==============================] - 27s 71ms/step - loss: 0.1595 - categorical_accuracy: 0.9440 - val_loss: 0.3227 - val_categorical_accuracy: 0.8889
# Epoch 8/10
# 386/386 [==============================] - 28s 72ms/step - loss: 0.1386 - categorical_accuracy: 0.9536 - val_loss: 0.3506 - val_categorical_accuracy: 0.8865
# Epoch 9/10
# 386/386 [==============================] - 27s 71ms/step - loss: 0.1155 - categorical_accuracy: 0.9621 - val_loss: 0.4283 - val_categorical_accuracy: 0.8860
# Epoch 10/10
# 386/386 [==============================] - 28s 71ms/step - loss: 0.1015 - categorical_accuracy: 0.9670 - val_loss: 0.4133 - val_categorical_accuracy: 0.8747
#
# Researching for 9/16 | Params: {'batch_size': 200, 'init': 'random_normal', 'conv_filter': (1, 2), 'pool_filter': (1, 2), 'pool_stride': (1, 2)}
#
# Epoch 1/10
#   6/193 [..............................] - ETA: 13s - loss: 0.8046 - categorical_accuracy: 0.5075WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0153s vs `on_train_batch_end` time: 0.0462s). Check your callbacks.
# 193/193 [==============================] - 18s 86ms/step - loss: 0.6733 - categorical_accuracy: 0.6275 - val_loss: 0.6534 - val_categorical_accuracy: 0.6398
# Epoch 2/10
# 193/193 [==============================] - 15s 78ms/step - loss: 0.6544 - categorical_accuracy: 0.6399 - val_loss: 0.6266 - val_categorical_accuracy: 0.6398
# Epoch 3/10
# 193/193 [==============================] - 15s 77ms/step - loss: 0.5561 - categorical_accuracy: 0.6989 - val_loss: 0.4240 - val_categorical_accuracy: 0.8133
# Epoch 4/10
# 193/193 [==============================] - 15s 79ms/step - loss: 0.3735 - categorical_accuracy: 0.8385 - val_loss: 0.3568 - val_categorical_accuracy: 0.8545
# Epoch 5/10
# 193/193 [==============================] - 15s 77ms/step - loss: 0.2998 - categorical_accuracy: 0.8803 - val_loss: 0.3262 - val_categorical_accuracy: 0.8673
# Epoch 6/10
# 193/193 [==============================] - 15s 78ms/step - loss: 0.2532 - categorical_accuracy: 0.9026 - val_loss: 0.3288 - val_categorical_accuracy: 0.8696
# Epoch 7/10
# 193/193 [==============================] - 15s 78ms/step - loss: 0.2094 - categorical_accuracy: 0.9235 - val_loss: 0.3502 - val_categorical_accuracy: 0.8620
# Epoch 8/10
# 193/193 [==============================] - 15s 77ms/step - loss: 0.1902 - categorical_accuracy: 0.9322 - val_loss: 0.3612 - val_categorical_accuracy: 0.8678
# Epoch 9/10
# 193/193 [==============================] - 15s 77ms/step - loss: 0.1545 - categorical_accuracy: 0.9472 - val_loss: 0.3688 - val_categorical_accuracy: 0.8681
# Epoch 10/10
# 193/193 [==============================] - 15s 78ms/step - loss: 0.1413 - categorical_accuracy: 0.9527 - val_loss: 0.4081 - val_categorical_accuracy: 0.8660
#
# Researching for 10/16 | Params: {'batch_size': 200, 'init': 'random_normal', 'conv_filter': (1, 2), 'pool_filter': (1, 2), 'pool_stride': (2, 4)}
#
# Epoch 1/10
#   6/193 [..............................] - ETA: 11s - loss: 0.6867 - categorical_accuracy: 0.5212WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.
# 193/193 [==============================] - 16s 83ms/step - loss: 0.2503 - categorical_accuracy: 0.9042 - val_loss: 0.3005 - val_categorical_accuracy: 0.8843
# Epoch 8/10
# 193/193 [==============================] - 16s 81ms/step - loss: 0.2232 - categorical_accuracy: 0.9197 - val_loss: 0.3070 - val_categorical_accuracy: 0.8870
# Epoch 9/10
# 193/193 [==============================] - 16s 81ms/step - loss: 0.2058 - categorical_accuracy: 0.9260 - val_loss: 0.3132 - val_categorical_accuracy: 0.8848
# Epoch 10/10
# 193/193 [==============================] - 16s 80ms/step - loss: 0.1907 - categorical_accuracy: 0.9319 - val_loss: 0.3221 - val_categorical_accuracy: 0.8839
#
# Researching for 12/16 | Params: {'batch_size': 200, 'init': 'random_normal', 'conv_filter': (1, 2), 'pool_filter': (2, 4), 'pool_stride': (2, 4)}
#
# Epoch 1/10
#   6/193 [..............................] - ETA: 11s - loss: 0.6773 - categorical_accuracy: 0.5446WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0136s vs `on_train_batch_end` time: 0.0482s). Check your callbacks.
# 193/193 [==============================] - 14s 69ms/step - loss: 0.6589 - categorical_accuracy: 0.6314 - val_loss: 0.6483 - val_categorical_accuracy: 0.6398
# Epoch 2/10
# 193/193 [==============================] - 13s 68ms/step - loss: 0.6118 - categorical_accuracy: 0.6686 - val_loss: 0.4167 - val_categorical_accuracy: 0.8117
# Epoch 3/10
# 193/193 [==============================] - 13s 68ms/step - loss: 0.3976 - categorical_accuracy: 0.8263 - val_loss: 0.3481 - val_categorical_accuracy: 0.8550
# Epoch 4/10
# 193/193 [==============================] - 13s 68ms/step - loss: 0.3290 - categorical_accuracy: 0.8625 - val_loss: 0.3186 - val_categorical_accuracy: 0.8741
# Epoch 5/10
# 193/193 [==============================] - 13s 68ms/step - loss: 0.2864 - categorical_accuracy: 0.8894 - val_loss: 0.3157 - val_categorical_accuracy: 0.8759
# Epoch 6/10
# 193/193 [==============================] - 13s 69ms/step - loss: 0.2559 - categorical_accuracy: 0.9025 - val_loss: 0.2998 - val_categorical_accuracy: 0.8841
# Epoch 7/10
# 193/193 [==============================] - 13s 68ms/step - loss: 0.2357 - categorical_accuracy: 0.9123 - val_loss: 0.3068 - val_categorical_accuracy: 0.8791
# Epoch 8/10
# 193/193 [==============================] - 13s 68ms/step - loss: 0.2151 - categorical_accuracy: 0.9210 - val_loss: 0.3144 - val_categorical_accuracy: 0.8852
# Epoch 9/10
# 193/193 [==============================] - 13s 68ms/step - loss: 0.1985 - categorical_accuracy: 0.9274 - val_loss: 0.3160 - val_categorical_accuracy: 0.8845
# Epoch 10/10
# 193/193 [==============================] - 13s 68ms/step - loss: 0.1751 - categorical_accuracy: 0.9388 - val_loss: 0.3427 - val_categorical_accuracy: 0.8755
#
# Researching for 13/16 | Params: {'batch_size': 200, 'init': 'random_normal', 'conv_filter': (2, 4), 'pool_filter': (1, 2), 'pool_stride': (1, 2)}
#
# Epoch 1/10
#   6/193 [..............................] - ETA: 24s - loss: 0.9469 - categorical_accuracy: 0.5323WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.
# 193/193 [==============================] - 26s 136ms/step - loss: 0.3303 - categorical_accuracy: 0.8675 - val_loss: 0.4178 - val_categorical_accuracy: 0.8297
# Epoch 8/10
# 193/193 [==============================] - 26s 136ms/step - loss: 0.3124 - categorical_accuracy: 0.8753 - val_loss: 0.4305 - val_categorical_accuracy: 0.8294
# Epoch 9/10
# 193/193 [==============================] - 26s 137ms/step - loss: 0.2896 - categorical_accuracy: 0.8878 - val_loss: 0.4379 - val_categorical_accuracy: 0.8279
# Epoch 10/10
# 193/193 [==============================] - 26s 136ms/step - loss: 0.2721 - categorical_accuracy: 0.8951 - val_loss: 0.4583 - val_categorical_accuracy: 0.8273
#
# Researching for 15/16 | Params: {'batch_size': 200, 'init': 'random_normal', 'conv_filter': (2, 4), 'pool_filter': (2, 4), 'pool_stride': (1, 2)}
#
# Epoch 1/10
#   6/193 [..............................] - ETA: 24s - loss: 0.8170 - categorical_accuracy: 0.4896WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0347s vs `on_train_batch_end` time: 0.0991s). Check your callbacks.
# 193/193 [==============================] - 29s 151ms/step - loss: 0.6751 - categorical_accuracy: 0.6158 - val_loss: 0.6332 - val_categorical_accuracy: 0.6398
# Epoch 2/10
# 193/193 [==============================] - 29s 150ms/step - loss: 0.5715 - categorical_accuracy: 0.6977 - val_loss: 0.4042 - val_categorical_accuracy: 0.8195
# Epoch 3/10
# 193/193 [==============================] - 30s 153ms/step - loss: 0.3826 - categorical_accuracy: 0.8362 - val_loss: 0.3265 - val_categorical_accuracy: 0.8657
# Epoch 4/10
# 193/193 [==============================] - 30s 157ms/step - loss: 0.3102 - categorical_accuracy: 0.8781 - val_loss: 0.2993 - val_categorical_accuracy: 0.8853
# Epoch 5/10
# 193/193 [==============================] - 31s 159ms/step - loss: 0.2695 - categorical_accuracy: 0.8984 - val_loss: 0.2865 - val_categorical_accuracy: 0.8922
# Epoch 6/10
# 193/193 [==============================] - 31s 159ms/step - loss: 0.2423 - categorical_accuracy: 0.9103 - val_loss: 0.2978 - val_categorical_accuracy: 0.8928
# Epoch 7/10
# 193/193 [==============================] - 31s 159ms/step - loss: 0.2125 - categorical_accuracy: 0.9230 - val_loss: 0.2937 - val_categorical_accuracy: 0.8924
# Epoch 8/10
# 193/193 [==============================] - 31s 159ms/step - loss: 0.1862 - categorical_accuracy: 0.9357 - val_loss: 0.3008 - val_categorical_accuracy: 0.8879
# Epoch 9/10
# 193/193 [==============================] - 31s 159ms/step - loss: 0.1654 - categorical_accuracy: 0.9400 - val_loss: 0.3429 - val_categorical_accuracy: 0.8900
# Epoch 10/10
# 193/193 [==============================] - 31s 159ms/step - loss: 0.1477 - categorical_accuracy: 0.9490 - val_loss: 0.3512 - val_categorical_accuracy: 0.8738
#
# Researching for 16/16 | Params: {'batch_size': 200, 'init': 'random_normal', 'conv_filter': (2, 4), 'pool_filter': (2, 4), 'pool_stride': (2, 4)}
#
# Epoch 1/10
#   6/193 [..............................] - ETA: 22s - loss: 0.7154 - categorical_accuracy: 0.5021WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0302s vs `on_train_batch_end` time: 0.0923s). Check your callbacks.
# 193/193 [==============================] - 29s 146ms/step - loss: 0.6596 - categorical_accuracy: 0.6292 - val_loss: 0.5111 - val_categorical_accuracy: 0.7505
# Epoch 2/10
# 193/193 [==============================] - 27s 142ms/step - loss: 0.4739 - categorical_accuracy: 0.7757 - val_loss: 0.3595 - val_categorical_accuracy: 0.8477
# Epoch 3/10
# 193/193 [==============================] - 26s 137ms/step - loss: 0.3342 - categorical_accuracy: 0.8615 - val_loss: 0.3339 - val_categorical_accuracy: 0.8649
# Epoch 4/10
# 193/193 [==============================] - 26s 136ms/step - loss: 0.2916 - categorical_accuracy: 0.8841 - val_loss: 0.2921 - val_categorical_accuracy: 0.8869
# Epoch 5/10
# 193/193 [==============================] - 26s 136ms/step - loss: 0.2536 - categorical_accuracy: 0.9037 - val_loss: 0.2896 - val_categorical_accuracy: 0.8911
# Epoch 6/10
# 193/193 [==============================] - 26s 135ms/step - loss: 0.2266 - categorical_accuracy: 0.9186 - val_loss: 0.3009 - val_categorical_accuracy: 0.8848
# Epoch 7/10
# 193/193 [==============================] - 26s 136ms/step - loss: 0.2115 - categorical_accuracy: 0.9244 - val_loss: 0.2943 - val_categorical_accuracy: 0.8928
# Epoch 8/10
# 193/193 [==============================] - 26s 136ms/step - loss: 0.1890 - categorical_accuracy: 0.9326 - val_loss: 0.3140 - val_categorical_accuracy: 0.8909
# Epoch 9/10
# 193/193 [==============================] - 26s 135ms/step - loss: 0.1663 - categorical_accuracy: 0.9413 - val_loss: 0.3311 - val_categorical_accuracy: 0.8896
# Epoch 10/10
# 193/193 [==============================] - 26s 135ms/step - loss: 0.1528 - categorical_accuracy: 0.9484 - val_loss: 0.3428 - val_categorical_accuracy: 0.8804

# %%
p_results_df.head()
# Out:
#         acc   val_acc      loss      f1s0      f1s1
# 0  0.859997  0.834262  0.421080  0.718408  0.876908
# 1  0.785588  0.767013  0.528314  0.627301  0.830259
# 2  0.867563  0.855593  0.364679  0.747231  0.893994
# 3  0.889778  0.875683  0.342720  0.816503  0.905674
# 4  0.905421  0.862116  0.387006  0.798608  0.894380

# %%
models_comparison_bars(p_results_df, title='Params research', interval=5,
                       save_file='results/en_conv/params_research.png')

# %%
best_num = 8
'Best one: {}'.format(p_options[best_num-1])
# Out:
# "Best one: {'batch_size': 100, 'init': 'random_normal', 'conv_filter': (2, 4), 'pool_filter': (2, 4), 'pool_stride': (2, 4)}"

# %%
model = ConvModel(nb_words, embed_dim, embedding_matrix, max_seq_len)
model.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_24 (Embedding)     (None, 50, 300)           12422100
# _________________________________________________________________
# reshape_24 (Reshape)         (None, 50, 100, 3)        0
# _________________________________________________________________
# wt_conv_1 (Conv2D)           (None, 49, 97, 64)        1600
# _________________________________________________________________
# wt_conv_2 (Conv2D)           (None, 48, 94, 64)        32832
# _________________________________________________________________
# wt_pool (MaxPooling2D)       (None, 24, 23, 64)        0
# _________________________________________________________________
# wt_flatten (Flatten)         (None, 35328)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2261056
# _________________________________________________________________
# predictions (Dense)          (None, 2)                 130
# =================================================================
# Total params: 14,717,718
# Trainable params: 2,295,618
# Non-trainable params: 12,422,100
# _________________________________________________________________

# %%
model.compile()
history = model.fit(word_seq_train, y_train, word_seq_test, y_test)
model.save('models/en_conv.model')
# Out:
# Epoch 1/10
#   6/386 [..............................] - ETA: 22s - loss: 0.7515 - categorical_accuracy: 0.6333WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0160s vs `on_train_batch_end` time: 0.0436s). Check your callbacks.
# 386/386 [==============================] - 26s 66ms/step - loss: 0.6616 - categorical_accuracy: 0.6312 - val_loss: 0.5278 - val_categorical_accuracy: 0.7469
# Epoch 2/10
# 386/386 [==============================] - 25s 65ms/step - loss: 0.4897 - categorical_accuracy: 0.7839 - val_loss: 0.3869 - val_categorical_accuracy: 0.8541
# Epoch 3/10
# 386/386 [==============================] - 25s 65ms/step - loss: 0.3693 - categorical_accuracy: 0.8593 - val_loss: 0.3330 - val_categorical_accuracy: 0.8802
# Epoch 4/10
# 386/386 [==============================] - 23s 60ms/step - loss: 0.3158 - categorical_accuracy: 0.8870 - val_loss: 0.3049 - val_categorical_accuracy: 0.8912
# Epoch 5/10
# 386/386 [==============================] - 23s 60ms/step - loss: 0.2714 - categorical_accuracy: 0.9036 - val_loss: 0.2877 - val_categorical_accuracy: 0.8946
# Epoch 6/10
# 386/386 [==============================] - 27s 70ms/step - loss: 0.2343 - categorical_accuracy: 0.9147 - val_loss: 0.2843 - val_categorical_accuracy: 0.8954
# Epoch 7/10
# 386/386 [==============================] - 29s 76ms/step - loss: 0.2112 - categorical_accuracy: 0.9247 - val_loss: 0.2905 - val_categorical_accuracy: 0.8975
# Epoch 8/10
# 386/386 [==============================] - 29s 75ms/step - loss: 0.1955 - categorical_accuracy: 0.9325 - val_loss: 0.2976 - val_categorical_accuracy: 0.8943
# Epoch 9/10
# 386/386 [==============================] - 29s 75ms/step - loss: 0.1784 - categorical_accuracy: 0.9386 - val_loss: 0.3202 - val_categorical_accuracy: 0.8952
# Epoch 10/10
# 386/386 [==============================] - 29s 75ms/step - loss: 0.1547 - categorical_accuracy: 0.9474 - val_loss: 0.3344 - val_categorical_accuracy: 0.8926
# INFO:tensorflow:Assets written to: models/en_conv.model/assets

# %%
predictions = model.predict(word_seq_test)
y_true = tf.argmax(y_test, axis=1)
y_pred = tf.argmax(predictions, axis=1)


conf_mat = tf.math.confusion_matrix(labels=y_true, predictions=y_pred, num_classes=2).numpy()
roc = roc_auc_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)

acc = float(np.sum(np.diag(conf_mat)))/np.sum(np.sum(conf_mat))
f1s0 = 2*float(conf_mat[0][0])/(2*float(conf_mat[0][0]) + conf_mat[0][1] + conf_mat[1][0])
f1s1 = 2*float(conf_mat[1][1])/(2*float(conf_mat[1][1]) + conf_mat[1][0] + conf_mat[0][1])

# %%
if not os.path.exists('results/en_conv/short_results.csv'):
    with open('results/en_conv/short_results.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(['Accuracy', 'F1 score (0)', 'F1 score (1)', 'F1', 'ROC', 'Precision'])
        writer.writerow([acc, f1s0, f1s1, f1, roc, precision])
else:
    with open('results/en_conv/short_results.csv', 'a') as f:
        writer = csv.writer(f)
        writer.writerow([acc, f1s0, f1s1, f1, roc, precision])

# %%
# save model history, confusion matrix and accuracy
model_results = {'acc': history.history['categorical_accuracy'],
                 'val_acc': history.history['val_categorical_accuracy'],
                 'loss': history.history['loss'],
                 'val_loss': history.history['val_loss'],
                 'f1s0': model.mc.val_f1s0,
                 'f1s1': model.mc.val_f1s1,
                 'conf_mat': conf_mat,
                 'main_acc': acc}
with open('results/en_conv/results.pkl', 'wb') as f:
    pickle.dump(model_results, f)

# %%
def plots(y_ss, y_labels, colors, title, file_name=None):
    x_s = range(1, len(y_ss[0])+1)
    for y_s, y_label, color in zip(y_ss, y_labels, colors):
        plt.plot(x_s, y_s, color, label=y_label)
    plt.xlabel('Epoch')
    plt.ylabel('Metrics')
    tick_marks = np.arange(1, len(x_s) + 1)
    plt.xticks(tick_marks, x_s)
    plt.title(title)
    
    plt.legend(loc='best', frameon=False)
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

def twinx_plot(y11_s, y12_s, y21_s, y22_s, x_label, y1_label,y2_label, title,
               styles=['r-', 'r--', 'b-', 'b--'], colors=['r', 'b'], file_name=None):
    fig, ax1 = plt.subplots()
    
    ax1.set_xlabel(x_label)
    ax1.set_xticks(range(1, len(y11_s)+1))
    
    ax1.set_ylabel(y1_label, color=colors[0])
    ax1.plot(range(1, len(y11_s)+1), y11_s, styles[0], label='train acc.')
    ax1.plot(range(1, len(y12_s)+1), y12_s, styles[1], label='valid. acc.')
    ax1.tick_params(axis='y', labelcolor=colors[0])
    
    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
    
    ax2.set_ylabel(y2_label, color=colors[1])  # we already handled the x-label with ax1
    ax2.plot(range(1, len(y21_s)+1), y21_s, styles[2], label='train loss')
    ax2.plot(range(1, len(y22_s)+1), y22_s, styles[3], label='valid. loss')
    ax2.tick_params(axis='y', labelcolor=colors[1])
    
    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    fig.legend(loc='right', bbox_to_anchor=(0.85, 0.5))
    plt.title(title)
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

def confusion_matrix_plot(conf_mat, cls, x_label, y_label, title, file_name=None):
    plt.imshow(conf_mat, interpolation='nearest', cmap=plt.cm.Wistia)
    plt.title(title)
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    tick_marks = np.arange(len(cls))
    plt.grid(False)
    plt.xticks(tick_marks, cls, rotation=45)
    plt.yticks(tick_marks, cls)
    
    for i in range(len(cls)):
        for j in range(len(cls)):
            plt.text(j - 0.2, i, str(conf_mat[i][j]), fontsize=16)
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

def class_distribution_hist(y_true, y_pred, cls, x_label, y_label, title, file_name=None):
    pd.Series([y_true, y_pred]).hist()
    plt.title(title)
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    tick_marks = np.arange(len(cls))
    plt.xticks(tick_marks, cls)
    plt.legend(labels=['Real', 'Predicted'], loc='best')
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

# %%
classes = ['hate speech', 'no hate']

# %%
plots([history.history['categorical_accuracy'],
       history.history['val_categorical_accuracy'],
       model.mc.val_f1s0,
       model.mc.val_f1s1],
      ['training acc.', 'validation acc.', 'no-hate f1 score', 'hate-speech f1 score'],
      ['-r', '--r', 'b', 'm'],
      title='Training progress', file_name='results/en_conv/train_progress.png')

# %%
twinx_plot(history.history['categorical_accuracy'], history.history['val_categorical_accuracy'],
           history.history['loss'], history.history['val_loss'],
          x_label='Epoch', y1_label='Accuracy', y2_label='Loss', title='Accuracy & loss / epoch',
          file_name='results/en_conv/acc_loss.png')

# %%
confusion_matrix_plot(conf_mat, cls=classes,
                      x_label='Real', y_label='Predicted',
                      title='Accuracy: {}'.format(round(acc, 2)),
                      file_name='results/en_conv/cm.png')

# %%
class_distribution_hist(y_true, y_pred, cls=classes,
                        x_label='Classes', y_label='Cardinality', title='Real and pred. classes cards.',
                        file_name='results/en_conv/cards.png')

# %%
with open('hsd/Reddit/perfect_data.pkl', 'rb') as f:
    texts, _ = pickle.load(f)
texts = texts[int(0.7*len(texts)):]

indices = [6, 10, 19, 26, 27, 28, 29, 164]
test_cases = []
for i, (t, p, l) in enumerate(zip(texts, y_pred, y_true)):
    if i in indices:
        test_cases.append({'Text': t, 'Prediction': p.numpy(), 'Label': l.numpy()})

# %%
def test_cases_board(test_cases, title, file_name=None):
    h = 20
    n = len(test_cases)
    fig, axis = plt.subplots(1, 1, figsize=(16., n*3.2))
    axis.axis('off')
    axis.set_xlim([0, 100])
    axis.set_ylim([0, n*h])
    axis.plot([0, 100], [0, 0], color='k')
    axis.plot([0, 0], [0, n*h], color='k')
    axis.plot([100, 100], [0, n*h], color='k')
    
    for i in range(n):
        axis.annotate('Tweet text:', xy=(4, 16 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        text = u'{}'.format(test_cases[i]['Text'].replace('\n', ''))
        text = '\n'.join([text[j:j+int(len(text)/3)] for j in range(0, len(text), int(len(text)/3))])
        axis.annotate(text, xy=(4, 7 + i*h), xycoords='data', size=15)
        
        axis.annotate('Prediction:', xy=(4, 4 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        pred = 'no hate' if test_cases[i]['Prediction'] == 0 else 'hate speech'
        pred_color = 'b' if pred == 'no hate' else 'm'
        axis.annotate(pred, xy=(15, 4 + i*h), xycoords='data', size=15, color=pred_color)
        
        axis.annotate('Label:', xy=(27, 4 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        label = 'no hate' if test_cases[i]['Label'] == 0 else 'hate speech'
        label_color = 'b' if label == 'no hate' else 'm'
        axis.annotate(label, xy=(34, 4 + i*h), xycoords='data', size=15, color=label_color)
        
        axis.annotate('Result:', xy=(50, 4 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        reason = 'OK' if pred == label else '1-st type error' if pred == 'no hate' else '2-nd type error'
        reason_color = 'g' if reason == 'OK' else 'r'
        axis.annotate(reason, xy=(57, 4 + i*h), xycoords='data', size=15, color=reason_color)
        
        axis.plot([0, 100], [20 + i*h, 20 + i*h], color='k')
    
    
    plt.title(title)
    if file_name:
        plt.savefig(file_name)
    plt.show()

# %%
test_cases_board(test_cases, title='Tweets summary', file_name='results/en_conv/tweets_summary.png')
