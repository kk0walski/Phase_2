# %% [markdown]
# # Hate Speech Detector - EN - LSTM model

# %%
import os
import pandas as pd
import csv
import glob
import numpy as np
import pickle
from klepto.archives import dir_archive

from sklearn.metrics import confusion_matrix

import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.layers import Input, Dense, SimpleRNN, LSTM, Concatenate
from tensorflow.keras.layers import Lambda
from tensorflow import split
from tensorflow.keras.utils import to_categorical

import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
# %matplotlib inline

# %% [markdown]
# ## Load features & labels

# %%
archive = dir_archive('hsd/Reddit/X_y_lstm', {}, cached=True)
archive.load()

features = archive['features']
labels = archive['labels']
first_card = archive['wt_num']

# %%
features.shape
# Out:
# (55132, 12, 300)

# %%
first_card
# Out:
# 12

# %% [markdown]
# ## Model

# %% [markdown]
# The best model was selected using a GridSearch with 5-fold CV.

# %%
# hyperparams
LAYERS = 4  # convolutional layers count
LR = 0.0005  # learning rate
OPTIM = tf.keras.optimizers.Adam  # optimizer
EPOCHS = 20

# params
BATCH_SIZE = 50  # size of input batch
INIT = 'random_normal'  # trainable param initializer
RNN_UNITS = 64  # recurrent network working units

# %%
SPLIT_RATIO = 0.7

# %%
X_train = features[:int(SPLIT_RATIO*len(features))]
y_train = labels[:int(SPLIT_RATIO*len(labels))]
X_test = features[int(SPLIT_RATIO*len(features)):]
y_test = labels[int(SPLIT_RATIO*len(labels)):]

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

print('Train x: {}'.format(len(X_train)))
print('Train y: {}'.format(len(y_train)))
print('Test x: {}'.format(len(X_test)))
print('Test y: {}'.format(len(y_test)))
# Out:
# Train x: 38592
# Train y: 38592
# Test x: 16540
# Test y: 16540

# %%
class MetricsCallback(Callback):
    def __init__(self):
        super(MetricsCallback, self).__init__()
        self.val_f1s0 = []
        self.val_f1s1 = []
    
    def on_epoch_end(self, epoch, logs={}):
        val_predict = np.asarray(tf.argmax(self.model.predict(X_test), axis=1))
        val_true = np.asarray(tf.argmax(y_test, axis=1))
        c_m = confusion_matrix(val_true, val_predict, labels=[0, 1])
        self.val_f1s0.append(2*float(c_m[0][0])/(2*float(c_m[0][0]) + c_m[0][1] + c_m[1][0]))
        self.val_f1s1.append(2*float(c_m[1][1])/(2*float(c_m[1][1]) + c_m[1][0] + c_m[0][1]))

# %%
class LSTMModel():
    def __init__(self, wt_card, input_shape, model_type='lstm', name='conv_model', **kwargs):
        self.wt_card = wt_card
        self.type = LSTM if model_type == 'lstm' else SimpleRNN
        
        # hyperparams
        self.layers = LAYERS if 'layers' not in kwargs else kwargs['layers']
        self.lr = LR if 'lr' not in kwargs else kwargs['lr']
        self.optim = OPTIM(learning_rate=self.lr) if 'optim' not in kwargs else kwargs['optim'](learning_rate=self.lr)
        self.epochs = EPOCHS if 'epochs' not in kwargs else kwargs['epochs']
        
        # params
        self.batch_size = BATCH_SIZE if 'batch_size' not in kwargs else kwargs['batch_size']
        self.init = INIT if 'init' not in kwargs else kwargs['init']
        self.rnn_units = RNN_UNITS if 'rnn_units' not in kwargs else kwargs['rnn_units']
        
        # layers
        inputs = Input(shape=input_shape, name='features')
        wt_inputs, pos_inputs = Lambda(lambda x: split(x, [self.wt_card, x.shape[1] - self.wt_card], axis=1), name='wt_pos_split')(inputs)
        
        x1 = self.type(units=self.rnn_units, name='wt_recurrent',
                       kernel_initializer=self.init, bias_initializer=self.init)(wt_inputs)
        x2 = self.type(units=self.rnn_units, name='pos_recurrent',
                       kernel_initializer=self.init, bias_initializer=self.init)(pos_inputs)
        
        x = Concatenate(axis=1, name='concatenation')([x1, x2])
        
        x = Dense(64, activation='relu', name='dense_1',
                  kernel_initializer='random_normal', bias_initializer='random_normal')(x)
        x = Dense(64, activation='relu', name='dense_2',
                  kernel_initializer='random_normal', bias_initializer='random_normal')(x)
        outputs = Dense(2, activation='softmax', name='predictions',
                        kernel_initializer='random_normal', bias_initializer='random_normal')(x)
        
        self.name = name
        self.model = Model(inputs=inputs, outputs=outputs, name=name)
        self.mc = MetricsCallback()
    
    def summary(self):
        return self.model.summary()
    
    def compile(self):
        self.model.compile(optimizer=self.optim,
                           loss=tf.keras.losses.CategoricalCrossentropy(),
                           metrics=[tf.keras.metrics.CategoricalAccuracy()])
    
    def fit(self, X_tr, y_tr, X_ev, y_ev):
        return self.model.fit(X_tr, y_tr, batch_size=self.batch_size, epochs=self.epochs,
                              validation_data=(X_ev, y_ev), callbacks=[self.mc])
    
    def predict(self, X_t):
        return self.model.predict(X_t)
    
    def save(self, file_name):
        self.model.save(file_name)

# %%
def models_comparison_bars(df, title, interval=2, save_file=None):
    fig, axs = plt.subplots(1, 3, figsize=(16, 4))
    
    labels = [i+1 if i%interval == 0 else '' for i in range(len(df))]
    x = range(len(labels))
    acc = df['acc'].values
    f1s0 = df['f1s0'].values
    f1s1 = df['f1s1'].values
    
    max_acc_id = np.argmax(acc)
    max_f1s0_id = np.argmax(f1s0)
    max_f1s1_id = np.argmax(f1s1)
    
    axs[0].bar(x, acc, color='r')
    axs[0].set_xlabel('Model number')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xticks(x)
    axs[0].set_xticklabels(labels)
    axs[0].set_ylim([0, 1])
    axs[0].set_title('Accuracy | max ({}) at: {}'.format(np.round(np.max(acc), 2), max_acc_id+1))
    axs[0].patches[max_acc_id].set_facecolor('g')
    
    axs[1].bar(x, f1s0, color='b')
    axs[1].set_xlabel('Model number')
    axs[1].set_ylabel('F1 score (no hate)')
    axs[1].set_title('F1 score (no hate) | max ({}) at: {}'.format(np.round(np.max(f1s0), 2), max_f1s0_id+1))
    axs[1].set_xticks(x)
    axs[1].set_xticklabels(labels)
    axs[1].set_ylim([0, 1])
    axs[1].patches[max_f1s0_id].set_facecolor('g')
    
    axs[2].bar(x, f1s1, color='m')
    axs[2].set_xlabel('Model number')
    axs[2].set_ylabel('F1 score (hate speech)')
    axs[2].set_title('F1 score (hate speech) | max ({}) at: {}'.format(np.round(np.max(f1s1), 2),
                                                                       max_f1s1_id+1))
    axs[2].set_xticks(x)
    axs[2].set_xticklabels(labels)
    axs[2].set_ylim([0, 1])
    axs[2].patches[max_f1s1_id].set_facecolor('g')
    
    fig.suptitle(title)
    
    if save_file:
        plt.savefig(save_file)
    plt.show()

# %% [markdown]
# ## Model hyperparams researching

# %%
layers_options = [2, 3, 4, 5]
lr_options = [0.01, 0.001, 0.0001]
optim_options = [tf.keras.optimizers.Adam, tf.keras.optimizers.SGD]
pochs_options = [5, 10, 15]

hp_options = []
for epochs in [epochs_options[-1]]:  # changed to process 15 epochs (eval. after each 5)
    for lr in lr_options:
        for optim in optim_options:
            for layer in layers_options:
                hp_options.append({'lr': lr, 'optim': optim, 'epochs': epochs, 'layers': layer})

# %%
pd.DataFrame(hp_options).head()
# Out:
#      lr                                              optim  epochs  layers
# 0  0.01  <class 'tensorflow.python.keras.optimizer_v2.a...      20       2
# 1  0.01  <class 'tensorflow.python.keras.optimizer_v2.a...      20       3
# 2  0.01  <class 'tensorflow.python.keras.optimizer_v2.a...      20       4
# 3  0.01  <class 'tensorflow.python.keras.optimizer_v2.a...      20       5
# 4  0.01  <class 'tensorflow.python.keras.optimizer_v2.a...      20       6

# %%
if not os.path.exists('results/en_lstm/hyperparams_research.csv'):
    hp_results = []
    for i, opts in enumerate(hp_options):
        print('\nResearching for {}/{} | Hyperparams: {}\n'.format(i+1, len(hp_options), opts))

        hp_model = LSTMModel(wt_card=first_card, input_shape=(12, 300, ), model_type='simple', **opts)
        hp_model.compile()
        hp_history = hp_model.fit(X_train, y_train, X_test, y_test)

        # append means for 5, 10 and 15 epochs
        for eps in epochs_options:
            hp_results.append({'acc': np.mean(hp_history.history['categorical_accuracy'][:eps]),
                               'val_acc': np.mean(hp_history.history['val_categorical_accuracy'][:eps]),
                               'loss': np.mean(hp_history.history['val_loss'][:eps]),
                               'f1s0': np.mean(hp_model.mc.val_f1s0[:eps]),
                               'f1s1': np.mean(hp_model.mc.val_f1s1[:eps])})
    
    hp_results_df = pd.DataFrame(hp_results)
    hp_results_df.to_csv('results/en_lstm/hyperparams_research.csv')
else:
    hp_results_df = pd.read_csv('results/en_lstm/hyperparams_research.csv', index_col=0)

# %%
hp_results_df.head()
# Out:
#         acc   val_acc      loss      f1s0  f1s1
# 0  0.845315  0.872007  0.385198  0.931628   0.0
# 1  0.845414  0.872007  0.385714  0.931628   0.0
# 2  0.845446  0.872007  0.385532  0.931628   0.0
# 3  0.845325  0.872007  0.385580  0.931628   0.0
# 4  0.845419  0.872007  0.385623  0.931628   0.0

# %%
models_comparison_bars(hp_results_df, title='Hyperparams research', interval=10, save_file='results/en_lstm/hyperparams_research.png')

# %%
best_h_num = 27
'Best one: {} with {} run epochs'.format(hp_options[(best_h_num-1)%3],
                                         ((best_h_num-1)%3)*5 if (best_h_num-1)%3 != 0 else 15)
# Out:
# "Best one: {'lr': 0.01, 'optim': <class 'tensorflow.python.keras.optimizer_v2.adam.Adam'>, 'epochs': 15, 'layers': 4} with 10 run epochs"

# %% [markdown]
# ## Model params researching

# %%
batch_size_options = [25, 50, 75, 100, 125, 1]
init_options = ['random_uniform', 'random_normal']
rnn_units_options = [64, 128, 192, 255]

p_options = []
for batch_size in batch_size_options:
    for init in init_options:
        for rnn_units in rnn_units_options:
            p_options.append({'batch_size': batch_size,
                              'init': init,
                              'rnn_units': rnn_units})

# %%
pd.DataFrame(p_options).head()
# Out:
#    batch_size            init  rnn_units
# 0          25  random_uniform         64
# 1          25  random_uniform        128
# 2          25  random_uniform        192
# 3          25   random_normal         64
# 4          25   random_normal        128

# %%
if not os.path.exists('results/en_lstm/params_research.csv'):
    p_results = []
    for i, opts in enumerate(p_options):
        print('\nResearching for {}/{} | Params: {}\n'.format(i+1, len(p_options), opts))

        p_model = LSTMModel(wt_card=first_card, input_shape=(11, 300, ), model_type='simple', **opts)
        p_model.compile()
        p_history = p_model.fit(X_train, y_train, X_test, y_test)

        p_results.append({'acc': np.mean(p_history.history['categorical_accuracy']),
                          'val_acc': np.mean(p_history.history['val_categorical_accuracy']),
                          'loss': np.mean(p_history.history['val_loss']),
                          'f1s0': np.mean(p_model.mc.val_f1s0),
                          'f1s1': np.mean(p_model.mc.val_f1s1)})
    
    p_results_df = pd.DataFrame(p_results)
    p_results_df.to_csv('results/en_lstm/params_research.csv')
else:
    p_results_df = pd.read_csv('results/en_lstm/params_research.csv', index_col=0)
# Out:
# Researching for 1/24 | Params: {'batch_size': 25, 'init': 'random_uniform', 'rnn_units': 64}
#
# Epoch 1/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4546 - categorical_accuracy: 0.8445 - val_loss: 0.4339 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4245 - categorical_accuracy: 0.8467 - val_loss: 0.4287 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4213 - categorical_accuracy: 0.8428 - val_loss: 0.4247 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4167 - categorical_accuracy: 0.8445 - val_loss: 0.4235 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4103 - categorical_accuracy: 0.8436 - val_loss: 0.4251 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4040 - categorical_accuracy: 0.8394 - val_loss: 0.4382 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3858 - categorical_accuracy: 0.8427 - val_loss: 0.4338 - val_categorical_accuracy: 0.8405
# Epoch 8/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3762 - categorical_accuracy: 0.8447 - val_loss: 0.4511 - val_categorical_accuracy: 0.8341
# Epoch 9/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3670 - categorical_accuracy: 0.8449 - val_loss: 0.4593 - val_categorical_accuracy: 0.8334
# Epoch 10/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3611 - categorical_accuracy: 0.8462 - val_loss: 0.4555 - val_categorical_accuracy: 0.8290
# Epoch 11/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3438 - categorical_accuracy: 0.8562 - val_loss: 0.4640 - val_categorical_accuracy: 0.8180
# Epoch 12/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3411 - categorical_accuracy: 0.8570 - val_loss: 0.4844 - val_categorical_accuracy: 0.8288
# Epoch 13/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3281 - categorical_accuracy: 0.8626 - val_loss: 0.4852 - val_categorical_accuracy: 0.8246
# Epoch 14/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3153 - categorical_accuracy: 0.8690 - val_loss: 0.5302 - val_categorical_accuracy: 0.8116
# Epoch 15/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3052 - categorical_accuracy: 0.8743 - val_loss: 0.5471 - val_categorical_accuracy: 0.8131
# Epoch 16/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.2925 - categorical_accuracy: 0.8765 - val_loss: 0.5383 - val_categorical_accuracy: 0.8240
# Epoch 17/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.2792 - categorical_accuracy: 0.8827 - val_loss: 0.5468 - val_categorical_accuracy: 0.8043
# Epoch 18/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.2701 - categorical_accuracy: 0.8893 - val_loss: 0.5920 - val_categorical_accuracy: 0.7832
# Epoch 19/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.2682 - categorical_accuracy: 0.8856 - val_loss: 0.5921 - val_categorical_accuracy: 0.7960
# Epoch 20/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.2478 - categorical_accuracy: 0.8965 - val_loss: 0.6571 - val_categorical_accuracy: 0.8157
#
# Researching for 2/24 | Params: {'batch_size': 25, 'init': 'random_uniform', 'rnn_units': 128}
#
# Epoch 1/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4602 - categorical_accuracy: 0.8422 - val_loss: 0.4384 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4342 - categorical_accuracy: 0.8438 - val_loss: 0.4380 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4410 - categorical_accuracy: 0.8394 - val_loss: 0.4361 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4300 - categorical_accuracy: 0.8458 - val_loss: 0.4373 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4398 - categorical_accuracy: 0.8408 - val_loss: 0.4358 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4346 - categorical_accuracy: 0.8426 - val_loss: 0.4346 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4386 - categorical_accuracy: 0.8394 - val_loss: 0.4383 - val_categorical_accuracy: 0.8409
# Epoch 8/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4252 - categorical_accuracy: 0.8473 - val_loss: 0.4317 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4327 - categorical_accuracy: 0.8419 - val_loss: 0.4348 - val_categorical_accuracy: 0.8409
# Epoch 10/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4390 - categorical_accuracy: 0.8379 - val_loss: 0.4354 - val_categorical_accuracy: 0.8409
# Epoch 11/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4214 - categorical_accuracy: 0.8479 - val_loss: 0.4334 - val_categorical_accuracy: 0.8409
# Epoch 12/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4303 - categorical_accuracy: 0.8429 - val_loss: 0.4354 - val_categorical_accuracy: 0.8409
# Epoch 13/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4331 - categorical_accuracy: 0.8423 - val_loss: 0.4328 - val_categorical_accuracy: 0.8409
# Epoch 14/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4264 - categorical_accuracy: 0.8442 - val_loss: 0.4340 - val_categorical_accuracy: 0.8409
# Epoch 15/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4272 - categorical_accuracy: 0.8423 - val_loss: 0.4298 - val_categorical_accuracy: 0.8409
# Epoch 16/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4216 - categorical_accuracy: 0.8428 - val_loss: 0.4307 - val_categorical_accuracy: 0.8409
# Epoch 17/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4187 - categorical_accuracy: 0.8438 - val_loss: 0.4312 - val_categorical_accuracy: 0.8409
# Epoch 18/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4188 - categorical_accuracy: 0.8409 - val_loss: 0.4337 - val_categorical_accuracy: 0.8409
# Epoch 19/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4095 - categorical_accuracy: 0.8456 - val_loss: 0.4296 - val_categorical_accuracy: 0.8409
# Epoch 20/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4124 - categorical_accuracy: 0.8435 - val_loss: 0.4319 - val_categorical_accuracy: 0.8409
#
# Researching for 3/24 | Params: {'batch_size': 25, 'init': 'random_uniform', 'rnn_units': 192}
#
# Epoch 1/20
# 920/920 [==============================] - 4s 4ms/step - loss: 0.4503 - categorical_accuracy: 0.8434 - val_loss: 0.4404 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4374 - categorical_accuracy: 0.8418 - val_loss: 0.4363 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4344 - categorical_accuracy: 0.8437 - val_loss: 0.4363 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4395 - categorical_accuracy: 0.8402 - val_loss: 0.4362 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4357 - categorical_accuracy: 0.8403 - val_loss: 0.4371 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4279 - categorical_accuracy: 0.8428 - val_loss: 0.4319 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4265 - categorical_accuracy: 0.8420 - val_loss: 0.4344 - val_categorical_accuracy: 0.8409
# Epoch 8/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4280 - categorical_accuracy: 0.8400 - val_loss: 0.4294 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4229 - categorical_accuracy: 0.8432 - val_loss: 0.4303 - val_categorical_accuracy: 0.8409
# Epoch 10/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4233 - categorical_accuracy: 0.8413 - val_loss: 0.4346 - val_categorical_accuracy: 0.8409
# Epoch 11/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4239 - categorical_accuracy: 0.8393 - val_loss: 0.4328 - val_categorical_accuracy: 0.8409
# Epoch 12/20
# 920/920 [==============================] - 3s 4ms/step - loss: 0.4218 - categorical_accuracy: 0.8418 - val_loss: 0.4314 - val_categorical_accuracy: 0.8409
# Epoch 13/20
# 920/920 [==============================] - 3s 4ms/step - loss: 0.4226 - categorical_accuracy: 0.8403 - val_loss: 0.4350 - val_categorical_accuracy: 0.8409
# Epoch 14/20
# 920/920 [==============================] - 3s 4ms/step - loss: 0.4095 - categorical_accuracy: 0.8475 - val_loss: 0.4406 - val_categorical_accuracy: 0.8409
# Epoch 15/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4177 - categorical_accuracy: 0.8411 - val_loss: 0.4401 - val_categorical_accuracy: 0.8409
# Epoch 16/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4125 - categorical_accuracy: 0.8443 - val_loss: 0.4367 - val_categorical_accuracy: 0.8409
# Epoch 17/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4117 - categorical_accuracy: 0.8430 - val_loss: 0.4324 - val_categorical_accuracy: 0.8409
# Epoch 18/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4069 - categorical_accuracy: 0.8445 - val_loss: 0.4361 - val_categorical_accuracy: 0.8409
# Epoch 19/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4081 - categorical_accuracy: 0.8416 - val_loss: 0.4354 - val_categorical_accuracy: 0.8409
# Epoch 20/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4017 - categorical_accuracy: 0.8453 - val_loss: 0.4365 - val_categorical_accuracy: 0.8409
#
# Researching for 4/24 | Params: {'batch_size': 25, 'init': 'random_normal', 'rnn_units': 64}
#
# Epoch 1/20
# 920/920 [==============================] - 3s 2ms/step - loss: 0.4649 - categorical_accuracy: 0.8008 - val_loss: 0.4427 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4348 - categorical_accuracy: 0.8433 - val_loss: 0.4387 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4336 - categorical_accuracy: 0.8429 - val_loss: 0.4290 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4266 - categorical_accuracy: 0.8427 - val_loss: 0.4325 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4191 - categorical_accuracy: 0.8452 - val_loss: 0.4297 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4167 - categorical_accuracy: 0.8421 - val_loss: 0.4302 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4074 - categorical_accuracy: 0.8397 - val_loss: 0.4343 - val_categorical_accuracy: 0.8409
# Epoch 8/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3909 - categorical_accuracy: 0.8437 - val_loss: 0.4456 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3816 - categorical_accuracy: 0.8445 - val_loss: 0.4510 - val_categorical_accuracy: 0.8327
# Epoch 10/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3782 - categorical_accuracy: 0.8455 - val_loss: 0.4593 - val_categorical_accuracy: 0.8307
# Epoch 11/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3617 - categorical_accuracy: 0.8529 - val_loss: 0.4558 - val_categorical_accuracy: 0.8382
# Epoch 12/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3597 - categorical_accuracy: 0.8496 - val_loss: 0.4653 - val_categorical_accuracy: 0.8283
# Epoch 13/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3540 - categorical_accuracy: 0.8546 - val_loss: 0.4655 - val_categorical_accuracy: 0.8334
# Epoch 14/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3371 - categorical_accuracy: 0.8610 - val_loss: 0.4678 - val_categorical_accuracy: 0.8222
# Epoch 15/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3307 - categorical_accuracy: 0.8636 - val_loss: 0.4894 - val_categorical_accuracy: 0.8294
# Epoch 16/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3162 - categorical_accuracy: 0.8691 - val_loss: 0.5081 - val_categorical_accuracy: 0.8011
# Epoch 17/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3016 - categorical_accuracy: 0.8787 - val_loss: 0.5246 - val_categorical_accuracy: 0.7907
# Epoch 18/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.2938 - categorical_accuracy: 0.8799 - val_loss: 0.5410 - val_categorical_accuracy: 0.8292
# Epoch 19/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.2809 - categorical_accuracy: 0.8874 - val_loss: 0.5287 - val_categorical_accuracy: 0.8063
# Epoch 20/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.2649 - categorical_accuracy: 0.8960 - val_loss: 0.5635 - val_categorical_accuracy: 0.7786
#
# Researching for 5/24 | Params: {'batch_size': 25, 'init': 'random_normal', 'rnn_units': 128}
#
# Epoch 1/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4429 - categorical_accuracy: 0.8482 - val_loss: 0.4366 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4431 - categorical_accuracy: 0.8373 - val_loss: 0.4318 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4206 - categorical_accuracy: 0.8473 - val_loss: 0.4280 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.4272 - categorical_accuracy: 0.8403 - val_loss: 0.4281 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4131 - categorical_accuracy: 0.8458 - val_loss: 0.4341 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4138 - categorical_accuracy: 0.8405 - val_loss: 0.4283 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4012 - categorical_accuracy: 0.8440 - val_loss: 0.4362 - val_categorical_accuracy: 0.8409
# Epoch 8/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.4008 - categorical_accuracy: 0.8401 - val_loss: 0.4469 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3851 - categorical_accuracy: 0.8467 - val_loss: 0.4428 - val_categorical_accuracy: 0.8409
# Epoch 10/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.3747 - categorical_accuracy: 0.8494 - val_loss: 0.4431 - val_categorical_accuracy: 0.8352
# Epoch 11/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3789 - categorical_accuracy: 0.8444 - val_loss: 0.4563 - val_categorical_accuracy: 0.8278
# Epoch 12/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.3594 - categorical_accuracy: 0.8518 - val_loss: 0.4670 - val_categorical_accuracy: 0.8210
# Epoch 13/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.3508 - categorical_accuracy: 0.8560 - val_loss: 0.4714 - val_categorical_accuracy: 0.8145
# Epoch 14/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.3450 - categorical_accuracy: 0.8537 - val_loss: 0.4984 - val_categorical_accuracy: 0.7979
# Epoch 15/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.3294 - categorical_accuracy: 0.8602 - val_loss: 0.5094 - val_categorical_accuracy: 0.8209
# Epoch 16/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.3142 - categorical_accuracy: 0.8690 - val_loss: 0.5243 - val_categorical_accuracy: 0.8096
# Epoch 17/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.3074 - categorical_accuracy: 0.8701 - val_loss: 0.5017 - val_categorical_accuracy: 0.8160
# Epoch 18/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.2931 - categorical_accuracy: 0.8751 - val_loss: 0.5354 - val_categorical_accuracy: 0.8148
# Epoch 19/20
# 920/920 [==============================] - 2s 3ms/step - loss: 0.2823 - categorical_accuracy: 0.8823 - val_loss: 0.5805 - val_categorical_accuracy: 0.8003
# Epoch 20/20
# 920/920 [==============================] - 2s 2ms/step - loss: 0.2667 - categorical_accuracy: 0.8859 - val_loss: 0.6149 - val_categorical_accuracy: 0.7847
#
# Researching for 6/24 | Params: {'batch_size': 25, 'init': 'random_normal', 'rnn_units': 192}
#
# Epoch 1/20
# 920/920 [==============================] - 4s 4ms/step - loss: 0.4501 - categorical_accuracy: 0.8361 - val_loss: 0.4375 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4374 - categorical_accuracy: 0.8421 - val_loss: 0.4321 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4271 - categorical_accuracy: 0.8461 - val_loss: 0.4312 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4235 - categorical_accuracy: 0.8462 - val_loss: 0.4339 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4280 - categorical_accuracy: 0.8419 - val_loss: 0.4320 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4234 - categorical_accuracy: 0.8428 - val_loss: 0.4350 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4255 - categorical_accuracy: 0.8421 - val_loss: 0.4336 - val_categorical_accuracy: 0.8409
# Epoch 8/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4291 - categorical_accuracy: 0.8431 - val_loss: 0.4310 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4241 - categorical_accuracy: 0.8424 - val_loss: 0.4380 - val_categorical_accuracy: 0.8409
# Epoch 10/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4222 - categorical_accuracy: 0.8419 - val_loss: 0.4339 - val_categorical_accuracy: 0.8409
# Epoch 11/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4231 - categorical_accuracy: 0.8423 - val_loss: 0.4376 - val_categorical_accuracy: 0.8409
# Epoch 12/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4324 - categorical_accuracy: 0.8374 - val_loss: 0.4477 - val_categorical_accuracy: 0.8409
# Epoch 13/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4294 - categorical_accuracy: 0.8388 - val_loss: 0.4315 - val_categorical_accuracy: 0.8409
# Epoch 14/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4231 - categorical_accuracy: 0.8409 - val_loss: 0.4310 - val_categorical_accuracy: 0.8409
# Epoch 15/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4120 - categorical_accuracy: 0.8478 - val_loss: 0.4300 - val_categorical_accuracy: 0.8409
# Epoch 16/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4228 - categorical_accuracy: 0.8401 - val_loss: 0.4317 - val_categorical_accuracy: 0.8409
# Epoch 17/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4176 - categorical_accuracy: 0.8426 - val_loss: 0.4347 - val_categorical_accuracy: 0.8409
# Epoch 18/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4219 - categorical_accuracy: 0.8413 - val_loss: 0.4339 - val_categorical_accuracy: 0.8409
# Epoch 19/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4134 - categorical_accuracy: 0.8449 - val_loss: 0.4319 - val_categorical_accuracy: 0.8409
# Epoch 20/20
# 920/920 [==============================] - 3s 3ms/step - loss: 0.4026 - categorical_accuracy: 0.8499 - val_loss: 0.4328 - val_categorical_accuracy: 0.8409
#
# Researching for 7/24 | Params: {'batch_size': 50, 'init': 'random_uniform', 'rnn_units': 64}
#
# Epoch 1/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.4835 - categorical_accuracy: 0.7834 - val_loss: 0.4364 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4363 - categorical_accuracy: 0.8417 - val_loss: 0.4333 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.4319 - categorical_accuracy: 0.8424 - val_loss: 0.4282 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.4239 - categorical_accuracy: 0.8423 - val_loss: 0.4246 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4254 - categorical_accuracy: 0.8375 - val_loss: 0.4241 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.4156 - categorical_accuracy: 0.8423 - val_loss: 0.4211 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.4112 - categorical_accuracy: 0.8430 - val_loss: 0.4330 - val_categorical_accuracy: 0.8409
# Epoch 8/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.4076 - categorical_accuracy: 0.8406 - val_loss: 0.4347 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.3985 - categorical_accuracy: 0.8407 - val_loss: 0.4290 - val_categorical_accuracy: 0.8411
# Epoch 10/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.3830 - categorical_accuracy: 0.8447 - val_loss: 0.4466 - val_categorical_accuracy: 0.8291
# Epoch 11/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.3722 - categorical_accuracy: 0.8495 - val_loss: 0.4419 - val_categorical_accuracy: 0.8299
# Epoch 12/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.3621 - categorical_accuracy: 0.8521 - val_loss: 0.4496 - val_categorical_accuracy: 0.8267
# Epoch 13/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.3586 - categorical_accuracy: 0.8530 - val_loss: 0.4689 - val_categorical_accuracy: 0.8210
# Epoch 14/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.3414 - categorical_accuracy: 0.8630 - val_loss: 0.4609 - val_categorical_accuracy: 0.8272
# Epoch 15/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.3355 - categorical_accuracy: 0.8646 - val_loss: 0.4829 - val_categorical_accuracy: 0.8275
# Epoch 16/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.3170 - categorical_accuracy: 0.8727 - val_loss: 0.4781 - val_categorical_accuracy: 0.8123
# Epoch 17/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.3094 - categorical_accuracy: 0.8722 - val_loss: 0.5111 - val_categorical_accuracy: 0.7949
# Epoch 18/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.3011 - categorical_accuracy: 0.8778 - val_loss: 0.5147 - val_categorical_accuracy: 0.8092
# Epoch 19/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.2912 - categorical_accuracy: 0.8825 - val_loss: 0.5337 - val_categorical_accuracy: 0.8028
# Epoch 20/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.2816 - categorical_accuracy: 0.8855 - val_loss: 0.5606 - val_categorical_accuracy: 0.7789
#
# Researching for 8/24 | Params: {'batch_size': 50, 'init': 'random_uniform', 'rnn_units': 128}
#
# Epoch 1/20
# 460/460 [==============================] - 2s 4ms/step - loss: 0.4780 - categorical_accuracy: 0.7966 - val_loss: 0.4366 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.4305 - categorical_accuracy: 0.8459 - val_loss: 0.4357 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.4265 - categorical_accuracy: 0.8473 - val_loss: 0.4371 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 460/460 [==============================] - 2s 4ms/step - loss: 0.4380 - categorical_accuracy: 0.8409 - val_loss: 0.4376 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.4285 - categorical_accuracy: 0.8462 - val_loss: 0.4357 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.4331 - categorical_accuracy: 0.8415 - val_loss: 0.4308 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 460/460 [==============================] - 2s 4ms/step - loss: 0.4258 - categorical_accuracy: 0.8418 - val_loss: 0.4295 - val_categorical_accuracy: 0.8409
# Epoch 8/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4198 - categorical_accuracy: 0.8428 - val_loss: 0.4299 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.4179 - categorical_accuracy: 0.8418 - val_loss: 0.4346 - val_categorical_accuracy: 0.8409
# Epoch 10/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.4157 - categorical_accuracy: 0.8405 - val_loss: 0.4338 - val_categorical_accuracy: 0.8409
# Epoch 11/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.4148 - categorical_accuracy: 0.8390 - val_loss: 0.4357 - val_categorical_accuracy: 0.8409
# Epoch 12/20
# 460/460 [==============================] - 2s 4ms/step - loss: 0.4111 - categorical_accuracy: 0.8405 - val_loss: 0.4374 - val_categorical_accuracy: 0.8409
# Epoch 13/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.3950 - categorical_accuracy: 0.8449 - val_loss: 0.4433 - val_categorical_accuracy: 0.8408
# Epoch 14/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.3911 - categorical_accuracy: 0.8437 - val_loss: 0.4430 - val_categorical_accuracy: 0.8411
# Epoch 15/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.3924 - categorical_accuracy: 0.8434 - val_loss: 0.4674 - val_categorical_accuracy: 0.8409
# Epoch 16/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.3901 - categorical_accuracy: 0.8426 - val_loss: 0.4450 - val_categorical_accuracy: 0.8387
# Epoch 17/20
# 460/460 [==============================] - 2s 4ms/step - loss: 0.3840 - categorical_accuracy: 0.8439 - val_loss: 0.4478 - val_categorical_accuracy: 0.8386
# Epoch 18/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.3728 - categorical_accuracy: 0.8471 - val_loss: 0.4468 - val_categorical_accuracy: 0.8370
# Epoch 19/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.3664 - categorical_accuracy: 0.8507 - val_loss: 0.4546 - val_categorical_accuracy: 0.8402
# Epoch 20/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.3702 - categorical_accuracy: 0.8461 - val_loss: 0.4441 - val_categorical_accuracy: 0.8340
#
# Researching for 9/24 | Params: {'batch_size': 50, 'init': 'random_uniform', 'rnn_units': 192}
#
# Epoch 1/20
# 460/460 [==============================] - 3s 5ms/step - loss: 0.4638 - categorical_accuracy: 0.8377 - val_loss: 0.4385 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4435 - categorical_accuracy: 0.8383 - val_loss: 0.4369 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4359 - categorical_accuracy: 0.8429 - val_loss: 0.4333 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4366 - categorical_accuracy: 0.8404 - val_loss: 0.4313 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4320 - categorical_accuracy: 0.8395 - val_loss: 0.4310 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4240 - categorical_accuracy: 0.8434 - val_loss: 0.4338 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4267 - categorical_accuracy: 0.8411 - val_loss: 0.4305 - val_categorical_accuracy: 0.8409
# Epoch 8/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4242 - categorical_accuracy: 0.8410 - val_loss: 0.4332 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4207 - categorical_accuracy: 0.8419 - val_loss: 0.4313 - val_categorical_accuracy: 0.8409
# Epoch 10/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4199 - categorical_accuracy: 0.8429 - val_loss: 0.4339 - val_categorical_accuracy: 0.8409
# Epoch 11/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4172 - categorical_accuracy: 0.8430 - val_loss: 0.4315 - val_categorical_accuracy: 0.8409
# Epoch 12/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4193 - categorical_accuracy: 0.8416 - val_loss: 0.4342 - val_categorical_accuracy: 0.8409
# Epoch 13/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4185 - categorical_accuracy: 0.8425 - val_loss: 0.4322 - val_categorical_accuracy: 0.8409
# Epoch 14/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4188 - categorical_accuracy: 0.8413 - val_loss: 0.4353 - val_categorical_accuracy: 0.8409
# Epoch 15/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4230 - categorical_accuracy: 0.8379 - val_loss: 0.4352 - val_categorical_accuracy: 0.8409
# Epoch 16/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4171 - categorical_accuracy: 0.8403 - val_loss: 0.4328 - val_categorical_accuracy: 0.8409
# Epoch 17/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4094 - categorical_accuracy: 0.8460 - val_loss: 0.4398 - val_categorical_accuracy: 0.8409
# Epoch 18/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4189 - categorical_accuracy: 0.8392 - val_loss: 0.4390 - val_categorical_accuracy: 0.8409
# Epoch 19/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4116 - categorical_accuracy: 0.8446 - val_loss: 0.4346 - val_categorical_accuracy: 0.8409
# Epoch 20/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4152 - categorical_accuracy: 0.8417 - val_loss: 0.4446 - val_categorical_accuracy: 0.8409
#
# Researching for 10/24 | Params: {'batch_size': 50, 'init': 'random_normal', 'rnn_units': 64}
#
# Epoch 1/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.4765 - categorical_accuracy: 0.8410 - val_loss: 0.4351 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.4342 - categorical_accuracy: 0.8426 - val_loss: 0.4465 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.4267 - categorical_accuracy: 0.8457 - val_loss: 0.4288 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.4285 - categorical_accuracy: 0.8421 - val_loss: 0.4276 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4239 - categorical_accuracy: 0.8432 - val_loss: 0.4250 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4204 - categorical_accuracy: 0.8419 - val_loss: 0.4242 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.4132 - categorical_accuracy: 0.8448 - val_loss: 0.4229 - val_categorical_accuracy: 0.8409
# Epoch 8/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4181 - categorical_accuracy: 0.8405 - val_loss: 0.4264 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.4086 - categorical_accuracy: 0.8426 - val_loss: 0.4255 - val_categorical_accuracy: 0.8409
# Epoch 10/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.4011 - categorical_accuracy: 0.8396 - val_loss: 0.4330 - val_categorical_accuracy: 0.8409
# Epoch 11/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.3853 - categorical_accuracy: 0.8436 - val_loss: 0.4400 - val_categorical_accuracy: 0.8409
# Epoch 12/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.3757 - categorical_accuracy: 0.8421 - val_loss: 0.4396 - val_categorical_accuracy: 0.8409
# Epoch 13/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.3665 - categorical_accuracy: 0.8435 - val_loss: 0.4586 - val_categorical_accuracy: 0.8317
# Epoch 14/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.3548 - categorical_accuracy: 0.8499 - val_loss: 0.4644 - val_categorical_accuracy: 0.8279
# Epoch 15/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.3390 - categorical_accuracy: 0.8523 - val_loss: 0.4849 - val_categorical_accuracy: 0.8239
# Epoch 16/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.3303 - categorical_accuracy: 0.8569 - val_loss: 0.4845 - val_categorical_accuracy: 0.8241
# Epoch 17/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.3284 - categorical_accuracy: 0.8534 - val_loss: 0.5028 - val_categorical_accuracy: 0.8173
# Epoch 18/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.3105 - categorical_accuracy: 0.8649 - val_loss: 0.5058 - val_categorical_accuracy: 0.7961
# Epoch 19/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.3025 - categorical_accuracy: 0.8671 - val_loss: 0.5229 - val_categorical_accuracy: 0.7984
# Epoch 20/20
# 460/460 [==============================] - 1s 2ms/step - loss: 0.2936 - categorical_accuracy: 0.8689 - val_loss: 0.5416 - val_categorical_accuracy: 0.8152
#
# Researching for 11/24 | Params: {'batch_size': 50, 'init': 'random_normal', 'rnn_units': 128}
#
# Epoch 1/20
# 460/460 [==============================] - 2s 4ms/step - loss: 0.4705 - categorical_accuracy: 0.8401 - val_loss: 0.4366 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.4361 - categorical_accuracy: 0.8426 - val_loss: 0.4592 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.4356 - categorical_accuracy: 0.8433 - val_loss: 0.4351 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.4353 - categorical_accuracy: 0.8422 - val_loss: 0.4405 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4350 - categorical_accuracy: 0.8426 - val_loss: 0.4349 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4371 - categorical_accuracy: 0.8405 - val_loss: 0.4322 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4292 - categorical_accuracy: 0.8430 - val_loss: 0.4354 - val_categorical_accuracy: 0.8409
# Epoch 8/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4326 - categorical_accuracy: 0.8416 - val_loss: 0.4305 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4351 - categorical_accuracy: 0.8381 - val_loss: 0.4283 - val_categorical_accuracy: 0.8409
# Epoch 10/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4277 - categorical_accuracy: 0.8413 - val_loss: 0.4332 - val_categorical_accuracy: 0.8409
# Epoch 11/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4236 - categorical_accuracy: 0.8442 - val_loss: 0.4244 - val_categorical_accuracy: 0.8409
# Epoch 12/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4231 - categorical_accuracy: 0.8418 - val_loss: 0.4291 - val_categorical_accuracy: 0.8409
# Epoch 13/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4198 - categorical_accuracy: 0.8436 - val_loss: 0.4261 - val_categorical_accuracy: 0.8409
# Epoch 14/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4121 - categorical_accuracy: 0.8456 - val_loss: 0.4260 - val_categorical_accuracy: 0.8409
# Epoch 15/20
# 460/460 [==============================] - 2s 3ms/step - loss: 0.4144 - categorical_accuracy: 0.8436 - val_loss: 0.4246 - val_categorical_accuracy: 0.8409
# Epoch 16/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4154 - categorical_accuracy: 0.8428 - val_loss: 0.4257 - val_categorical_accuracy: 0.8409
# Epoch 17/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4200 - categorical_accuracy: 0.8401 - val_loss: 0.4276 - val_categorical_accuracy: 0.8409
# Epoch 18/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4134 - categorical_accuracy: 0.8426 - val_loss: 0.4252 - val_categorical_accuracy: 0.8409
# Epoch 19/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4107 - categorical_accuracy: 0.8442 - val_loss: 0.4270 - val_categorical_accuracy: 0.8409
# Epoch 20/20
# 460/460 [==============================] - 1s 3ms/step - loss: 0.4146 - categorical_accuracy: 0.8408 - val_loss: 0.4231 - val_categorical_accuracy: 0.8409
#
# Researching for 12/24 | Params: {'batch_size': 50, 'init': 'random_normal', 'rnn_units': 192}
#
# Epoch 1/20
# 460/460 [==============================] - 3s 5ms/step - loss: 0.4570 - categorical_accuracy: 0.8313 - val_loss: 0.4391 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4447 - categorical_accuracy: 0.8377 - val_loss: 0.4351 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 460/460 [==============================] - 2s 4ms/step - loss: 0.4272 - categorical_accuracy: 0.8449 - val_loss: 0.4323 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4234 - categorical_accuracy: 0.8447 - val_loss: 0.4293 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4305 - categorical_accuracy: 0.8370 - val_loss: 0.4284 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 460/460 [==============================] - 2s 4ms/step - loss: 0.4188 - categorical_accuracy: 0.8433 - val_loss: 0.4294 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 460/460 [==============================] - 2s 4ms/step - loss: 0.4179 - categorical_accuracy: 0.8432 - val_loss: 0.4340 - val_categorical_accuracy: 0.8409
# Epoch 8/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4292 - categorical_accuracy: 0.8405 - val_loss: 0.4326 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 460/460 [==============================] - 2s 4ms/step - loss: 0.4158 - categorical_accuracy: 0.8459 - val_loss: 0.4357 - val_categorical_accuracy: 0.8409
# Epoch 10/20
# 460/460 [==============================] - 2s 4ms/step - loss: 0.4163 - categorical_accuracy: 0.8418 - val_loss: 0.4304 - val_categorical_accuracy: 0.8409
# Epoch 11/20
# 460/460 [==============================] - 2s 4ms/step - loss: 0.4095 - categorical_accuracy: 0.8442 - val_loss: 0.4383 - val_categorical_accuracy: 0.8409
# Epoch 12/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4061 - categorical_accuracy: 0.8431 - val_loss: 0.4358 - val_categorical_accuracy: 0.8409
# Epoch 13/20
# 460/460 [==============================] - 2s 4ms/step - loss: 0.4051 - categorical_accuracy: 0.8390 - val_loss: 0.4345 - val_categorical_accuracy: 0.8409
# Epoch 14/20
# 460/460 [==============================] - 2s 4ms/step - loss: 0.3917 - categorical_accuracy: 0.8446 - val_loss: 0.4590 - val_categorical_accuracy: 0.8409
# Epoch 15/20
# 460/460 [==============================] - 2s 4ms/step - loss: 0.3901 - categorical_accuracy: 0.8432 - val_loss: 0.4439 - val_categorical_accuracy: 0.8409
# Epoch 16/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.3793 - categorical_accuracy: 0.8444 - val_loss: 0.4439 - val_categorical_accuracy: 0.8409
# Epoch 17/20
# 460/460 [==============================] - 2s 4ms/step - loss: 0.3776 - categorical_accuracy: 0.8408 - val_loss: 0.4525 - val_categorical_accuracy: 0.8418
# Epoch 18/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.3682 - categorical_accuracy: 0.8468 - val_loss: 0.4607 - val_categorical_accuracy: 0.8389
# Epoch 19/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.3548 - categorical_accuracy: 0.8515 - val_loss: 0.4942 - val_categorical_accuracy: 0.8389
# Epoch 20/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.3488 - categorical_accuracy: 0.8535 - val_loss: 0.4843 - val_categorical_accuracy: 0.8226
#
# Researching for 13/24 | Params: {'batch_size': 75, 'init': 'random_uniform', 'rnn_units': 64}
#
# Epoch 1/20
# 307/307 [==============================] - 2s 4ms/step - loss: 0.4890 - categorical_accuracy: 0.8450 - val_loss: 0.4363 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.4316 - categorical_accuracy: 0.8435 - val_loss: 0.4340 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.4280 - categorical_accuracy: 0.8407 - val_loss: 0.4345 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.4313 - categorical_accuracy: 0.8373 - val_loss: 0.4272 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.4201 - categorical_accuracy: 0.8400 - val_loss: 0.4245 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.4027 - categorical_accuracy: 0.8458 - val_loss: 0.4290 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.4036 - categorical_accuracy: 0.8378 - val_loss: 0.4358 - val_categorical_accuracy: 0.8407
# Epoch 8/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.3844 - categorical_accuracy: 0.8412 - val_loss: 0.4342 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.3769 - categorical_accuracy: 0.8421 - val_loss: 0.4435 - val_categorical_accuracy: 0.8408
# Epoch 10/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.3580 - categorical_accuracy: 0.8525 - val_loss: 0.4491 - val_categorical_accuracy: 0.8376
# Epoch 11/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.3541 - categorical_accuracy: 0.8525 - val_loss: 0.4609 - val_categorical_accuracy: 0.8205
# Epoch 12/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.3491 - categorical_accuracy: 0.8521 - val_loss: 0.4626 - val_categorical_accuracy: 0.8291
# Epoch 13/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.3359 - categorical_accuracy: 0.8572 - val_loss: 0.4773 - val_categorical_accuracy: 0.8115
# Epoch 14/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.3371 - categorical_accuracy: 0.8581 - val_loss: 0.4995 - val_categorical_accuracy: 0.8059
# Epoch 15/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.3249 - categorical_accuracy: 0.8613 - val_loss: 0.5135 - val_categorical_accuracy: 0.7947
# Epoch 16/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.3030 - categorical_accuracy: 0.8732 - val_loss: 0.5106 - val_categorical_accuracy: 0.8015
# Epoch 17/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.2992 - categorical_accuracy: 0.8729 - val_loss: 0.5490 - val_categorical_accuracy: 0.8059
# Epoch 18/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.2828 - categorical_accuracy: 0.8791 - val_loss: 0.5474 - val_categorical_accuracy: 0.8024
# Epoch 19/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.2738 - categorical_accuracy: 0.8853 - val_loss: 0.5485 - val_categorical_accuracy: 0.7892
# Epoch 20/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.2666 - categorical_accuracy: 0.8896 - val_loss: 0.5529 - val_categorical_accuracy: 0.8064
#
# Researching for 14/24 | Params: {'batch_size': 75, 'init': 'random_uniform', 'rnn_units': 128}
#
# Epoch 1/20
# 307/307 [==============================] - 2s 5ms/step - loss: 0.4646 - categorical_accuracy: 0.8457 - val_loss: 0.4384 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 307/307 [==============================] - 1s 5ms/step - loss: 0.4332 - categorical_accuracy: 0.8440 - val_loss: 0.4358 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 307/307 [==============================] - 1s 5ms/step - loss: 0.4419 - categorical_accuracy: 0.8380 - val_loss: 0.4422 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.4356 - categorical_accuracy: 0.8421 - val_loss: 0.4529 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 307/307 [==============================] - 2s 5ms/step - loss: 0.4373 - categorical_accuracy: 0.8414 - val_loss: 0.4366 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 307/307 [==============================] - 2s 5ms/step - loss: 0.4266 - categorical_accuracy: 0.8418 - val_loss: 0.4283 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.4199 - categorical_accuracy: 0.8416 - val_loss: 0.4305 - val_categorical_accuracy: 0.8409
# Epoch 8/20
# 307/307 [==============================] - 1s 5ms/step - loss: 0.4167 - categorical_accuracy: 0.8415 - val_loss: 0.4305 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 307/307 [==============================] - 1s 5ms/step - loss: 0.4094 - categorical_accuracy: 0.8419 - val_loss: 0.4301 - val_categorical_accuracy: 0.8409
# Epoch 10/20
# 307/307 [==============================] - 1s 5ms/step - loss: 0.4094 - categorical_accuracy: 0.8396 - val_loss: 0.4350 - val_categorical_accuracy: 0.8409
# Epoch 11/20
# 307/307 [==============================] - 1s 5ms/step - loss: 0.4044 - categorical_accuracy: 0.8407 - val_loss: 0.4366 - val_categorical_accuracy: 0.8409
# Epoch 12/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.3931 - categorical_accuracy: 0.8436 - val_loss: 0.4430 - val_categorical_accuracy: 0.8409
# Epoch 13/20
# 307/307 [==============================] - 1s 5ms/step - loss: 0.3887 - categorical_accuracy: 0.8420 - val_loss: 0.4388 - val_categorical_accuracy: 0.8409
# Epoch 14/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.3793 - categorical_accuracy: 0.8428 - val_loss: 0.4474 - val_categorical_accuracy: 0.8409
# Epoch 15/20
# 307/307 [==============================] - 2s 5ms/step - loss: 0.3725 - categorical_accuracy: 0.8435 - val_loss: 0.4503 - val_categorical_accuracy: 0.8380
# Epoch 16/20
# 307/307 [==============================] - 2s 5ms/step - loss: 0.3616 - categorical_accuracy: 0.8495 - val_loss: 0.4481 - val_categorical_accuracy: 0.8291
# Epoch 17/20
# 307/307 [==============================] - 1s 5ms/step - loss: 0.3580 - categorical_accuracy: 0.8501 - val_loss: 0.4725 - val_categorical_accuracy: 0.8202
# Epoch 18/20
# 307/307 [==============================] - 1s 5ms/step - loss: 0.3526 - categorical_accuracy: 0.8532 - val_loss: 0.4657 - val_categorical_accuracy: 0.8174
# Epoch 19/20
# 307/307 [==============================] - 1s 5ms/step - loss: 0.3468 - categorical_accuracy: 0.8502 - val_loss: 0.4729 - val_categorical_accuracy: 0.8224
# Epoch 20/20
# 307/307 [==============================] - 1s 5ms/step - loss: 0.3316 - categorical_accuracy: 0.8624 - val_loss: 0.4882 - val_categorical_accuracy: 0.7932
#
# ...
# Epoch 8/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4252 - categorical_accuracy: 0.8422 - val_loss: 0.4344 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4251 - categorical_accuracy: 0.8410 - val_loss: 0.4306 - val_categorical_accuracy: 0.8409
# Epoch 10/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4182 - categorical_accuracy: 0.8456 - val_loss: 0.4295 - val_categorical_accuracy: 0.8409
# Epoch 11/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4214 - categorical_accuracy: 0.8424 - val_loss: 0.4293 - val_categorical_accuracy: 0.8409
# Epoch 12/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4182 - categorical_accuracy: 0.8461 - val_loss: 0.4282 - val_categorical_accuracy: 0.8409
# Epoch 13/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4190 - categorical_accuracy: 0.8434 - val_loss: 0.4319 - val_categorical_accuracy: 0.8409
# Epoch 14/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4253 - categorical_accuracy: 0.8399 - val_loss: 0.4259 - val_categorical_accuracy: 0.8409
# Epoch 15/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4178 - categorical_accuracy: 0.8426 - val_loss: 0.4276 - val_categorical_accuracy: 0.8409
# Epoch 16/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4168 - categorical_accuracy: 0.8427 - val_loss: 0.4257 - val_categorical_accuracy: 0.8409
# Epoch 17/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4180 - categorical_accuracy: 0.8410 - val_loss: 0.4309 - val_categorical_accuracy: 0.8409
# Epoch 18/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4164 - categorical_accuracy: 0.8406 - val_loss: 0.4239 - val_categorical_accuracy: 0.8409
# Epoch 19/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4152 - categorical_accuracy: 0.8439 - val_loss: 0.4306 - val_categorical_accuracy: 0.8409
# Epoch 20/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4129 - categorical_accuracy: 0.8439 - val_loss: 0.4297 - val_categorical_accuracy: 0.8409
#
# Researching for 21/24 | Params: {'batch_size': 100, 'init': 'random_uniform', 'rnn_units': 192}
#
# Epoch 1/20
# 230/230 [==============================] - 2s 8ms/step - loss: 0.4700 - categorical_accuracy: 0.8411 - val_loss: 0.4435 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 230/230 [==============================] - 2s 8ms/step - loss: 0.4336 - categorical_accuracy: 0.8439 - val_loss: 0.4300 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.4324 - categorical_accuracy: 0.8399 - val_loss: 0.4291 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 230/230 [==============================] - 2s 8ms/step - loss: 0.4217 - categorical_accuracy: 0.8422 - val_loss: 0.4260 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.4244 - categorical_accuracy: 0.8402 - val_loss: 0.4267 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 230/230 [==============================] - 2s 8ms/step - loss: 0.4154 - categorical_accuracy: 0.8429 - val_loss: 0.4252 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.4169 - categorical_accuracy: 0.8380 - val_loss: 0.4370 - val_categorical_accuracy: 0.8409
# Epoch 8/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.3968 - categorical_accuracy: 0.8472 - val_loss: 0.4291 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.3995 - categorical_accuracy: 0.8425 - val_loss: 0.4447 - val_categorical_accuracy: 0.8409
# Epoch 10/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.3905 - categorical_accuracy: 0.8448 - val_loss: 0.4345 - val_categorical_accuracy: 0.8409
# Epoch 11/20
# 230/230 [==============================] - 2s 8ms/step - loss: 0.3828 - categorical_accuracy: 0.8428 - val_loss: 0.4367 - val_categorical_accuracy: 0.8409
# Epoch 12/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.3793 - categorical_accuracy: 0.8414 - val_loss: 0.4698 - val_categorical_accuracy: 0.8366
# Epoch 13/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.3685 - categorical_accuracy: 0.8474 - val_loss: 0.4798 - val_categorical_accuracy: 0.8380
# Epoch 14/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.3636 - categorical_accuracy: 0.8470 - val_loss: 0.4639 - val_categorical_accuracy: 0.8302
# Epoch 15/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.3483 - categorical_accuracy: 0.8511 - val_loss: 0.4873 - val_categorical_accuracy: 0.8325
# Epoch 16/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.3407 - categorical_accuracy: 0.8537 - val_loss: 0.4999 - val_categorical_accuracy: 0.7822
# Epoch 17/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.3274 - categorical_accuracy: 0.8618 - val_loss: 0.5014 - val_categorical_accuracy: 0.8312
# Epoch 18/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.3157 - categorical_accuracy: 0.8641 - val_loss: 0.5254 - val_categorical_accuracy: 0.7879
# Epoch 19/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.3076 - categorical_accuracy: 0.8646 - val_loss: 0.5525 - val_categorical_accuracy: 0.8169
# Epoch 20/20
# 230/230 [==============================] - 2s 8ms/step - loss: 0.2905 - categorical_accuracy: 0.8793 - val_loss: 0.5566 - val_categorical_accuracy: 0.8000
#
# Researching for 22/24 | Params: {'batch_size': 100, 'init': 'random_normal', 'rnn_units': 64}
#
# Epoch 1/20
# 230/230 [==============================] - 2s 5ms/step - loss: 0.5083 - categorical_accuracy: 0.8137 - val_loss: 0.4368 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.4420 - categorical_accuracy: 0.8381 - val_loss: 0.4375 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.4351 - categorical_accuracy: 0.8419 - val_loss: 0.4315 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.4241 - categorical_accuracy: 0.8442 - val_loss: 0.4241 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.4170 - categorical_accuracy: 0.8440 - val_loss: 0.4297 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.4150 - categorical_accuracy: 0.8409 - val_loss: 0.4295 - val_categorical_accuracy: 0.8410
# Epoch 7/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.4089 - categorical_accuracy: 0.8424 - val_loss: 0.4245 - val_categorical_accuracy: 0.8410
# Epoch 8/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3993 - categorical_accuracy: 0.8427 - val_loss: 0.4255 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3951 - categorical_accuracy: 0.8429 - val_loss: 0.4374 - val_categorical_accuracy: 0.8414
# Epoch 10/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3773 - categorical_accuracy: 0.8487 - val_loss: 0.4381 - val_categorical_accuracy: 0.8358
# Epoch 11/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3744 - categorical_accuracy: 0.8483 - val_loss: 0.4460 - val_categorical_accuracy: 0.8336
# Epoch 12/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3630 - categorical_accuracy: 0.8550 - val_loss: 0.4594 - val_categorical_accuracy: 0.8325
# Epoch 13/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3579 - categorical_accuracy: 0.8559 - val_loss: 0.4693 - val_categorical_accuracy: 0.8221
# Epoch 14/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3507 - categorical_accuracy: 0.8608 - val_loss: 0.4615 - val_categorical_accuracy: 0.8263
# Epoch 15/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3376 - categorical_accuracy: 0.8635 - val_loss: 0.4724 - val_categorical_accuracy: 0.8235
# Epoch 16/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3312 - categorical_accuracy: 0.8717 - val_loss: 0.4874 - val_categorical_accuracy: 0.8155
# Epoch 17/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3176 - categorical_accuracy: 0.8743 - val_loss: 0.5011 - val_categorical_accuracy: 0.8329
# Epoch 18/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3196 - categorical_accuracy: 0.8714 - val_loss: 0.4976 - val_categorical_accuracy: 0.8191
# Epoch 19/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3099 - categorical_accuracy: 0.8794 - val_loss: 0.5196 - val_categorical_accuracy: 0.8062
# Epoch 20/20
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3016 - categorical_accuracy: 0.8792 - val_loss: 0.5428 - val_categorical_accuracy: 0.8122
#
# Researching for 23/24 | Params: {'batch_size': 100, 'init': 'random_normal', 'rnn_units': 128}
#
# Epoch 1/20
# 230/230 [==============================] - 2s 6ms/step - loss: 0.4891 - categorical_accuracy: 0.8111 - val_loss: 0.4357 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4374 - categorical_accuracy: 0.8411 - val_loss: 0.4443 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4337 - categorical_accuracy: 0.8444 - val_loss: 0.4364 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 230/230 [==============================] - 1s 5ms/step - loss: 0.4373 - categorical_accuracy: 0.8416 - val_loss: 0.4401 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4311 - categorical_accuracy: 0.8457 - val_loss: 0.4374 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4356 - categorical_accuracy: 0.8428 - val_loss: 0.4362 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4344 - categorical_accuracy: 0.8431 - val_loss: 0.4363 - val_categorical_accuracy: 0.8409
# Epoch 8/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4366 - categorical_accuracy: 0.8419 - val_loss: 0.4350 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4344 - categorical_accuracy: 0.8423 - val_loss: 0.4356 - val_categorical_accuracy: 0.8409
# Epoch 10/20
# 230/230 [==============================] - 1s 5ms/step - loss: 0.4265 - categorical_accuracy: 0.8456 - val_loss: 0.4378 - val_categorical_accuracy: 0.8409
# Epoch 11/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4389 - categorical_accuracy: 0.8402 - val_loss: 0.4304 - val_categorical_accuracy: 0.8409
# Epoch 12/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4305 - categorical_accuracy: 0.8425 - val_loss: 0.4303 - val_categorical_accuracy: 0.8409
# Epoch 13/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4288 - categorical_accuracy: 0.8418 - val_loss: 0.4314 - val_categorical_accuracy: 0.8409
# Epoch 14/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4306 - categorical_accuracy: 0.8401 - val_loss: 0.4289 - val_categorical_accuracy: 0.8409
# Epoch 15/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4253 - categorical_accuracy: 0.8429 - val_loss: 0.4279 - val_categorical_accuracy: 0.8409
# Epoch 16/20
# 230/230 [==============================] - 1s 5ms/step - loss: 0.4184 - categorical_accuracy: 0.8455 - val_loss: 0.4265 - val_categorical_accuracy: 0.8409
# Epoch 17/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4156 - categorical_accuracy: 0.8467 - val_loss: 0.4284 - val_categorical_accuracy: 0.8409
# Epoch 18/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4193 - categorical_accuracy: 0.8451 - val_loss: 0.4256 - val_categorical_accuracy: 0.8409
# Epoch 19/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4295 - categorical_accuracy: 0.8377 - val_loss: 0.4323 - val_categorical_accuracy: 0.8409
# Epoch 20/20
# 230/230 [==============================] - 1s 6ms/step - loss: 0.4166 - categorical_accuracy: 0.8452 - val_loss: 0.4245 - val_categorical_accuracy: 0.8409
#
# Researching for 24/24 | Params: {'batch_size': 100, 'init': 'random_normal', 'rnn_units': 192}
#
# Epoch 1/20
# 230/230 [==============================] - 3s 8ms/step - loss: 0.4885 - categorical_accuracy: 0.8385 - val_loss: 0.4383 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.4351 - categorical_accuracy: 0.8433 - val_loss: 0.4340 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.4322 - categorical_accuracy: 0.8432 - val_loss: 0.4368 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 230/230 [==============================] - 2s 8ms/step - loss: 0.4454 - categorical_accuracy: 0.8369 - val_loss: 0.4369 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.4316 - categorical_accuracy: 0.8444 - val_loss: 0.4355 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 230/230 [==============================] - 2s 8ms/step - loss: 0.4332 - categorical_accuracy: 0.8437 - val_loss: 0.4348 - val_categorical_accuracy: 0.8409
# Epoch 7/20
# 230/230 [==============================] - 2s 8ms/step - loss: 0.4319 - categorical_accuracy: 0.8443 - val_loss: 0.4350 - val_categorical_accuracy: 0.8409
# Epoch 8/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.4353 - categorical_accuracy: 0.8420 - val_loss: 0.4352 - val_categorical_accuracy: 0.8409
# Epoch 9/20
# 230/230 [==============================] - 2s 8ms/step - loss: 0.4337 - categorical_accuracy: 0.8406 - val_loss: 0.4368 - val_categorical_accuracy: 0.8409
# Epoch 10/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.4236 - categorical_accuracy: 0.8447 - val_loss: 0.4312 - val_categorical_accuracy: 0.8409
# Epoch 11/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.4236 - categorical_accuracy: 0.8446 - val_loss: 0.4319 - val_categorical_accuracy: 0.8409
# Epoch 12/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.4210 - categorical_accuracy: 0.8426 - val_loss: 0.4281 - val_categorical_accuracy: 0.8409
# Epoch 13/20
# 230/230 [==============================] - 2s 8ms/step - loss: 0.4235 - categorical_accuracy: 0.8410 - val_loss: 0.4363 - val_categorical_accuracy: 0.8409
# Epoch 14/20
# 230/230 [==============================] - 2s 8ms/step - loss: 0.4216 - categorical_accuracy: 0.8413 - val_loss: 0.4339 - val_categorical_accuracy: 0.8409
# Epoch 15/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.4125 - categorical_accuracy: 0.8447 - val_loss: 0.4286 - val_categorical_accuracy: 0.8409
# Epoch 16/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.4142 - categorical_accuracy: 0.8435 - val_loss: 0.4296 - val_categorical_accuracy: 0.8409
# Epoch 17/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.4165 - categorical_accuracy: 0.8414 - val_loss: 0.4275 - val_categorical_accuracy: 0.8409
# Epoch 18/20
# 230/230 [==============================] - 2s 8ms/step - loss: 0.4110 - categorical_accuracy: 0.8424 - val_loss: 0.4282 - val_categorical_accuracy: 0.8409
# Epoch 19/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.4087 - categorical_accuracy: 0.8438 - val_loss: 0.4324 - val_categorical_accuracy: 0.8409
# Epoch 20/20
# 230/230 [==============================] - 2s 7ms/step - loss: 0.4215 - categorical_accuracy: 0.8361 - val_loss: 0.4309 - val_categorical_accuracy: 0.8409

# %%
p_results_df.head()
# Out:
#         acc   val_acc      loss      f1s0      f1s1
# 0  0.858087  0.825084  0.490552  0.903015  0.080194
# 1  0.842489  0.840898  0.434138  0.913573  0.000000
# 2  0.842522  0.840898  0.435191  0.913573  0.000000
# 3  0.853668  0.827399  0.470138  0.904548  0.066780
# 4  0.852454  0.825546  0.475747  0.903462  0.064768

# %%
models_comparison_bars(p_results_df, title='Params research', save_file='results/en_lstm/params_research.png')

# %%
best_num = 10
'Best one: {}'.format(p_options[best_num-1])
# Out:
# "Best one: {'batch_size': 50, 'init': 'random_normal', 'rnn_units': 64}"

# %% [markdown]
# ## Best model

# %%
model = LSTMModel(wt_card=first_card, input_shape=(11, 300))
model.summary()
# Out:
# Model: "conv_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# features (InputLayer)        [(None, 11, 300)]         0
# _________________________________________________________________
# wt_recurrent (LSTM)          (None, 64)                93440
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# predictions (Dense)          (None, 2)                 130
# =================================================================
# Total params: 101,890
# Trainable params: 101,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile()
history = model.fit(X_train, y_train, X_test, y_test)
model.save('models/en_lstm.model')
# Out:
# Epoch 1/20
# 460/460 [==============================] - 4s 6ms/step - loss: 0.4976 - categorical_accuracy: 0.8421 - val_loss: 0.4322 - val_categorical_accuracy: 0.8409
# Epoch 2/20
# 460/460 [==============================] - 3s 6ms/step - loss: 0.4286 - categorical_accuracy: 0.8426 - val_loss: 0.4238 - val_categorical_accuracy: 0.8409
# Epoch 3/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4215 - categorical_accuracy: 0.8416 - val_loss: 0.4221 - val_categorical_accuracy: 0.8409
# Epoch 4/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4189 - categorical_accuracy: 0.8400 - val_loss: 0.4219 - val_categorical_accuracy: 0.8409
# Epoch 5/20
# 460/460 [==============================] - 3s 6ms/step - loss: 0.4134 - categorical_accuracy: 0.8418 - val_loss: 0.4225 - val_categorical_accuracy: 0.8409
# Epoch 6/20
# 460/460 [==============================] - 3s 6ms/step - loss: 0.4166 - categorical_accuracy: 0.8375 - val_loss: 0.4217 - val_categorical_accuracy: 0.8406
# Epoch 7/20
# 460/460 [==============================] - 3s 6ms/step - loss: 0.4055 - categorical_accuracy: 0.8450 - val_loss: 0.4224 - val_categorical_accuracy: 0.8409
# Epoch 8/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4076 - categorical_accuracy: 0.8428 - val_loss: 0.4217 - val_categorical_accuracy: 0.8407
# Epoch 9/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.4077 - categorical_accuracy: 0.8409 - val_loss: 0.4242 - val_categorical_accuracy: 0.8402
# Epoch 10/20
# 460/460 [==============================] - 3s 6ms/step - loss: 0.3963 - categorical_accuracy: 0.8468 - val_loss: 0.4249 - val_categorical_accuracy: 0.8385
# Epoch 11/20
# 460/460 [==============================] - 3s 6ms/step - loss: 0.4004 - categorical_accuracy: 0.8443 - val_loss: 0.4233 - val_categorical_accuracy: 0.8406
# Epoch 12/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.3867 - categorical_accuracy: 0.8520 - val_loss: 0.4257 - val_categorical_accuracy: 0.8393
# Epoch 13/20
# 460/460 [==============================] - 2s 5ms/step - loss: 0.3968 - categorical_accuracy: 0.8454 - val_loss: 0.4279 - val_categorical_accuracy: 0.8392
# Epoch 14/20
# 460/460 [==============================] - 3s 6ms/step - loss: 0.3886 - categorical_accuracy: 0.8485 - val_loss: 0.4340 - val_categorical_accuracy: 0.8388
# Epoch 15/20
# 460/460 [==============================] - 3s 6ms/step - loss: 0.3862 - categorical_accuracy: 0.8502 - val_loss: 0.4356 - val_categorical_accuracy: 0.8386
# Epoch 16/20
# 460/460 [==============================] - 3s 5ms/step - loss: 0.3815 - categorical_accuracy: 0.8502 - val_loss: 0.4331 - val_categorical_accuracy: 0.8403
# Epoch 17/20
# 460/460 [==============================] - 3s 6ms/step - loss: 0.3771 - categorical_accuracy: 0.8521 - val_loss: 0.4440 - val_categorical_accuracy: 0.8364
# Epoch 18/20
# 460/460 [==============================] - 3s 6ms/step - loss: 0.3777 - categorical_accuracy: 0.8497 - val_loss: 0.4474 - val_categorical_accuracy: 0.8350
# Epoch 19/20
# 460/460 [==============================] - 3s 6ms/step - loss: 0.3737 - categorical_accuracy: 0.8475 - val_loss: 0.4501 - val_categorical_accuracy: 0.8390
# Epoch 20/20
# 460/460 [==============================] - 3s 6ms/step - loss: 0.3726 - categorical_accuracy: 0.8504 - val_loss: 0.4609 - val_categorical_accuracy: 0.8373
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/en_lstm.model/assets
# INFO:tensorflow:Assets written to: models/en_lstm.model/assets

# %%
predictions = model.predict(X_test)
y_true = tf.argmax(y_test, axis=1)
y_pred = tf.argmax(predictions, axis=1)

conf_mat = tf.math.confusion_matrix(labels=y_true, predictions=y_pred, num_classes=2).numpy()
acc = float(np.sum(np.diag(conf_mat)))/np.sum(np.sum(conf_mat))
f1s0 = 2*float(conf_mat[0][0])/(2*float(conf_mat[0][0]) + conf_mat[0][1] + conf_mat[1][0])
f1s1 = 2*float(conf_mat[1][1])/(2*float(conf_mat[1][1]) + conf_mat[1][0] + conf_mat[0][1])

# %%
if not os.path.exists('results/en_lstm/short_results.csv'):
    with open('results/en_lstm/short_results.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(['Accuracy', 'F1 score (0)', 'F1 score (1)'])
        writer.writerow([acc, f1s0, f1s1])
else:
    with open('results/en_lstm/short_results.csv', 'a') as f:
        writer = csv.writer(f)
        writer.writerow([acc, f1s0, f1s1])

# %%
# save model history, confusion matrix and accuracy
model_results = {'acc': history.history['categorical_accuracy'],
                 'val_acc': history.history['val_categorical_accuracy'],
                 'loss': history.history['loss'],
                 'val_loss': history.history['val_loss'],
                 'f1s0': model.mc.val_f1s0,
                 'f1s1': model.mc.val_f1s1,
                 'conf_mat': conf_mat,
                 'main_acc': acc}
with open('results/en_lstm/results.pkl', 'wb') as f:
    pickle.dump(model_results, f)

# %% [markdown]
# ## Visualizations

# %%
def plots(y_ss, y_labels, colors, title, file_name=None):
    x_s = range(1, len(y_ss[0])+1)
    for y_s, y_label, color in zip(y_ss, y_labels, colors):
        plt.plot(x_s, y_s, color, label=y_label)
    plt.xlabel('Epoch')
    plt.ylabel('Metrics')
    tick_marks = np.arange(1, len(x_s) + 1)
    plt.xticks(tick_marks, x_s)
    plt.title(title)
    
    plt.legend(loc='best', frameon=False)
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

def twinx_plot(y11_s, y12_s, y21_s, y22_s, x_label, y1_label,y2_label, title,
               styles=['r-', 'r--', 'b-', 'b--'], colors=['r', 'b'], file_name=None):
    fig, ax1 = plt.subplots()
    
    ax1.set_xlabel(x_label)
    ax1.set_xticks(range(1, len(y11_s)+1))
    
    ax1.set_ylabel(y1_label, color=colors[0])
    ax1.plot(range(1, len(y11_s)+1), y11_s, styles[0], label='train acc.')
    ax1.plot(range(1, len(y12_s)+1), y12_s, styles[1], label='valid. acc.')
    ax1.tick_params(axis='y', labelcolor=colors[0])
    
    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
    
    ax2.set_ylabel(y2_label, color=colors[1])  # we already handled the x-label with ax1
    ax2.plot(range(1, len(y21_s)+1), y21_s, styles[2], label='train loss')
    ax2.plot(range(1, len(y22_s)+1), y22_s, styles[3], label='valid. loss')
    ax2.tick_params(axis='y', labelcolor=colors[1])
    
    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    fig.legend(loc='right', bbox_to_anchor=(0.85, 0.5))
    plt.title(title)
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

def confusion_matrix_plot(conf_mat, cls, x_label, y_label, title, file_name=None):
    plt.imshow(conf_mat, interpolation='nearest', cmap=plt.cm.Wistia)
    plt.title(title)
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    tick_marks = np.arange(len(cls))
    plt.grid(False)
    plt.xticks(tick_marks, cls, rotation=45)
    plt.yticks(tick_marks, cls)
    
    for i in range(len(cls)):
        for j in range(len(cls)):
            plt.text(j - 0.2, i, str(conf_mat[i][j]), fontsize=16)
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

def class_distribution_hist(y_true, y_pred, cls, x_label, y_label, title, file_name=None):
    pd.Series([y_true, y_pred]).hist()
    plt.title(title)
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    tick_marks = np.arange(len(cls))
    plt.xticks(tick_marks, cls)
    plt.legend(labels=['Real', 'Predicted'], loc='best')
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

# %%
classes = ['no hate', 'hate speech']

# %%
plots([history.history['categorical_accuracy'],
       history.history['val_categorical_accuracy'],
       model.mc.val_f1s0,
       model.mc.val_f1s1],
      ['training acc.', 'validation acc.', 'no-hate f1 score', 'hate-speech f1 score'],
      ['-r', '--r', 'b', 'm'],
      title='Training progress', file_name='results/en_lstm/train_progress.png')

# %%
twinx_plot(history.history['categorical_accuracy'], history.history['val_categorical_accuracy'],
           history.history['loss'], history.history['val_loss'],
          x_label='Epoch', y1_label='Accuracy', y2_label='Loss', title='Accuracy & loss / epoch',
          file_name='results/en_lstm/acc_loss.png')

# %%
confusion_matrix_plot(conf_mat, cls=classes,
                      x_label='Real', y_label='Predicted',
                      title='Accuracy: {}'.format(round(acc, 2)),
                      file_name='results/en_lstm/cm.png')

# %%
class_distribution_hist(y_true, y_pred, cls=classes,
                        x_label='Classes', y_label='Cardinality', title='Real and pred. classes cards.',
                        file_name='results/en_lstm/cards.png')

# %%
with open('hsd/DavidsonEtAl/perfect_data.pkl', 'rb') as f:
    texts, _ = pickle.load(f)
texts = texts[int(SPLIT_RATIO*len(texts)):]

indices = [6, 10, 19, 26, 27, 28, 29, 164]
test_cases = []
for i, (t, p, l) in enumerate(zip(texts, y_pred, y_true)):
    if i in indices:
        test_cases.append({'Text': t, 'Prediction': p.numpy(), 'Label': l.numpy()})

# %%
def test_cases_board(test_cases, title, file_name=None):
    h = 20
    n = len(test_cases)
    fig, axis = plt.subplots(1, 1, figsize=(16., n*3.2))
    axis.axis('off')
    axis.set_xlim([0, 100])
    axis.set_ylim([0, n*h])
    axis.plot([0, 100], [0, 0], color='k')
    axis.plot([0, 0], [0, n*h], color='k')
    axis.plot([100, 100], [0, n*h], color='k')
    
    for i in range(n):
        axis.annotate('Tweet text:', xy=(4, 16 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        text = u'{}'.format(test_cases[i]['Text'].replace('\n', ''))
        text = '\n'.join([text[j:j+int(len(text)/3)] for j in range(0, len(text), int(len(text)/3))])
        axis.annotate(text, xy=(4, 7 + i*h), xycoords='data', size=15)
        
        axis.annotate('Prediction:', xy=(4, 4 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        pred = 'no hate' if test_cases[i]['Prediction'] == 0 else 'hate speech'
        pred_color = 'b' if pred == 'no hate' else 'm'
        axis.annotate(pred, xy=(15, 4 + i*h), xycoords='data', size=15, color=pred_color)
        
        axis.annotate('Label:', xy=(27, 4 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        label = 'no hate' if test_cases[i]['Label'] == 0 else 'hate speech'
        label_color = 'b' if label == 'no hate' else 'm'
        axis.annotate(label, xy=(34, 4 + i*h), xycoords='data', size=15, color=label_color)
        
        axis.annotate('Result:', xy=(50, 4 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        reason = 'OK' if pred == label else '1-st type error' if pred == 'no hate' else '2-nd type error'
        reason_color = 'g' if reason == 'OK' else 'r'
        axis.annotate(reason, xy=(57, 4 + i*h), xycoords='data', size=15, color=reason_color)
        
        axis.plot([0, 100], [20 + i*h, 20 + i*h], color='k')
    
    
    plt.title(title)
    if file_name:
        plt.savefig(file_name)
    plt.show()

# %%
test_cases_board(test_cases, title='Tweets summary', file_name='results/en_lstm/tweets_summary.png')

# %% [markdown]
# # Hate Speech Detector - EN - LSTM model testing

# %% [markdown]
# ## Load test features, predict classes, assign tweets and save to .csv

# %%
# with open('tests/en_lstm/assigned_labels.csv', 'w+') as f:
#     writer = csv.writer(f)
#     writer.writerow(['Label'])
    
#     t = sorted(glob.glob('tests/en_lstm/X*'))
#     for file_name in t:
#         print("DZIAŁA!")
#         t.set_postfix_str(file_name)
#         archive = dir_archive(file_name, {}, cached=True)
#         archive.load()

#         test_features = archive['features']
        
#         test_predictions = model.predict(test_features)
#         test_labels = tf.argmax(test_predictions, axis=1).numpy()
        
#         for tl in test_labels:
#             writer.writerow([tl])
