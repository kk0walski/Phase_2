# %% [markdown]
# # Hate Speech Detector - EN - LSTM model

# %%
import os
import pandas as pd
import csv
import glob
import numpy as np
import pickle
from klepto.archives import dir_archive
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix

import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.layers import Input, Dense, SimpleRNN, LSTM, Concatenate
from tensorflow.keras.layers import Lambda
from tensorflow import split
from tensorflow.keras.utils import to_categorical

from collections import Counter
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
# %matplotlib inline

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %% [markdown]
# ## Load features & labels

# %%
archive = dir_archive( 'hsd/Reddit/X_y_lstm', {}, cached=True)
archive.load()
first_card = archive['wt_num']
archive = None

# %%
def get_data(data_path = 'hsd/Reddit/X_y_lstm', test=0.3):
    archive = dir_archive(data_path, {}, cached=True)
    archive.load()

    features = archive['features']
    labels = archive['labels']
    features = np.array(features)
    labels = np.array(labels)
    print(features.shape)
    print(first_card)
    
    X_train, X_test, y_train, y_test = train_test_split(features, labels, stratify=labels, test_size=test)

    print(Counter(y_train))
    print(Counter(y_test))

    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)

    return X_train, y_train, X_test, y_test

# %% [markdown]
# ## Model

# %% [markdown]
# The best model was selected using a GridSearch with 5-fold CV.

# %%
# hyperparams
LAYERS = 4  # convolutional layers count
LR = 0.01  # learning rate
OPTIM = tf.keras.optimizers.Adam  # optimizer
EPOCHS = 10

# params
BATCH_SIZE = 50  # size of input batch
INIT = 'random_normal'  # trainable param initializer
RNN_UNITS = 64  # recurrent network working units

# %%
class MetricsCallback(Callback):
    def __init__(self):
        super(MetricsCallback, self).__init__()
        self.val_f1s0 = []
        self.val_f1s1 = []
    
    def on_epoch_end(self, epoch, logs={}):
        val_predict = np.asarray(tf.argmax(self.model.predict(X_test), axis=1))
        val_true = np.asarray(tf.argmax(y_test, axis=1))
        c_m = confusion_matrix(val_true, val_predict, labels=[0, 1])
        self.val_f1s0.append(2*float(c_m[0][0])/(2*float(c_m[0][0]) + c_m[0][1] + c_m[1][0]))
        self.val_f1s1.append(2*float(c_m[1][1])/(2*float(c_m[1][1]) + c_m[1][0] + c_m[0][1]))

# %%
class LSTMModel():
    def __init__(self, wt_card, input_shape, model_type='lstm', name='conv_model', **kwargs):
        self.wt_card = wt_card
        self.type = LSTM if model_type == 'lstm' else SimpleRNN
        
        # hyperparams
        self.layers = LAYERS if 'layers' not in kwargs else kwargs['layers']
        self.lr = LR if 'lr' not in kwargs else kwargs['lr']
        self.optim = OPTIM(learning_rate=self.lr) if 'optim' not in kwargs else kwargs['optim'](learning_rate=self.lr)
        self.epochs = EPOCHS if 'epochs' not in kwargs else kwargs['epochs']
        
        # params
        self.batch_size = BATCH_SIZE if 'batch_size' not in kwargs else kwargs['batch_size']
        self.init = INIT if 'init' not in kwargs else kwargs['init']
        self.rnn_units = RNN_UNITS if 'rnn_units' not in kwargs else kwargs['rnn_units']
        
        # layers
        inputs = Input(shape=input_shape, name='features')
        # wt_inputs, pos_inputs = Lambda(lambda x: tf.split(x, [self.wt_card, x.shape[1] - self.wt_card], axis=1), name='wt_pos_split')(inputs)
        #wt_inputs, pos_inputs = Lambda(lambda x: split(x, [self.wt_card, x.shape[1] - self.wt_card], axis=1), name='wt_pos_split')(inputs)
        
        x = self.type(units=self.rnn_units, name='wt_recurrent',
                       kernel_initializer=self.init, bias_initializer=self.init)(inputs)
#         x2 = self.type(units=self.rnn_units, name='pos_recurrent',
#                        kernel_initializer=self.init, bias_initializer=self.init)(pos_inputs)
        
#         x = Concatenate(axis=1, name='concatenation')([x1, x2])
        
        x = Dense(64, activation='relu', name='dense_1',
                  kernel_initializer='random_normal', bias_initializer='random_normal')(x)
        x = Dense(64, activation='relu', name='dense_2',
                  kernel_initializer='random_normal', bias_initializer='random_normal')(x)
        outputs = Dense(2, activation='softmax', name='predictions',
                        kernel_initializer='random_normal', bias_initializer='random_normal')(x)
        
        self.name = name
        self.model = Model(inputs=inputs, outputs=outputs, name=name)
        self.mc = MetricsCallback()
    
    def summary(self):
        return self.model.summary()
    
    def compile(self):
        self.model.compile(optimizer=self.optim,
                           loss=tf.keras.losses.CategoricalCrossentropy(),
                           metrics=[tf.keras.metrics.CategoricalAccuracy()])
    
    def fit(self, X_tr, y_tr, X_ev, y_ev):
        return self.model.fit(X_tr, y_tr, batch_size=self.batch_size, epochs=self.epochs,
                              validation_data=(X_ev, y_ev), callbacks=[self.mc])
    
    def predict(self, X_t):
        return self.model.predict(X_t)
    
    def save(self, file_name):
        self.model.save(file_name)

# %%
def models_comparison_bars(df, title, interval=2, save_file=None):
    fig, axs = plt.subplots(1, 3, figsize=(16, 4))
    
    labels = [i+1 if i%interval == 0 else '' for i in range(len(df))]
    x = range(len(labels))
    acc = df['acc'].values
    f1s0 = df['f1s0'].values
    f1s1 = df['f1s1'].values
    
    max_acc_id = np.argmax(acc)
    max_f1s0_id = np.argmax(f1s0)
    max_f1s1_id = np.argmax(f1s1)
    
    axs[0].bar(x, acc, color='r')
    axs[0].set_xlabel('Model number')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xticks(x)
    axs[0].set_xticklabels(labels)
    axs[0].set_ylim([0, 1])
    axs[0].set_title('Accuracy | max ({}) at: {}'.format(np.round(np.max(acc), 2), max_acc_id+1))
    axs[0].patches[max_acc_id].set_facecolor('g')
    
    axs[1].bar(x, f1s0, color='b')
    axs[1].set_xlabel('Model number')
    axs[1].set_ylabel('F1 score (no hate)')
    axs[1].set_title('F1 score (no hate) | max ({}) at: {}'.format(np.round(np.max(f1s0), 2), max_f1s0_id+1))
    axs[1].set_xticks(x)
    axs[1].set_xticklabels(labels)
    axs[1].set_ylim([0, 1])
    axs[1].patches[max_f1s0_id].set_facecolor('g')
    
    axs[2].bar(x, f1s1, color='m')
    axs[2].set_xlabel('Model number')
    axs[2].set_ylabel('F1 score (hate speech)')
    axs[2].set_title('F1 score (hate speech) | max ({}) at: {}'.format(np.round(np.max(f1s1), 2),
                                                                       max_f1s1_id+1))
    axs[2].set_xticks(x)
    axs[2].set_xticklabels(labels)
    axs[2].set_ylim([0, 1])
    axs[2].patches[max_f1s1_id].set_facecolor('g')
    
    fig.suptitle(title)
    
    if save_file:
        plt.savefig(save_file)
    plt.show()

# %% [markdown]
# ## Model hyperparams researching

# %%
def get_hyperparams_options(layers_options = [2, 3, 4, 5], lr_options = [0.01, 0.001],
                            optim_options = [tf.keras.optimizers.Adam, tf.keras.optimizers.SGD],
                            epochs_options = [5, 10, 15]):
    hp_options = []
    for epochs in [epochs_options[-1]]:  # changed to process 15 epochs (eval. after each 5)
        for lr in lr_options:
            for optim in optim_options:
                for layer in layers_options:
                    hp_options.append({'lr': lr, 'optim': optim, 'epochs': epochs, 'layers': layer})
    return hp_options

# %%
X_train, y_train, X_test, y_test = get_data()
# Out:
# (55132, 19, 300)
# 19
# Counter({0: 24690, 1: 13902})
# Counter({0: 10582, 1: 5958})

# %%
def find_hyper_parameters(options, shape, save_path = 'results/en_lstm/hyperparams_research.csv', epochs_options = [5, 10, 15]):    
    if not os.path.exists('results/en_lstm/hyperparams_research.csv'):
        hp_results = []
        for i, opts in enumerate(options):
            print('\nResearching for {}/{} | Hyperparams: {}\n'.format(i+1, len(hp_options), opts))
            hp_model = LSTMModel(wt_card=first_card, input_shape=shape, model_type='simple', **opts)
            hp_model.compile()
            hp_history = hp_model.fit(X_train, y_train, X_test, y_test)

            # append means for 5, 10 and 15 epochs
            for eps in epochs_options:
                hp_results.append({'acc': np.mean(hp_history.history['categorical_accuracy'][:eps]),
                                'val_acc': np.mean(hp_history.history['val_categorical_accuracy'][:eps]),
                                'loss': np.mean(hp_history.history['val_loss'][:eps]),
                                'f1s0': np.mean(hp_model.mc.val_f1s0[:eps]),
                                'f1s1': np.mean(hp_model.mc.val_f1s1[:eps])})
        
        hp_results_df = pd.DataFrame(hp_results)
        hp_results_df.to_csv('results/en_lstm/hyperparams_research.csv')
    else:
        hp_results_df = pd.read_csv('results/en_lstm/hyperparams_research.csv', index_col=0)
    return hp_results_df

# %%
hp_options = get_hyperparams_options()
hp_results_df = find_hyper_parameters(options = hp_options, shape=(19, 300, ))

# %%
hp_results_df.head()
# Out:
#         acc   val_acc      loss      f1s0  f1s1
# 0  0.639697  0.639782  0.653851  0.780326   0.0
# 1  0.639734  0.639782  0.653759  0.780326   0.0
# 2  0.639746  0.639782  0.653790  0.780326   0.0
# 3  0.639770  0.639782  0.653733  0.780326   0.0
# 4  0.639770  0.639782  0.653821  0.780326   0.0

# %%
models_comparison_bars(hp_results_df, title='Hyperparams research', interval=10, save_file='results/en_lstm/hyperparams_research.png')
hp_results_df = None

# %%
best_h_num = 36
'Best one: {} with {} run epochs'.format(hp_options[(best_h_num-1)%3],
                                         ((best_h_num-1)%3)*5 if (best_h_num-1)%3 != 0 else 15)
# Out:
# "Best one: {'lr': 0.01, 'optim': <class 'tensorflow.python.keras.optimizer_v2.adam.Adam'>, 'epochs': 15, 'layers': 4} with 10 run epochs"

# %% [markdown]
# ## Model params researching

# %%
def get_params_options( batch_size_options = [25, 50, 75, 100, 125],
                        init_options = ['random_uniform', 'random_normal'],
                        rnn_units_options = [64, 128, 192, 255]):

    p_options = []
    for batch_size in batch_size_options:
        for init in init_options:
            for rnn_units in rnn_units_options:
                p_options.append({'batch_size': batch_size,
                                'init': init,
                                'rnn_units': rnn_units})
    return p_options

# %%
p_options = get_params_options()
pd.DataFrame(p_options).head()
# Out:
#    batch_size            init  rnn_units
# 0          25  random_uniform         64
# 1          25  random_uniform        128
# 2          25  random_uniform        192
# 3          25  random_uniform        255
# 4          25   random_normal         64

# %%
def find_parameters(options, shape, 
    save_path = 'results/en_lstm/params_research.csv', epochs_options = [5, 10, 15]):
    if not os.path.exists(save_path):
        p_results = []
        for i, opts in enumerate(p_options):
            print('\nResearching for {}/{} | Hyperparams: {}\n'.format(i+1, len(p_options), opts))

            p_model = LSTMModel(wt_card=first_card, input_shape=shape, model_type='simple', **opts)
            p_model.compile()
            p_history = p_model.fit(X_train, y_train, X_test, y_test)

            p_results.append({'acc': np.mean(p_history.history['categorical_accuracy']),
                            'val_acc': np.mean(p_history.history['val_categorical_accuracy']),
                            'loss': np.mean(p_history.history['val_loss']),
                            'f1s0': np.mean(p_model.mc.val_f1s0),
                            'f1s1': np.mean(p_model.mc.val_f1s1)})

        p_results_df = pd.DataFrame(p_results)
        p_results_df.to_csv(save_path)
    else:
        p_results_df = pd.read_csv(save_path, index_col=0)
    return p_results_df

# %%
p_results_df = find_parameters(options = p_options, shape = (19, 300, ))
# Out:
# Researching for 1/40 | Hyperparams: {'batch_size': 25, 'init': 'random_uniform', 'rnn_units': 64}
#
# Epoch 1/10
# 1544/1544 [==============================] - 19s 11ms/step - loss: 0.6566 - categorical_accuracy: 0.6386 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 2/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6528 - categorical_accuracy: 0.6420 - val_loss: 0.6543 - val_categorical_accuracy: 0.6398
# Epoch 3/10
# 1544/1544 [==============================] - 17s 11ms/step - loss: 0.6542 - categorical_accuracy: 0.6393 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 4/10
# 1544/1544 [==============================] - 16s 11ms/step - loss: 0.6570 - categorical_accuracy: 0.6342 - val_loss: 0.6540 - val_categorical_accuracy: 0.6398
# Epoch 5/10
# 1544/1544 [==============================] - 16s 11ms/step - loss: 0.6541 - categorical_accuracy: 0.6397 - val_loss: 0.6543 - val_categorical_accuracy: 0.6398
# Epoch 6/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6527 - categorical_accuracy: 0.6421 - val_loss: 0.6540 - val_categorical_accuracy: 0.6398
# Epoch 7/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6548 - categorical_accuracy: 0.6385 - val_loss: 0.6544 - val_categorical_accuracy: 0.6398
# Epoch 8/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6521 - categorical_accuracy: 0.6431 - val_loss: 0.6539 - val_categorical_accuracy: 0.6398
# Epoch 9/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6546 - categorical_accuracy: 0.6389 - val_loss: 0.6542 - val_categorical_accuracy: 0.6398
# Epoch 10/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6529 - categorical_accuracy: 0.6418 - val_loss: 0.6537 - val_categorical_accuracy: 0.6398
#
# Researching for 2/40 | Hyperparams: {'batch_size': 25, 'init': 'random_uniform', 'rnn_units': 128}
#
# Epoch 1/10
# 1544/1544 [==============================] - 18s 11ms/step - loss: 0.6576 - categorical_accuracy: 0.6398 - val_loss: 0.6538 - val_categorical_accuracy: 0.6398
# Epoch 2/10
# 1544/1544 [==============================] - 17s 11ms/step - loss: 0.6536 - categorical_accuracy: 0.6407 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 3/10
# 1544/1544 [==============================] - 17s 11ms/step - loss: 0.6564 - categorical_accuracy: 0.6357 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 4/10
# 1544/1544 [==============================] - 18s 12ms/step - loss: 0.6531 - categorical_accuracy: 0.6413 - val_loss: 0.6535 - val_categorical_accuracy: 0.6398
# Epoch 5/10
# 1544/1544 [==============================] - 18s 11ms/step - loss: 0.6549 - categorical_accuracy: 0.6385 - val_loss: 0.6535 - val_categorical_accuracy: 0.6398
# Epoch 6/10
# 1544/1544 [==============================] - 17s 11ms/step - loss: 0.6515 - categorical_accuracy: 0.6442 - val_loss: 0.6537 - val_categorical_accuracy: 0.6398
# Epoch 7/10
# 1544/1544 [==============================] - 17s 11ms/step - loss: 0.6544 - categorical_accuracy: 0.6396 - val_loss: 0.6568 - val_categorical_accuracy: 0.6398
# Epoch 8/10
# 1544/1544 [==============================] - 17s 11ms/step - loss: 0.6533 - categorical_accuracy: 0.6409 - val_loss: 0.6539 - val_categorical_accuracy: 0.6398
# Epoch 9/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6549 - categorical_accuracy: 0.6381 - val_loss: 0.6535 - val_categorical_accuracy: 0.6398
# Epoch 10/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6562 - categorical_accuracy: 0.6357 - val_loss: 0.6540 - val_categorical_accuracy: 0.6398
#
# Researching for 3/40 | Hyperparams: {'batch_size': 25, 'init': 'random_uniform', 'rnn_units': 192}
#
# Epoch 1/10
# 1544/1544 [==============================] - 17s 11ms/step - loss: 0.6570 - categorical_accuracy: 0.6375 - val_loss: 0.6535 - val_categorical_accuracy: 0.6398
# Epoch 2/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6539 - categorical_accuracy: 0.6401 - val_loss: 0.6537 - val_categorical_accuracy: 0.6398
# Epoch 3/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6548 - categorical_accuracy: 0.6381 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 4/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6523 - categorical_accuracy: 0.6430 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 5/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6524 - categorical_accuracy: 0.6426 - val_loss: 0.6535 - val_categorical_accuracy: 0.6398
# Epoch 6/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6569 - categorical_accuracy: 0.6346 - val_loss: 0.6542 - val_categorical_accuracy: 0.6398
# Epoch 7/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6550 - categorical_accuracy: 0.6386 - val_loss: 0.6545 - val_categorical_accuracy: 0.6398
# Epoch 8/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6564 - categorical_accuracy: 0.6355 - val_loss: 0.6542 - val_categorical_accuracy: 0.6398
# Epoch 9/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6545 - categorical_accuracy: 0.6387 - val_loss: 0.6535 - val_categorical_accuracy: 0.6398
# Epoch 10/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6517 - categorical_accuracy: 0.6437 - val_loss: 0.6552 - val_categorical_accuracy: 0.6398
#
# Researching for 4/40 | Hyperparams: {'batch_size': 25, 'init': 'random_uniform', 'rnn_units': 255}
#
# Epoch 1/10
# 1544/1544 [==============================] - 17s 11ms/step - loss: 0.6641 - categorical_accuracy: 0.6336 - val_loss: 0.6564 - val_categorical_accuracy: 0.6398
# Epoch 2/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6555 - categorical_accuracy: 0.6367 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 3/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6542 - categorical_accuracy: 0.6395 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 4/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6537 - categorical_accuracy: 0.6403 - val_loss: 0.6539 - val_categorical_accuracy: 0.6398
# Epoch 5/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6547 - categorical_accuracy: 0.6386 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 6/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6550 - categorical_accuracy: 0.6380 - val_loss: 0.6538 - val_categorical_accuracy: 0.6398
# Epoch 7/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6563 - categorical_accuracy: 0.6359 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 8/10
# 1544/1544 [==============================] - 18s 11ms/step - loss: 0.6539 - categorical_accuracy: 0.6397 - val_loss: 0.6540 - val_categorical_accuracy: 0.6398
# Epoch 9/10
# 1544/1544 [==============================] - 17s 11ms/step - loss: 0.6528 - categorical_accuracy: 0.6421 - val_loss: 0.6564 - val_categorical_accuracy: 0.6398
# Epoch 10/10
# 1544/1544 [==============================] - 17s 11ms/step - loss: 0.6531 - categorical_accuracy: 0.6420 - val_loss: 0.6537 - val_categorical_accuracy: 0.6398
#
# Researching for 5/40 | Hyperparams: {'batch_size': 25, 'init': 'random_normal', 'rnn_units': 64}
#
# Epoch 1/10
# 1544/1544 [==============================] - 18s 11ms/step - loss: 0.6555 - categorical_accuracy: 0.6356 - val_loss: 0.6541 - val_categorical_accuracy: 0.6398
# Epoch 2/10
# 1544/1544 [==============================] - 17s 11ms/step - loss: 0.6538 - categorical_accuracy: 0.6399 - val_loss: 0.6558 - val_categorical_accuracy: 0.6398
# Epoch 3/10
# 1544/1544 [==============================] - 16s 11ms/step - loss: 0.6537 - categorical_accuracy: 0.6410 - val_loss: 0.6546 - val_categorical_accuracy: 0.6398
# Epoch 4/10
# 1544/1544 [==============================] - 16s 11ms/step - loss: 0.6550 - categorical_accuracy: 0.6385 - val_loss: 0.6538 - val_categorical_accuracy: 0.6398
# Epoch 5/10
# 1544/1544 [==============================] - 17s 11ms/step - loss: 0.6536 - categorical_accuracy: 0.6405 - val_loss: 0.6540 - val_categorical_accuracy: 0.6398
# Epoch 6/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6537 - categorical_accuracy: 0.6404 - val_loss: 0.6540 - val_categorical_accuracy: 0.6398
# Epoch 7/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6526 - categorical_accuracy: 0.6419 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 8/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6509 - categorical_accuracy: 0.6449 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 9/10
# 1544/1544 [==============================] - 16s 11ms/step - loss: 0.6545 - categorical_accuracy: 0.6389 - val_loss: 0.6544 - val_categorical_accuracy: 0.6398
# Epoch 10/10
# 1544/1544 [==============================] - 16s 10ms/step - loss: 0.6534 - categorical_accuracy: 0.6414 - val_loss: 0.6535 - val_categorical_accuracy: 0.6398
#
# Researching for 6/40 | Hyperparams: {'batch_size': 25, 'init': 'random_normal', 'rnn_units': 128}
#
# Epoch 1/10
# 1544/1544 [==============================] - 18s 11ms/step - loss: 0.6600 - categorical_accuracy: 0.6347 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 2/10
# 1544/1544 [==============================] - 17s 11ms/step - loss: 0.6522 - categorical_accuracy: 0.6434 - val_loss: 0.6536 - val_categorical_accuracy: 0.6398
# Epoch 3/10
# 1544/1544 [==============================] - 17s 11ms/step - loss: 0.6518 - categorical_accuracy: 0.6435 - val_loss: 0.6540 - val_categorical_accuracy: 0.6398
# Epoch 4/10
# 1544/1544 [==============================] - 16s 11ms/step - loss: 0.6527 - categorical_accuracy: 0.6419 - val_loss: 0.6548 - val_categorical_accuracy: 0.6398
# Epoch 5/10
# 1544/1544 [==============================] - 16s 11ms/step - loss: 0.6529 - categorical_accuracy: 0.6420 - val_loss: 0.6553 - val_categorical_accuracy: 0.6398
# Epoch 6/10
# 1544/1544 [==============================] - 17s 11ms/step - loss: 0.6535 - categorical_accuracy: 0.6412 - val_loss: 0.6537 - val_categorical_accuracy: 0.6398
# Epoch 7/10
# 1544/1544 [==============================] - 16s 11ms/step - loss: 0.6542 - categorical_accuracy: 0.6398 - val_loss: 0.6541 - val_categorical_accuracy: 0.6398
# Epoch 8/10
# 1544/1544 [==============================] - 16s 11ms/step - loss: 0.6531 - categorical_accuracy: 0.6416 - val_loss: 0.6542 - val_categorical_accuracy: 0.6398
# Epoch 9/10
# 1544/1544 [==============================] - 16s 11ms/step - loss: 0.6533 - categorical_accuracy: 0.6411 - val_loss: 0.6539 - val_categorical_accuracy: 0.6398
# Epoch 10/10
# 1544/1544 [==============================] - 16s 11ms/step - loss: 0.6547 - categorical_accuracy: 0.6385 - val_loss: 0.6538 - val_categorical_accuracy: 0.6398
#
# Researching for 7/40 | Hyperparams: {'batch_size': 25, 'init': 'random_normal', 'rnn_units': 192}
#
# Epoch 1/10
# 1544/1544 [==============================] - 18s 11ms/step - loss: 0.6575 - categorical_accuracy: 0.6426 - val_loss: 0.6535 - val_categorical_accuracy: 0.6398
# Epoch 2/10
# 1544/1544 [==============================] - 16s 11ms/step - loss: 0.6725 - categorical_accuracy: 0.6431 - val_loss: 0.6535 - val_categorical_accuracy: 0.6398
# Epoch 3/10
# 1544/1544 [==============================] - 16s 11ms/step - loss: 0.6542 - categorical_accuracy: 0.6395 - val_loss: 0.6569 - val_categorical_accuracy: 0.6398
# Epoch 4/10
# 1063/1544 [===================>..........] - ETA: 4s - loss: 0.6529 - categorical_accuracy: 0.6425

# %%
p_results_df.head()

# %%
models_comparison_bars(p_results_df, title='Params research', save_file='results/en_lstm/params_research.png')

# %%
best_num = 33
'Best one: {}'.format(p_options[best_num-1])
# Out:
# "Best one: {'batch_size': 125, 'init': 'random_uniform', 'rnn_units': 64}"

# %% [markdown]
# ## Best model

# %%
model = LSTMModel(wt_card=first_card, input_shape=(19, 300, ))
model.summary()
# Out:
# Model: "conv_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# features (InputLayer)        [(None, 19, 300)]         0
# _________________________________________________________________
# wt_recurrent (LSTM)          (None, 64)                93440
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# predictions (Dense)          (None, 2)                 130
# =================================================================
# Total params: 101,890
# Trainable params: 101,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile()
X_train, y_train, X_test, y_test = get_data()
history = model.fit(X_train, y_train, X_test, y_test)
model.save('models/en_lstm.model')
# Out:
# (55132, 19, 300)
# 19
# Counter({0: 24690, 1: 13902})
# Counter({0: 10582, 1: 5958})
# Epoch 1/20
# 772/772 [==============================] - 38s 7ms/step - loss: 0.5831 - categorical_accuracy: 0.6958 - val_loss: 0.3428 - val_categorical_accuracy: 0.8632
# Epoch 2/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.3394 - categorical_accuracy: 0.8651 - val_loss: 0.3380 - val_categorical_accuracy: 0.8660
# Epoch 3/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.3253 - categorical_accuracy: 0.8705 - val_loss: 0.3297 - val_categorical_accuracy: 0.8682
# Epoch 4/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.3160 - categorical_accuracy: 0.8743 - val_loss: 0.3359 - val_categorical_accuracy: 0.8679
# Epoch 5/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.2963 - categorical_accuracy: 0.8821 - val_loss: 0.3453 - val_categorical_accuracy: 0.8575
# Epoch 6/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.2771 - categorical_accuracy: 0.8889 - val_loss: 0.3554 - val_categorical_accuracy: 0.8563
# Epoch 7/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.2501 - categorical_accuracy: 0.9029 - val_loss: 0.3722 - val_categorical_accuracy: 0.8577
# Epoch 8/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.2261 - categorical_accuracy: 0.9113 - val_loss: 0.3988 - val_categorical_accuracy: 0.8505
# Epoch 9/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.2018 - categorical_accuracy: 0.9205 - val_loss: 0.4678 - val_categorical_accuracy: 0.8486
# Epoch 10/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.1820 - categorical_accuracy: 0.9300 - val_loss: 0.4601 - val_categorical_accuracy: 0.8486
# Epoch 11/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.1560 - categorical_accuracy: 0.9413 - val_loss: 0.5639 - val_categorical_accuracy: 0.8446
# Epoch 12/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.1369 - categorical_accuracy: 0.9508 - val_loss: 0.6238 - val_categorical_accuracy: 0.8420
# Epoch 13/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.1251 - categorical_accuracy: 0.9540 - val_loss: 0.6111 - val_categorical_accuracy: 0.8349
# Epoch 14/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.1049 - categorical_accuracy: 0.9632 - val_loss: 0.7184 - val_categorical_accuracy: 0.8319
# Epoch 15/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.1077 - categorical_accuracy: 0.9632 - val_loss: 0.7398 - val_categorical_accuracy: 0.8340
# Epoch 16/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.0896 - categorical_accuracy: 0.9702 - val_loss: 0.7463 - val_categorical_accuracy: 0.8256
# Epoch 17/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.0844 - categorical_accuracy: 0.9728 - val_loss: 0.6308 - val_categorical_accuracy: 0.8289
# Epoch 18/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.0808 - categorical_accuracy: 0.9734 - val_loss: 0.8306 - val_categorical_accuracy: 0.8297
# Epoch 19/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.0754 - categorical_accuracy: 0.9757 - val_loss: 0.8702 - val_categorical_accuracy: 0.8294
# Epoch 20/20
# 772/772 [==============================] - 4s 5ms/step - loss: 0.0708 - categorical_accuracy: 0.9775 - val_loss: 0.7621 - val_categorical_accuracy: 0.8247
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/en_lstm.model/assets
# INFO:tensorflow:Assets written to: models/en_lstm.model/assets

# %%
predictions = model.predict(X_test)
y_true = tf.argmax(y_test, axis=1)
y_pred = tf.argmax(predictions, axis=1)

conf_mat = tf.math.confusion_matrix(labels=y_true, predictions=y_pred, num_classes=2).numpy()
acc = float(np.sum(np.diag(conf_mat)))/np.sum(np.sum(conf_mat))
f1s0 = 2*float(conf_mat[0][0])/(2*float(conf_mat[0][0]) + conf_mat[0][1] + conf_mat[1][0])
f1s1 = 2*float(conf_mat[1][1])/(2*float(conf_mat[1][1]) + conf_mat[1][0] + conf_mat[0][1])

# %%
if not os.path.exists('results/en_lstm/short_results.csv'):
    with open('results/en_lstm/short_results.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(['Accuracy', 'F1 score (0)', 'F1 score (1)'])
        writer.writerow([acc, f1s0, f1s1])
else:
    with open('results/en_lstm/short_results.csv', 'a') as f:
        writer = csv.writer(f)
        writer.writerow([acc, f1s0, f1s1])

# %%
# save model history, confusion matrix and accuracy
model_results = {'acc': history.history['categorical_accuracy'],
                 'val_acc': history.history['val_categorical_accuracy'],
                 'loss': history.history['loss'],
                 'val_loss': history.history['val_loss'],
                 'f1s0': model.mc.val_f1s0,
                 'f1s1': model.mc.val_f1s1,
                 'conf_mat': conf_mat,
                 'main_acc': acc}
with open('results/en_lstm/results.pkl', 'wb') as f:
    pickle.dump(model_results, f)

# %% [markdown]
# ## Visualizations

# %%
def plots(y_ss, y_labels, colors, title, file_name=None):
    x_s = range(1, len(y_ss[0])+1)
    for y_s, y_label, color in zip(y_ss, y_labels, colors):
        plt.plot(x_s, y_s, color, label=y_label)
    plt.xlabel('Epoch')
    plt.ylabel('Metrics')
    tick_marks = np.arange(1, len(x_s) + 1)
    plt.xticks(tick_marks, x_s)
    plt.title(title)
    
    plt.legend(loc='best', frameon=False)
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

def twinx_plot(y11_s, y12_s, y21_s, y22_s, x_label, y1_label,y2_label, title,
               styles=['r-', 'r--', 'b-', 'b--'], colors=['r', 'b'], file_name=None):
    fig, ax1 = plt.subplots()
    
    ax1.set_xlabel(x_label)
    ax1.set_xticks(range(1, len(y11_s)+1))
    
    ax1.set_ylabel(y1_label, color=colors[0])
    ax1.plot(range(1, len(y11_s)+1), y11_s, styles[0], label='train acc.')
    ax1.plot(range(1, len(y12_s)+1), y12_s, styles[1], label='valid. acc.')
    ax1.tick_params(axis='y', labelcolor=colors[0])
    
    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
    
    ax2.set_ylabel(y2_label, color=colors[1])  # we already handled the x-label with ax1
    ax2.plot(range(1, len(y21_s)+1), y21_s, styles[2], label='train loss')
    ax2.plot(range(1, len(y22_s)+1), y22_s, styles[3], label='valid. loss')
    ax2.tick_params(axis='y', labelcolor=colors[1])
    
    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    fig.legend(loc='right', bbox_to_anchor=(0.85, 0.5))
    plt.title(title)
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

def confusion_matrix_plot(conf_mat, cls, x_label, y_label, title, file_name=None):
    plt.imshow(conf_mat, interpolation='nearest', cmap=plt.cm.Wistia)
    plt.title(title)
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    tick_marks = np.arange(len(cls))
    plt.grid(False)
    plt.xticks(tick_marks, cls, rotation=45)
    plt.yticks(tick_marks, cls)
    
    for i in range(len(cls)):
        for j in range(len(cls)):
            plt.text(j - 0.2, i, str(conf_mat[i][j]), fontsize=16)
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

def class_distribution_hist(y_true, y_pred, cls, x_label, y_label, title, file_name=None):
    pd.Series([y_true, y_pred]).hist()
    plt.title(title)
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    tick_marks = np.arange(len(cls))
    plt.xticks(tick_marks, cls)
    plt.legend(labels=['Real', 'Predicted'], loc='best')
    
    if file_name:
        plt.savefig(file_name)
    plt.show()

# %%
classes = ['no hate', 'hate speech']

# %%
plots([history.history['categorical_accuracy'],
       history.history['val_categorical_accuracy'],
       model.mc.val_f1s0,
       model.mc.val_f1s1],
      ['training acc.', 'validation acc.', 'no-hate f1 score', 'hate-speech f1 score'],
      ['-r', '--r', 'b', 'm'],
      title='Training progress', file_name='results/en_lstm/train_progress.png')

# %%
twinx_plot(history.history['categorical_accuracy'], history.history['val_categorical_accuracy'],
           history.history['loss'], history.history['val_loss'],
          x_label='Epoch', y1_label='Accuracy', y2_label='Loss', title='Accuracy & loss / epoch',
          file_name='results/en_lstm/acc_loss.png')

# %%
confusion_matrix_plot(conf_mat, cls=classes,
                      x_label='Real', y_label='Predicted',
                      title='Accuracy: {}'.format(round(acc, 2)),
                      file_name='results/en_lstm/cm.png')

# %%
class_distribution_hist(y_true, y_pred, cls=classes,
                        x_label='Classes', y_label='Cardinality', title='Real and pred. classes cards.',
                        file_name='results/en_lstm/cards.png')

# %%
with open('hsd/Reddit/perfect_data.pkl', 'rb') as f:
    texts, _ = pickle.load(f)
texts = texts[int(0.7*len(texts)):]

indices = [6, 10, 19, 26, 27, 28, 29, 164]
test_cases = []
for i, (t, p, l) in enumerate(zip(texts, y_pred, y_true)):
    if i in indices:
        test_cases.append({'Text': t, 'Prediction': p.numpy(), 'Label': l.numpy()})

# %%
def test_cases_board(test_cases, title, file_name=None):
    h = 20
    n = len(test_cases)
    fig, axis = plt.subplots(1, 1, figsize=(16., n*3.2))
    axis.axis('off')
    axis.set_xlim([0, 100])
    axis.set_ylim([0, n*h])
    axis.plot([0, 100], [0, 0], color='k')
    axis.plot([0, 0], [0, n*h], color='k')
    axis.plot([100, 100], [0, n*h], color='k')
    
    for i in range(n):
        axis.annotate('Tweet text:', xy=(4, 16 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        text = u'{}'.format(test_cases[i]['Text'].replace('\n', ''))
        text = '\n'.join([text[j:j+int(len(text)/3)] for j in range(0, len(text), int(len(text)/3))])
        axis.annotate(text, xy=(4, 7 + i*h), xycoords='data', size=15)
        
        axis.annotate('Prediction:', xy=(4, 4 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        pred = 'no hate' if test_cases[i]['Prediction'] == 0 else 'hate speech'
        pred_color = 'b' if pred == 'no hate' else 'm'
        axis.annotate(pred, xy=(15, 4 + i*h), xycoords='data', size=15, color=pred_color)
        
        axis.annotate('Label:', xy=(27, 4 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        label = 'no hate' if test_cases[i]['Label'] == 0 else 'hate speech'
        label_color = 'b' if label == 'no hate' else 'm'
        axis.annotate(label, xy=(34, 4 + i*h), xycoords='data', size=15, color=label_color)
        
        axis.annotate('Result:', xy=(50, 4 + i*h),
                      xycoords='data', size=15, fontweight='bold')
        reason = 'OK' if pred == label else '1-st type error' if pred == 'no hate' else '2-nd type error'
        reason_color = 'g' if reason == 'OK' else 'r'
        axis.annotate(reason, xy=(57, 4 + i*h), xycoords='data', size=15, color=reason_color)
        
        axis.plot([0, 100], [20 + i*h, 20 + i*h], color='k')
    
    
    plt.title(title)
    if file_name:
        plt.savefig(file_name)
    plt.show()

# %%
test_cases_board(test_cases, title='Tweets summary', file_name='results/en_lstm/tweets_summary.png')

# %% [markdown]
# # Hate Speech Detector - EN - LSTM model testing

# %% [markdown]
# ## Load test features, predict classes, assign tweets and save to .csv

# %%
# with open('tests/en_lstm/assigned_labels.csv', 'w+') as f:
#     writer = csv.writer(f)
#     writer.writerow(['Label'])
    
#     t = sorted(glob.glob('tests/en_lstm/X*'))
#     for file_name in t:
#         print("DZIAŁA!")
#         t.set_postfix_str(file_name)
#         archive = dir_archive(file_name, {}, cached=True)
#         archive.load()

#         test_features = archive['features']
        
#         test_predictions = model.predict(test_features)
#         test_labels = tf.argmax(test_predictions, axis=1).numpy()
        
#         for tl in test_labels:
#             writer.writerow([tl])
